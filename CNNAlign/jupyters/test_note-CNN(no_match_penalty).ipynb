# %%
import os, sys
root_path = os.path.abspath('.').split('jupyters')[0]
sys.path.append(root_path)

# %%
import json
import argparse
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

from data_loader import load_data
from models.cnn_geo import CNN_geo

from debug_tools import data, train, visualize
from utils import image
import geo_transform as tps
import CNNgeo_debug

# %% [markdown]
# # 1. Read configuration file

# %%
with open('../overfit.json') as fp:
    config = json.load(fp)
split = 'val'

# %%
print(config)
# Out:
# {'exp_desc': '200507_regressor_filter_size_up', 'dataset_name': 'mini_imagenet', 'data_dir': '/home/files/datasets/mini_imagenet', 'image_shape': [64, 64, 3], 'model_name': 'CNNgeo', 'backbone': 'prototypical_network', 'data': {'method': 'synthesized_pair', 'tps_random_rate': 0.2, 'pad_ratio': 0.2}, 'ckpt': {'save_type': 'latest', 'max_to_keep': 10}, 'train': {'n_examples': 1, 'learning_rate': 0.0001, 'batch_size': 1, 'epochs': 200, 'print_step': 10}, 'val': {'n_examples': 1, 'batch_size': 1}, 'test': {'n_examples': -1, 'batch_size': 128}}

# %%
print(config['train'])
# Out:
# {'n_examples': 1, 'learning_rate': 0.0001, 'batch_size': 1, 'epochs': 200, 'print_step': 10}

# %%
config['backbone'] = 'vgg16'
config['train']['epochs'] = 200

# %%
print("backbone : ", config['backbone'])
print("n_examples : ", config['train']['n_examples'])
print("learning_rate : ", config['train']['learning_rate'])
print("batch_size : ", config['train']['batch_size'])
print("epoch num : ", config['train']['epochs'])
# Out:
# backbone :  vgg16
# n_examples :  1
# learning_rate :  0.0001
# batch_size :  1
# epoch num :  200

# %% [markdown]
# # 2. Train model on the config parameters

# %%
model = CNNgeo_debug.train(config)
# Out:
# train dataset amount : 1
# val dataset amount : 1
# start of epoch 1
# Training loss (for one batch) at step 0: 0.4000958800315857
# Epoch 1, Loss: 0.4000958800315857, Val Loss: 0.39375659823417664
# end of epoch.
# start of epoch 2
# Training loss (for one batch) at step 0: 0.5947171449661255
# Epoch 2, Loss: 0.5947171449661255, Val Loss: 0.4371248483657837
# end of epoch.
# start of epoch 3
# Training loss (for one batch) at step 0: 0.42278024554252625
# Epoch 3, Loss: 0.42278024554252625, Val Loss: 0.47741010785102844
# end of epoch.
# start of epoch 4
# Training loss (for one batch) at step 0: 0.4198911786079407
# Epoch 4, Loss: 0.4198911786079407, Val Loss: 0.49175095558166504
# end of epoch.
# start of epoch 5
# Training loss (for one batch) at step 0: 0.46138983964920044
# Epoch 5, Loss: 0.46138983964920044, Val Loss: 0.4655132591724396
# end of epoch.
# start of epoch 6
# Training loss (for one batch) at step 0: 0.5430690050125122
# Epoch 6, Loss: 0.5430690050125122, Val Loss: 0.4431743025779724
# end of epoch.
# start of epoch 7
# Training loss (for one batch) at step 0: 0.5646045804023743
# Epoch 7, Loss: 0.5646045804023743, Val Loss: 0.5192415714263916
# end of epoch.
# start of epoch 8
# Training loss (for one batch) at step 0: 0.3780044615268707
# Epoch 8, Loss: 0.3780044615268707, Val Loss: 0.452041357755661
# end of epoch.
# start of epoch 9
# Training loss (for one batch) at step 0: 0.463996559381485
# Epoch 9, Loss: 0.463996559381485, Val Loss: 0.4299556314945221
# end of epoch.
# start of epoch 10
# Training loss (for one batch) at step 0: 0.5185344815254211
# Epoch 10, Loss: 0.5185344815254211, Val Loss: 0.4404972493648529
# end of epoch.
# start of epoch 11
# Training loss (for one batch) at step 0: 0.49826323986053467
# Epoch 11, Loss: 0.49826323986053467, Val Loss: 0.5160384178161621
# end of epoch.
# start of epoch 12
# Training loss (for one batch) at step 0: 0.48121264576911926
# Epoch 12, Loss: 0.48121264576911926, Val Loss: 0.4504469633102417
# end of epoch.
# start of epoch 13
# Training loss (for one batch) at step 0: 0.5251848101615906
# Epoch 13, Loss: 0.5251848101615906, Val Loss: 0.45294952392578125
# end of epoch.
# start of epoch 14
# Training loss (for one batch) at step 0: 0.5043129324913025
# Epoch 14, Loss: 0.5043129324913025, Val Loss: 0.5045661330223083
# end of epoch.
# start of epoch 15
# Training loss (for one batch) at step 0: 0.5272942781448364
# Epoch 15, Loss: 0.5272942781448364, Val Loss: 0.5196816325187683
# end of epoch.
# start of epoch 16
# Training loss (for one batch) at step 0: 0.5350862741470337
# Epoch 16, Loss: 0.5350862741470337, Val Loss: 0.5044053792953491
# end of epoch.
# start of epoch 17
# Training loss (for one batch) at step 0: 0.42250582575798035
# Epoch 17, Loss: 0.42250582575798035, Val Loss: 0.5844043493270874
# end of epoch.
# start of epoch 18
# Training loss (for one batch) at step 0: 0.4585246741771698
# Epoch 18, Loss: 0.4585246741771698, Val Loss: 0.5348750948905945
# end of epoch.
# start of epoch 19
# Training loss (for one batch) at step 0: 0.49671831727027893
# Epoch 19, Loss: 0.49671831727027893, Val Loss: 0.4856959879398346
# end of epoch.
# start of epoch 20
# Training loss (for one batch) at step 0: 0.5155988335609436
# Epoch 20, Loss: 0.5155988335609436, Val Loss: 0.5294046998023987
# end of epoch.
# start of epoch 21
# Training loss (for one batch) at step 0: 0.4006807208061218
# Epoch 21, Loss: 0.4006807208061218, Val Loss: 0.5410781502723694
# end of epoch.
# start of epoch 22
# Training loss (for one batch) at step 0: 0.49274227023124695
# Epoch 22, Loss: 0.49274227023124695, Val Loss: 0.5512199997901917
# end of epoch.
# start of epoch 23
# Training loss (for one batch) at step 0: 0.4989531934261322
# Epoch 23, Loss: 0.4989531934261322, Val Loss: 0.49186962842941284
# end of epoch.
# start of epoch 24
# Training loss (for one batch) at step 0: 0.414101243019104
# Epoch 24, Loss: 0.414101243019104, Val Loss: 0.48510611057281494
# end of epoch.
# start of epoch 25
# Training loss (for one batch) at step 0: 0.5448585152626038
# Epoch 25, Loss: 0.5448585152626038, Val Loss: 0.5212429761886597
# end of epoch.
# start of epoch 26
# Training loss (for one batch) at step 0: 0.46926426887512207
# Epoch 26, Loss: 0.46926426887512207, Val Loss: 0.4053484797477722
# end of epoch.
# start of epoch 27
# Training loss (for one batch) at step 0: 0.5581909418106079
# Epoch 27, Loss: 0.5581909418106079, Val Loss: 0.6275267004966736
# end of epoch.
# start of epoch 28
# Training loss (for one batch) at step 0: 0.4528725743293762
# Epoch 28, Loss: 0.4528725743293762, Val Loss: 0.4589780867099762
# end of epoch.
# start of epoch 29
# Training loss (for one batch) at step 0: 0.4924532175064087
# Epoch 29, Loss: 0.4924532175064087, Val Loss: 0.44716712832450867
# end of epoch.
# start of epoch 30
# Training loss (for one batch) at step 0: 0.5345035195350647
# Epoch 30, Loss: 0.5345035195350647, Val Loss: 0.5588847994804382
# end of epoch.
# start of epoch 31
# Training loss (for one batch) at step 0: 0.5585817694664001
# Epoch 31, Loss: 0.5585817694664001, Val Loss: 0.42214488983154297
# end of epoch.
# start of epoch 32
# Training loss (for one batch) at step 0: 0.5348128080368042
# Epoch 32, Loss: 0.5348128080368042, Val Loss: 0.45295700430870056
# end of epoch.
# start of epoch 33
# Training loss (for one batch) at step 0: 0.4979481101036072
# Epoch 33, Loss: 0.4979481101036072, Val Loss: 0.48987680673599243
# end of epoch.
# start of epoch 34
# Training loss (for one batch) at step 0: 0.46659037470817566
# Epoch 34, Loss: 0.46659037470817566, Val Loss: 0.5306487083435059
# end of epoch.
# start of epoch 35
# Training loss (for one batch) at step 0: 0.5684027075767517
# Epoch 35, Loss: 0.5684027075767517, Val Loss: 0.5112037062644958
# end of epoch.
# start of epoch 36
# Training loss (for one batch) at step 0: 0.4494321048259735
# Epoch 36, Loss: 0.4494321048259735, Val Loss: 0.5047738552093506
# end of epoch.
# start of epoch 37
# Training loss (for one batch) at step 0: 0.5226185321807861
# Epoch 37, Loss: 0.5226185321807861, Val Loss: 0.6030565500259399
# end of epoch.
# start of epoch 38
# Training loss (for one batch) at step 0: 0.49628302454948425
# Epoch 38, Loss: 0.49628302454948425, Val Loss: 0.45993855595588684
# end of epoch.
# start of epoch 39
# Training loss (for one batch) at step 0: 0.4434162974357605
# Epoch 39, Loss: 0.4434162974357605, Val Loss: 0.5092592835426331
# end of epoch.
# start of epoch 40
# Training loss (for one batch) at step 0: 0.3777603805065155
# Epoch 40, Loss: 0.3777603805065155, Val Loss: 0.47354939579963684
# end of epoch.
# start of epoch 41
# Training loss (for one batch) at step 0: 0.4478451609611511
# Epoch 41, Loss: 0.4478451609611511, Val Loss: 0.471333771944046
# end of epoch.
# start of epoch 42
# Training loss (for one batch) at step 0: 0.5097488164901733
# Epoch 42, Loss: 0.5097488164901733, Val Loss: 0.5488102436065674
# end of epoch.
# start of epoch 43
# Training loss (for one batch) at step 0: 0.48784905672073364
# Epoch 43, Loss: 0.48784905672073364, Val Loss: 0.41748014092445374
# end of epoch.
# start of epoch 44
# Training loss (for one batch) at step 0: 0.5014104247093201
# Epoch 44, Loss: 0.5014104247093201, Val Loss: 0.40304163098335266
# end of epoch.
# start of epoch 45
# Training loss (for one batch) at step 0: 0.48351284861564636
# Epoch 45, Loss: 0.48351284861564636, Val Loss: 0.3832744061946869
# end of epoch.
# start of epoch 46
# Training loss (for one batch) at step 0: 0.44040513038635254
# Epoch 46, Loss: 0.44040513038635254, Val Loss: 0.5227104425430298
# end of epoch.
# start of epoch 47
# Training loss (for one batch) at step 0: 0.41919374465942383
# Epoch 47, Loss: 0.41919374465942383, Val Loss: 0.5227857232093811
# end of epoch.
# start of epoch 48
# Training loss (for one batch) at step 0: 0.5235023498535156
# Epoch 48, Loss: 0.5235023498535156, Val Loss: 0.462319552898407
# end of epoch.
# start of epoch 49
# Training loss (for one batch) at step 0: 0.46149158477783203
# Epoch 49, Loss: 0.46149158477783203, Val Loss: 0.49667879939079285
# end of epoch.
# start of epoch 50
# Training loss (for one batch) at step 0: 0.5629028081893921
# Epoch 50, Loss: 0.5629028081893921, Val Loss: 0.5331072211265564
# end of epoch.
# start of epoch 51
# Training loss (for one batch) at step 0: 0.534115195274353
# Epoch 51, Loss: 0.534115195274353, Val Loss: 0.5816246867179871
# end of epoch.
# start of epoch 52
# Training loss (for one batch) at step 0: 0.4495042860507965
# Epoch 52, Loss: 0.4495042860507965, Val Loss: 0.49368882179260254
# end of epoch.
# start of epoch 53
# Training loss (for one batch) at step 0: 0.5376396775245667
# Epoch 53, Loss: 0.5376396775245667, Val Loss: 0.5735130310058594
# end of epoch.
# start of epoch 54
# Training loss (for one batch) at step 0: 0.5175212025642395
# Epoch 54, Loss: 0.5175212025642395, Val Loss: 0.4603210389614105
# end of epoch.
# start of epoch 55
# Training loss (for one batch) at step 0: 0.4365273714065552
# Epoch 55, Loss: 0.4365273714065552, Val Loss: 0.5047029256820679
# end of epoch.
# start of epoch 56
# Training loss (for one batch) at step 0: 0.49578720331192017
# Epoch 56, Loss: 0.49578720331192017, Val Loss: 0.49616435170173645
# end of epoch.
# start of epoch 57
# Training loss (for one batch) at step 0: 0.5788593292236328
# Epoch 57, Loss: 0.5788593292236328, Val Loss: 0.5217395424842834
# end of epoch.
# start of epoch 58
# Training loss (for one batch) at step 0: 0.5333397388458252
# Epoch 58, Loss: 0.5333397388458252, Val Loss: 0.441923588514328
# end of epoch.
# start of epoch 59
# Training loss (for one batch) at step 0: 0.6100801825523376
# Epoch 59, Loss: 0.6100801825523376, Val Loss: 0.4499370753765106
# end of epoch.
# start of epoch 60
# Training loss (for one batch) at step 0: 0.4869993329048157
# Epoch 60, Loss: 0.4869993329048157, Val Loss: 0.39743033051490784
# end of epoch.
# start of epoch 61
# Training loss (for one batch) at step 0: 0.4871066212654114
# Epoch 61, Loss: 0.4871066212654114, Val Loss: 0.5193631052970886
# end of epoch.
# start of epoch 62
# Training loss (for one batch) at step 0: 0.4695917069911957
# Epoch 62, Loss: 0.4695917069911957, Val Loss: 0.5544487833976746
# end of epoch.
# start of epoch 63
# Training loss (for one batch) at step 0: 0.5715793371200562
# Epoch 63, Loss: 0.5715793371200562, Val Loss: 0.5166196227073669
# end of epoch.
# start of epoch 64
# Training loss (for one batch) at step 0: 0.42044931650161743
# Epoch 64, Loss: 0.42044931650161743, Val Loss: 0.4341941177845001
# end of epoch.
# start of epoch 65
# Training loss (for one batch) at step 0: 0.5327854156494141
# Epoch 65, Loss: 0.5327854156494141, Val Loss: 0.4029656946659088
# end of epoch.
# start of epoch 66
# Training loss (for one batch) at step 0: 0.4169391691684723
# Epoch 66, Loss: 0.4169391691684723, Val Loss: 0.4700267016887665
# end of epoch.
# start of epoch 67
# Training loss (for one batch) at step 0: 0.5168440937995911
# Epoch 67, Loss: 0.5168440937995911, Val Loss: 0.484963595867157
# end of epoch.
# start of epoch 68
# Training loss (for one batch) at step 0: 0.4543379247188568
# Epoch 68, Loss: 0.4543379247188568, Val Loss: 0.4503229558467865
# end of epoch.
# start of epoch 69
# Training loss (for one batch) at step 0: 0.5251112580299377
# Epoch 69, Loss: 0.5251112580299377, Val Loss: 0.5173981785774231
# end of epoch.
# start of epoch 70
# Training loss (for one batch) at step 0: 0.49964240193367004
# Epoch 70, Loss: 0.49964240193367004, Val Loss: 0.4916415214538574
# end of epoch.
# start of epoch 71
# Training loss (for one batch) at step 0: 0.4303372800350189
# Epoch 71, Loss: 0.4303372800350189, Val Loss: 0.4282166659832001
# end of epoch.
# start of epoch 72
# Training loss (for one batch) at step 0: 0.47215619683265686
# Epoch 72, Loss: 0.47215619683265686, Val Loss: 0.3849458694458008
# end of epoch.
# start of epoch 73
# Training loss (for one batch) at step 0: 0.4929790198802948
# Epoch 73, Loss: 0.4929790198802948, Val Loss: 0.45234477519989014
# end of epoch.
# start of epoch 74
# Training loss (for one batch) at step 0: 0.4657623767852783
# Epoch 74, Loss: 0.4657623767852783, Val Loss: 0.6021280884742737
# end of epoch.
# start of epoch 75
# Training loss (for one batch) at step 0: 0.5696142911911011
# Epoch 75, Loss: 0.5696142911911011, Val Loss: 0.5564284324645996
# end of epoch.
# start of epoch 76
# Training loss (for one batch) at step 0: 0.38057756423950195
# Epoch 76, Loss: 0.38057756423950195, Val Loss: 0.3792001008987427
# end of epoch.
# start of epoch 77
# Training loss (for one batch) at step 0: 0.41762447357177734
# Epoch 77, Loss: 0.41762447357177734, Val Loss: 0.5070562958717346
# end of epoch.
# start of epoch 78
# Training loss (for one batch) at step 0: 0.5106577277183533
# Epoch 78, Loss: 0.5106577277183533, Val Loss: 0.5832944512367249
# end of epoch.
# start of epoch 79
# Training loss (for one batch) at step 0: 0.4994036853313446
# Epoch 79, Loss: 0.4994036853313446, Val Loss: 0.520304799079895
# end of epoch.
# start of epoch 80
# Training loss (for one batch) at step 0: 0.49511948227882385
# Epoch 80, Loss: 0.49511948227882385, Val Loss: 0.45607468485832214
# end of epoch.
# start of epoch 81
# Training loss (for one batch) at step 0: 0.5995929837226868
# Epoch 81, Loss: 0.5995929837226868, Val Loss: 0.5039781928062439
# end of epoch.
# start of epoch 82
# Training loss (for one batch) at step 0: 0.48451781272888184
# Epoch 82, Loss: 0.48451781272888184, Val Loss: 0.48139461874961853
# end of epoch.
# start of epoch 83
# Training loss (for one batch) at step 0: 0.5128088593482971
# Epoch 83, Loss: 0.5128088593482971, Val Loss: 0.4949965178966522
# end of epoch.
# start of epoch 84
# Training loss (for one batch) at step 0: 0.48763787746429443
# Epoch 84, Loss: 0.48763787746429443, Val Loss: 0.4480126202106476
# end of epoch.
# start of epoch 85
# Training loss (for one batch) at step 0: 0.5040716528892517
# Epoch 85, Loss: 0.5040716528892517, Val Loss: 0.5348941087722778
# end of epoch.
# start of epoch 86
# Training loss (for one batch) at step 0: 0.5668767094612122
# Epoch 86, Loss: 0.5668767094612122, Val Loss: 0.5584952235221863
# end of epoch.
# start of epoch 87
# Training loss (for one batch) at step 0: 0.4569075405597687
# Epoch 87, Loss: 0.4569075405597687, Val Loss: 0.5204274654388428
# end of epoch.
# start of epoch 88
# Training loss (for one batch) at step 0: 0.4806520938873291
# Epoch 88, Loss: 0.4806520938873291, Val Loss: 0.5166271924972534
# end of epoch.
# start of epoch 89
# Training loss (for one batch) at step 0: 0.4742477536201477
# Epoch 89, Loss: 0.4742477536201477, Val Loss: 0.4986409544944763
# end of epoch.
# start of epoch 90
# Training loss (for one batch) at step 0: 0.42378249764442444
# Epoch 90, Loss: 0.42378249764442444, Val Loss: 0.46411678194999695
# end of epoch.
# start of epoch 91
# Training loss (for one batch) at step 0: 0.5809309482574463
# Epoch 91, Loss: 0.5809309482574463, Val Loss: 0.40761929750442505
# end of epoch.
# start of epoch 92
# Training loss (for one batch) at step 0: 0.4266098737716675
# Epoch 92, Loss: 0.4266098737716675, Val Loss: 0.508072555065155
# end of epoch.
# start of epoch 93
# Training loss (for one batch) at step 0: 0.505592405796051
# Epoch 93, Loss: 0.505592405796051, Val Loss: 0.4354431629180908
# end of epoch.
# start of epoch 94
# Training loss (for one batch) at step 0: 0.40851113200187683
# Epoch 94, Loss: 0.40851113200187683, Val Loss: 0.5283469557762146
# end of epoch.
# start of epoch 95
# Training loss (for one batch) at step 0: 0.5226619839668274
# Epoch 95, Loss: 0.5226619839668274, Val Loss: 0.4299934208393097
# end of epoch.
# start of epoch 96
# Training loss (for one batch) at step 0: 0.4515830874443054
# Epoch 96, Loss: 0.4515830874443054, Val Loss: 0.5339803695678711
# end of epoch.
# start of epoch 97
# Training loss (for one batch) at step 0: 0.3900001347064972
# Epoch 97, Loss: 0.3900001347064972, Val Loss: 0.49187108874320984
# end of epoch.
# start of epoch 98
# Training loss (for one batch) at step 0: 0.42995205521583557
# Epoch 98, Loss: 0.42995205521583557, Val Loss: 0.5060190558433533
# end of epoch.
# start of epoch 99
# Training loss (for one batch) at step 0: 0.4651976227760315
# Epoch 99, Loss: 0.4651976227760315, Val Loss: 0.407349556684494
# end of epoch.
# start of epoch 100
# Training loss (for one batch) at step 0: 0.4394179582595825
# Epoch 100, Loss: 0.4394179582595825, Val Loss: 0.4544469118118286
# end of epoch.
# start of epoch 101
# Training loss (for one batch) at step 0: 0.5319070816040039
# Epoch 101, Loss: 0.5319070816040039, Val Loss: 0.6168369650840759
# end of epoch.
# start of epoch 102
# Training loss (for one batch) at step 0: 0.4537810683250427
# Epoch 102, Loss: 0.4537810683250427, Val Loss: 0.5498307347297668
# end of epoch.
# start of epoch 103
# Training loss (for one batch) at step 0: 0.48460960388183594
# Epoch 103, Loss: 0.48460960388183594, Val Loss: 0.5181766152381897
# end of epoch.
# start of epoch 104
# Training loss (for one batch) at step 0: 0.533250093460083
# Epoch 104, Loss: 0.533250093460083, Val Loss: 0.42134690284729004
# end of epoch.
# start of epoch 105
# Training loss (for one batch) at step 0: 0.465449720621109
# Epoch 105, Loss: 0.465449720621109, Val Loss: 0.4739561378955841
# end of epoch.
# start of epoch 106
# Training loss (for one batch) at step 0: 0.45727235078811646
# Epoch 106, Loss: 0.45727235078811646, Val Loss: 0.5149345993995667
# end of epoch.
# start of epoch 107
# Training loss (for one batch) at step 0: 0.4776645600795746
# Epoch 107, Loss: 0.4776645600795746, Val Loss: 0.46766743063926697
# end of epoch.
# start of epoch 108
# Training loss (for one batch) at step 0: 0.5053183436393738
# Epoch 108, Loss: 0.5053183436393738, Val Loss: 0.5487709045410156
# end of epoch.
# start of epoch 109
# Training loss (for one batch) at step 0: 0.5564815402030945
# Epoch 109, Loss: 0.5564815402030945, Val Loss: 0.49246034026145935
# end of epoch.
# start of epoch 110
# Training loss (for one batch) at step 0: 0.4008312523365021
# Epoch 110, Loss: 0.4008312523365021, Val Loss: 0.5056240558624268
# end of epoch.
# start of epoch 111
# Training loss (for one batch) at step 0: 0.4914112091064453
# Epoch 111, Loss: 0.4914112091064453, Val Loss: 0.541645348072052
# end of epoch.
# start of epoch 112
# Training loss (for one batch) at step 0: 0.5158113241195679
# Epoch 112, Loss: 0.5158113241195679, Val Loss: 0.46980059146881104
# end of epoch.
# start of epoch 113
# Training loss (for one batch) at step 0: 0.48822107911109924
# Epoch 113, Loss: 0.48822107911109924, Val Loss: 0.5137779712677002
# end of epoch.
# start of epoch 114
# Training loss (for one batch) at step 0: 0.48247307538986206
# Epoch 114, Loss: 0.48247307538986206, Val Loss: 0.48160165548324585
# end of epoch.
# start of epoch 115
# Training loss (for one batch) at step 0: 0.4831385612487793
# Epoch 115, Loss: 0.4831385612487793, Val Loss: 0.5090319514274597
# end of epoch.
# start of epoch 116
# Training loss (for one batch) at step 0: 0.40506675839424133
# Epoch 116, Loss: 0.40506675839424133, Val Loss: 0.4787445664405823
# end of epoch.
# start of epoch 117
# Training loss (for one batch) at step 0: 0.584339439868927
# Epoch 117, Loss: 0.584339439868927, Val Loss: 0.48781874775886536
# end of epoch.
# start of epoch 118
# Training loss (for one batch) at step 0: 0.4572327136993408
# Epoch 118, Loss: 0.4572327136993408, Val Loss: 0.5360828638076782
# end of epoch.
# start of epoch 119
# Training loss (for one batch) at step 0: 0.5050507187843323
# Epoch 119, Loss: 0.5050507187843323, Val Loss: 0.4864485263824463
# end of epoch.
# start of epoch 120
# Training loss (for one batch) at step 0: 0.4365079998970032
# Epoch 120, Loss: 0.4365079998970032, Val Loss: 0.5394227504730225
# end of epoch.
# start of epoch 121
# Training loss (for one batch) at step 0: 0.48060357570648193
# Epoch 121, Loss: 0.48060357570648193, Val Loss: 0.5180236101150513
# end of epoch.
# start of epoch 122
# Training loss (for one batch) at step 0: 0.4091159403324127
# Epoch 122, Loss: 0.4091159403324127, Val Loss: 0.4834076464176178
# end of epoch.
# start of epoch 123
# Training loss (for one batch) at step 0: 0.47883978486061096
# Epoch 123, Loss: 0.47883978486061096, Val Loss: 0.4388722777366638
# end of epoch.
# start of epoch 124
# Training loss (for one batch) at step 0: 0.5418046116828918
# Epoch 124, Loss: 0.5418046116828918, Val Loss: 0.4606247842311859
# end of epoch.
# start of epoch 125
# Training loss (for one batch) at step 0: 0.5274366736412048
# Epoch 125, Loss: 0.5274366736412048, Val Loss: 0.4523438811302185
# end of epoch.
# start of epoch 126
# Training loss (for one batch) at step 0: 0.4248325824737549
# Epoch 126, Loss: 0.4248325824737549, Val Loss: 0.5289387106895447
# end of epoch.
# start of epoch 127
# Training loss (for one batch) at step 0: 0.406781941652298
# Epoch 127, Loss: 0.406781941652298, Val Loss: 0.47489723563194275
# end of epoch.
# start of epoch 128
# Training loss (for one batch) at step 0: 0.43527737259864807
# Epoch 128, Loss: 0.43527737259864807, Val Loss: 0.5025712847709656
# end of epoch.
# start of epoch 129
# Training loss (for one batch) at step 0: 0.5403357744216919
# Epoch 129, Loss: 0.5403357744216919, Val Loss: 0.49418386816978455
# end of epoch.
# start of epoch 130
# Training loss (for one batch) at step 0: 0.47166430950164795
# Epoch 130, Loss: 0.47166430950164795, Val Loss: 0.5344535708427429
# end of epoch.
# start of epoch 131
# Training loss (for one batch) at step 0: 0.54832524061203
# Epoch 131, Loss: 0.54832524061203, Val Loss: 0.4854559898376465
# end of epoch.
# start of epoch 132
# Training loss (for one batch) at step 0: 0.510915219783783
# Epoch 132, Loss: 0.510915219783783, Val Loss: 0.5876187682151794
# end of epoch.
# start of epoch 133
# Training loss (for one batch) at step 0: 0.4813378155231476
# Epoch 133, Loss: 0.4813378155231476, Val Loss: 0.5646204352378845
# end of epoch.
# start of epoch 134
# Training loss (for one batch) at step 0: 0.4721604585647583
# Epoch 134, Loss: 0.4721604585647583, Val Loss: 0.48951050639152527
# end of epoch.
# start of epoch 135
# Training loss (for one batch) at step 0: 0.5430070757865906
# Epoch 135, Loss: 0.5430070757865906, Val Loss: 0.488469660282135
# end of epoch.
# start of epoch 136
# Training loss (for one batch) at step 0: 0.47422343492507935
# Epoch 136, Loss: 0.47422343492507935, Val Loss: 0.5649393796920776
# end of epoch.
# start of epoch 137
# Training loss (for one batch) at step 0: 0.5133339762687683
# Epoch 137, Loss: 0.5133339762687683, Val Loss: 0.5336148142814636
# end of epoch.
# start of epoch 138
# Training loss (for one batch) at step 0: 0.48599186539649963
# Epoch 138, Loss: 0.48599186539649963, Val Loss: 0.42617785930633545
# end of epoch.
# start of epoch 139
# Training loss (for one batch) at step 0: 0.4190852642059326
# Epoch 139, Loss: 0.4190852642059326, Val Loss: 0.5225685834884644
# end of epoch.
# start of epoch 140
# Training loss (for one batch) at step 0: 0.5138601064682007
# Epoch 140, Loss: 0.5138601064682007, Val Loss: 0.5966269373893738
# end of epoch.
# start of epoch 141
# Training loss (for one batch) at step 0: 0.4887058734893799
# Epoch 141, Loss: 0.4887058734893799, Val Loss: 0.47009503841400146
# end of epoch.
# start of epoch 142
# Training loss (for one batch) at step 0: 0.49480026960372925
# Epoch 142, Loss: 0.49480026960372925, Val Loss: 0.48326483368873596
# end of epoch.
# start of epoch 143
# Training loss (for one batch) at step 0: 0.46037837862968445
# Epoch 143, Loss: 0.46037837862968445, Val Loss: 0.5493097305297852
# end of epoch.
# start of epoch 144
# Training loss (for one batch) at step 0: 0.5294685363769531
# Epoch 144, Loss: 0.5294685363769531, Val Loss: 0.5063843727111816
# end of epoch.
# start of epoch 145
# Training loss (for one batch) at step 0: 0.5662927031517029
# Epoch 145, Loss: 0.5662927031517029, Val Loss: 0.4009915888309479
# end of epoch.
# start of epoch 146
# Training loss (for one batch) at step 0: 0.4745416045188904
# Epoch 146, Loss: 0.4745416045188904, Val Loss: 0.47891661524772644
# end of epoch.
# start of epoch 147
# Training loss (for one batch) at step 0: 0.5276932716369629
# Epoch 147, Loss: 0.5276932716369629, Val Loss: 0.5391061902046204
# end of epoch.
# start of epoch 148
# Training loss (for one batch) at step 0: 0.5708063244819641
# Epoch 148, Loss: 0.5708063244819641, Val Loss: 0.4237864911556244
# end of epoch.
# start of epoch 149
# Training loss (for one batch) at step 0: 0.48485782742500305
# Epoch 149, Loss: 0.48485782742500305, Val Loss: 0.5176178216934204
# end of epoch.
# start of epoch 150
# Training loss (for one batch) at step 0: 0.5319273471832275
# Epoch 150, Loss: 0.5319273471832275, Val Loss: 0.4956948161125183
# end of epoch.
# start of epoch 151
# Training loss (for one batch) at step 0: 0.5099020004272461
# Epoch 151, Loss: 0.5099020004272461, Val Loss: 0.5550918579101562
# end of epoch.
# start of epoch 152
# Training loss (for one batch) at step 0: 0.39060404896736145
# Epoch 152, Loss: 0.39060404896736145, Val Loss: 0.44361498951911926
# end of epoch.
# start of epoch 153
# Training loss (for one batch) at step 0: 0.5295597314834595
# Epoch 153, Loss: 0.5295597314834595, Val Loss: 0.47458121180534363
# end of epoch.
# start of epoch 154
# Training loss (for one batch) at step 0: 0.5114500522613525
# Epoch 154, Loss: 0.5114500522613525, Val Loss: 0.5133302807807922
# end of epoch.
# start of epoch 155
# Training loss (for one batch) at step 0: 0.4444078803062439
# Epoch 155, Loss: 0.4444078803062439, Val Loss: 0.36209458112716675
# end of epoch.
# start of epoch 156
# Training loss (for one batch) at step 0: 0.598200261592865
# Epoch 156, Loss: 0.598200261592865, Val Loss: 0.4626007676124573
# end of epoch.
# start of epoch 157
# Training loss (for one batch) at step 0: 0.5518804788589478
# Epoch 157, Loss: 0.5518804788589478, Val Loss: 0.44084495306015015
# end of epoch.
# start of epoch 158
# Training loss (for one batch) at step 0: 0.5641905665397644
# Epoch 158, Loss: 0.5641905665397644, Val Loss: 0.56502765417099
# end of epoch.
# start of epoch 159
# Training loss (for one batch) at step 0: 0.550068199634552
# Epoch 159, Loss: 0.550068199634552, Val Loss: 0.5065479278564453
# end of epoch.
# start of epoch 160
# Training loss (for one batch) at step 0: 0.4971342086791992
# Epoch 160, Loss: 0.4971342086791992, Val Loss: 0.4791986644268036
# end of epoch.
# start of epoch 161
# Training loss (for one batch) at step 0: 0.5150797963142395
# Epoch 161, Loss: 0.5150797963142395, Val Loss: 0.34190645813941956
# end of epoch.
# start of epoch 162
# Training loss (for one batch) at step 0: 0.4423571527004242
# Epoch 162, Loss: 0.4423571527004242, Val Loss: 0.534000039100647
# end of epoch.
# start of epoch 163
# Training loss (for one batch) at step 0: 0.575284481048584
# Epoch 163, Loss: 0.575284481048584, Val Loss: 0.5492818355560303
# end of epoch.
# start of epoch 164
# Training loss (for one batch) at step 0: 0.4365158975124359
# Epoch 164, Loss: 0.4365158975124359, Val Loss: 0.4219766855239868
# end of epoch.
# start of epoch 165
# Training loss (for one batch) at step 0: 0.475442111492157
# Epoch 165, Loss: 0.475442111492157, Val Loss: 0.4665026366710663
# end of epoch.
# start of epoch 166
# Training loss (for one batch) at step 0: 0.45014408230781555
# Epoch 166, Loss: 0.45014408230781555, Val Loss: 0.49758976697921753
# end of epoch.
# start of epoch 167
# Training loss (for one batch) at step 0: 0.464907705783844
# Epoch 167, Loss: 0.464907705783844, Val Loss: 0.5379075407981873
# end of epoch.
# start of epoch 168
# Training loss (for one batch) at step 0: 0.43222740292549133
# Epoch 168, Loss: 0.43222740292549133, Val Loss: 0.40970349311828613
# end of epoch.
# start of epoch 169
# Training loss (for one batch) at step 0: 0.5201084613800049
# Epoch 169, Loss: 0.5201084613800049, Val Loss: 0.4826388955116272
# end of epoch.
# start of epoch 170
# Training loss (for one batch) at step 0: 0.5415351390838623
# Epoch 170, Loss: 0.5415351390838623, Val Loss: 0.500620424747467
# end of epoch.
# start of epoch 171
# Training loss (for one batch) at step 0: 0.4480495750904083
# Epoch 171, Loss: 0.4480495750904083, Val Loss: 0.548475980758667
# end of epoch.
# start of epoch 172
# Training loss (for one batch) at step 0: 0.506658136844635
# Epoch 172, Loss: 0.506658136844635, Val Loss: 0.4713711142539978
# end of epoch.
# start of epoch 173
# Training loss (for one batch) at step 0: 0.4496987760066986
# Epoch 173, Loss: 0.4496987760066986, Val Loss: 0.45060673356056213
# end of epoch.
# start of epoch 174
# Training loss (for one batch) at step 0: 0.488097220659256
# Epoch 174, Loss: 0.488097220659256, Val Loss: 0.41965264081954956
# end of epoch.
# start of epoch 175
# Training loss (for one batch) at step 0: 0.48105141520500183
# Epoch 175, Loss: 0.48105141520500183, Val Loss: 0.5569593906402588
# end of epoch.
# start of epoch 176
# Training loss (for one batch) at step 0: 0.49711012840270996
# Epoch 176, Loss: 0.49711012840270996, Val Loss: 0.4502781927585602
# end of epoch.
# start of epoch 177
# Training loss (for one batch) at step 0: 0.43336576223373413
# Epoch 177, Loss: 0.43336576223373413, Val Loss: 0.5136339664459229
# end of epoch.
# start of epoch 178
# Training loss (for one batch) at step 0: 0.4553094506263733
# Epoch 178, Loss: 0.4553094506263733, Val Loss: 0.5372822284698486
# end of epoch.
# start of epoch 179
# Training loss (for one batch) at step 0: 0.5029827952384949
# Epoch 179, Loss: 0.5029827952384949, Val Loss: 0.5567241907119751
# end of epoch.
# start of epoch 180
# Training loss (for one batch) at step 0: 0.47556203603744507
# Epoch 180, Loss: 0.47556203603744507, Val Loss: 0.5500853061676025
# end of epoch.
# start of epoch 181
# Training loss (for one batch) at step 0: 0.48630279302597046
# Epoch 181, Loss: 0.48630279302597046, Val Loss: 0.5249858498573303
# end of epoch.
# start of epoch 182
# Training loss (for one batch) at step 0: 0.41049250960350037
# Epoch 182, Loss: 0.41049250960350037, Val Loss: 0.4187965989112854
# end of epoch.
# start of epoch 183
# Training loss (for one batch) at step 0: 0.4448770582675934
# Epoch 183, Loss: 0.4448770582675934, Val Loss: 0.36608999967575073
# end of epoch.
# start of epoch 184
# Training loss (for one batch) at step 0: 0.4745621085166931
# Epoch 184, Loss: 0.4745621085166931, Val Loss: 0.3921186327934265
# end of epoch.
# start of epoch 185
# Training loss (for one batch) at step 0: 0.5085623860359192
# Epoch 185, Loss: 0.5085623860359192, Val Loss: 0.47621119022369385
# end of epoch.
# start of epoch 186
# Training loss (for one batch) at step 0: 0.5829017162322998
# Epoch 186, Loss: 0.5829017162322998, Val Loss: 0.4623129069805145
# end of epoch.
# start of epoch 187
# Training loss (for one batch) at step 0: 0.5121700763702393
# Epoch 187, Loss: 0.5121700763702393, Val Loss: 0.3349688649177551
# end of epoch.
# start of epoch 188
# Training loss (for one batch) at step 0: 0.6260310411453247
# Epoch 188, Loss: 0.6260310411453247, Val Loss: 0.4431144595146179
# end of epoch.
# start of epoch 189
# Training loss (for one batch) at step 0: 0.4758102297782898
# Epoch 189, Loss: 0.4758102297782898, Val Loss: 0.4927981495857239
# end of epoch.
# start of epoch 190
# Training loss (for one batch) at step 0: 0.5349183082580566
# Epoch 190, Loss: 0.5349183082580566, Val Loss: 0.47006919980049133
# end of epoch.
# start of epoch 191
# Training loss (for one batch) at step 0: 0.5066890120506287
# Epoch 191, Loss: 0.5066890120506287, Val Loss: 0.4682653844356537
# end of epoch.
# start of epoch 192
# Training loss (for one batch) at step 0: 0.4909228980541229
# Epoch 192, Loss: 0.4909228980541229, Val Loss: 0.5307431221008301
# end of epoch.
# start of epoch 193
# Training loss (for one batch) at step 0: 0.4706691801548004
# Epoch 193, Loss: 0.4706691801548004, Val Loss: 0.4497518837451935
# end of epoch.
# start of epoch 194
# Training loss (for one batch) at step 0: 0.5056122541427612
# Epoch 194, Loss: 0.5056122541427612, Val Loss: 0.4958673119544983
# end of epoch.
# start of epoch 195
# Training loss (for one batch) at step 0: 0.36980748176574707
# Epoch 195, Loss: 0.36980748176574707, Val Loss: 0.5337918400764465
# end of epoch.
# start of epoch 196
# Training loss (for one batch) at step 0: 0.5636746883392334
# Epoch 196, Loss: 0.5636746883392334, Val Loss: 0.5280073881149292
# end of epoch.
# start of epoch 197
# Training loss (for one batch) at step 0: 0.46405503153800964
# Epoch 197, Loss: 0.46405503153800964, Val Loss: 0.5040690898895264
# end of epoch.
# start of epoch 198
# Training loss (for one batch) at step 0: 0.5399280190467834
# Epoch 198, Loss: 0.5399280190467834, Val Loss: 0.49906209111213684
# end of epoch.
# start of epoch 199
# Training loss (for one batch) at step 0: 0.5175328850746155
# Epoch 199, Loss: 0.5175328850746155, Val Loss: 0.49372926354408264
# end of epoch.
# start of epoch 200
# Training loss (for one batch) at step 0: 0.40980449318885803
# Epoch 200, Loss: 0.40980449318885803, Val Loss: 0.48804882168769836
# end of epoch.
# Checkpoint directory :  checkpoints/CNNgeo/200507_regressor_filter_size_up
# Tensorboard log directory :  logs/CNNgeo/200507_regressor_filter_size_up

# %%
model.summary()
# Out:
# Model: "cnn_geo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature__extractor (Feature_ multiple                  1735488
# _________________________________________________________________
# correlation_network (Correla multiple                  0
# _________________________________________________________________
# spatial_transformer_regresso multiple                  875250
# =================================================================
# Total params: 2,610,738
# Trainable params: 2,610,546
# Non-trainable params: 192
# _________________________________________________________________

# %% [markdown]
# # 3. Debug

# %%
datasets = load_data(['train'], config)
ds = datasets['train'].batch(1)
# Out:
# train dataset amount : 1

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
#image_B_hat = np.ones([1, 64, 64, 3])
pred, score = model(image_A, image_B)

# %%
print("parameter shape", pred.shape)
print("score shape", score.shape)
print(image_A.shape)
# Out:
# parameter shape (1, 9, 2)
# score shape (1, 16, 16, 16, 16)
# (1, 64, 64, 3)

# %% [markdown]
# ## 3.1. 입력 영상에 따른 모델 추정 확인

# %% [markdown]
# ### case 1) 임의의 기하관계를 갖는 영상 쌍 (image A, image B)

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred1 = pred.copy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.03100619 -0.18044543]
#   [ 0.19932203  0.00098267]
#   [ 0.15574227 -0.1491972 ]
#   [ 0.09301758 -0.14225212]
#   [ 0.0404202   0.05568657]
#   [ 0.13513108  0.07313418]
#   [ 0.06055555  0.0873796 ]
#   [-0.09374218 -0.16627626]
#   [ 0.0194058   0.03699536]]] and
#  pred : [[[ 7.5467816e-03 -2.2332161e-03]
#   [ 6.5952465e-03  9.3992660e-03]
#   [ 8.1838733e-03 -4.9727707e-05]
#   [-3.3819394e-03  7.1898173e-03]
#   [ 6.2676761e-03 -6.0287805e-04]
#   [-3.3628233e-03  6.2667844e-03]
#   [-2.4443362e-03  8.1980070e-03]
#   [ 4.4058805e-04 -4.2693219e-03]
#   [ 6.0640241e-04  1.2380278e-02]]]
# loss : [0.11020298]

# %% [markdown]
# ### case 2) 임의의 다른 기하관계를 갖는 영상 쌍 (image A, image B)

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred2 = pred.copy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.12675405  0.04527674]
#   [ 0.09534893 -0.1906054 ]
#   [ 0.0921567   0.1447969 ]
#   [-0.16727142  0.14908014]
#   [ 0.00156069 -0.08923822]
#   [ 0.08564263  0.16123724]
#   [ 0.09016037  0.09052096]
#   [-0.17935424 -0.16246934]
#   [ 0.07558189  0.13221745]]] and
#  pred : [[[ 6.96604047e-03 -2.14882009e-03]
#   [ 3.38341133e-03  1.15210265e-02]
#   [ 6.50892779e-03  1.08389999e-03]
#   [-4.50181728e-03  9.20241512e-03]
#   [ 4.81328182e-03  2.82136025e-05]
#   [-2.31498806e-03  4.47133835e-03]
#   [-1.02382146e-04  6.10741507e-03]
#   [-1.23623898e-03 -5.19714877e-03]
#   [ 2.64657824e-03  1.21645490e-02]]]
# loss : [0.13762434]

# %% [markdown]
# ### case 3) Image A와 연관 없는 image B(백색 사진)의 영상 쌍

# %%
image_B = np.ones([1, 64, 64, 3])
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred3 = pred.copy()
# Out:
# WARNING:tensorflow:Layer feature__extractor is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.12675405  0.04527674]
#   [ 0.09534893 -0.1906054 ]
#   [ 0.0921567   0.1447969 ]
#   [-0.16727142  0.14908014]
#   [ 0.00156069 -0.08923822]
#   [ 0.08564263  0.16123724]
#   [ 0.09016037  0.09052096]
#   [-0.17935424 -0.16246934]
#   [ 0.07558189  0.13221745]]] and
#  pred : [[[ 0.00743404 -0.00098018]
#   [ 0.00012429  0.00868114]
#   [ 0.00549515 -0.00237109]
#   [-0.00183765  0.00807347]
#   [ 0.00299769  0.00120734]
#   [-0.00220964  0.00293937]
#   [-0.00156404  0.00517634]
#   [-0.00166786 -0.0060398 ]
#   [ 0.00501351  0.00838291]]]
# loss : [0.13918108]

# %%
print(pred1, "\n", pred2, "\n", pred3)
# Out:
# [[[ 7.5467816e-03 -2.2332161e-03]
#   [ 6.5952465e-03  9.3992660e-03]
#   [ 8.1838733e-03 -4.9727707e-05]
#   [-3.3819394e-03  7.1898173e-03]
#   [ 6.2676761e-03 -6.0287805e-04]
#   [-3.3628233e-03  6.2667844e-03]
#   [-2.4443362e-03  8.1980070e-03]
#   [ 4.4058805e-04 -4.2693219e-03]
#   [ 6.0640241e-04  1.2380278e-02]]]
#  [[[ 6.96604047e-03 -2.14882009e-03]
#   [ 3.38341133e-03  1.15210265e-02]
#   [ 6.50892779e-03  1.08389999e-03]
#   [-4.50181728e-03  9.20241512e-03]
#   [ 4.81328182e-03  2.82136025e-05]
#   [-2.31498806e-03  4.47133835e-03]
#   [-1.02382146e-04  6.10741507e-03]
#   [-1.23623898e-03 -5.19714877e-03]
#   [ 2.64657824e-03  1.21645490e-02]]]
#  [[[ 0.00743404 -0.00098018]
#   [ 0.00012429  0.00868114]
#   [ 0.00549515 -0.00237109]
#   [-0.00183765  0.00807347]
#   [ 0.00299769  0.00120734]
#   [-0.00220964  0.00293937]
#   [-0.00156404  0.00517634]
#   [-0.00166786 -0.0060398 ]
#   [ 0.00501351  0.00838291]]]

# %% [markdown]
# case 1)와 case 2)는 동일한 영상을 다른 기하관계를 사용하여 두 개의 영상쌍(image pair)을 만든 경우를 말한다. 모델이 정상적이라면 각 영상쌍의 기하관계를 추정할 수 있을 것이다. 그러나 두 영상쌍이 다른 기하관계를 갖음에도 동일한 모션파라미터를 추정하였다. case 3)에서는 전혀 연관 없는 영상을 image B로 사용하였다. image B는 어떤 특징 정보도 없는 백색 사진임에도 불구하고 모델은 case 1)과 case 2)에서와 같은 모션파라미터를 추정하였다.

# %%
model.summary()
# Out:
# Model: "cnn_geo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature__extractor (Feature_ multiple                  1735488
# _________________________________________________________________
# correlation_network (Correla multiple                  0
# _________________________________________________________________
# spatial_transformer_regresso multiple                  875250
# =================================================================
# Total params: 2,610,738
# Trainable params: 2,610,546
# Non-trainable params: 192
# _________________________________________________________________

# %% [markdown]
# ## 3.2 Correlation 분포에 따른 Regressor 예측

# %% [markdown]
# 3.1의 case 1, 2, 3에서 Regressor은 같은 모션파라미터를 예측했다. 명확한 이유를 파악하기 위해 입력 correlation(matching scores)를 제어하며 spatial parameter regressor의 출력을 분석했다.

# %%
x = np.zeros([1, 16, 16, 16, 16]) # all correlations are zero
y = model.layers[2](x)
print(y)
# Out:
# WARNING:tensorflow:Layer spatial_transformer_regressor is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# tf.Tensor(
# [[ 0.00634592  0.00063899  0.00029003  0.00631394  0.00320222 -0.00160296
#   -0.00256587  0.00750365  0.00218026  0.00165893 -0.00137142  0.00015265
#    0.0008345   0.00242014 -0.001849   -0.00621235  0.00509075  0.0076446 ]], shape=(1, 18), dtype=float32)

# %%
x = np.ones([1, 16, 16, 16, 16]) # all correlations are one
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[ 1.8514451  -1.9488013   2.0077896   0.980503    5.2474313  -3.3215067
#    0.8157524  -0.17510895  5.182543   -3.0244153  -1.3893834   7.5677013
#   -3.2870984   7.464047    1.9141004   3.0278761  -2.7832086   2.4061728 ]], shape=(1, 18), dtype=float32)

# %%
x = np.random.normal(loc=0.5, scale=0.0, size=[1, 16, 16, 16, 16])
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[ 0.92834526 -0.97443515  1.0040045   0.49498937  2.625592   -1.6611236
#    0.40654555 -0.08480907  2.5914962  -1.5113616  -0.6939933   3.7841785
#   -1.6423507   3.733076    0.9554677   1.5113188  -1.3876966   1.2068322 ]], shape=(1, 18), dtype=float32)

# %%
x = np.random.normal(loc=0.5, scale=0.3, size=[1, 16, 16, 16, 16])
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[ 0.9685453  -0.82678556  1.3471022   0.6510097   2.5824103  -1.4689473
#    0.5440779   0.09925523  2.657371   -1.601314   -0.6368603   3.9411464
#   -1.5576326   3.6391747   1.1790589   1.5034575  -1.3064967   1.0051819 ]], shape=(1, 18), dtype=float32)

# %% [markdown]
# 위 실험의 결과를 토대로 확인할 수 있는 것은 regressor의 출력은 입력 correlation의 크기가 아닌 편차에 따라 달라진다는 것이다. correlation의 분포의 표준편차를 변화시키며 출력의 변화 정도를 추정해주었다.

# %%
_range = np.linspace(0, 1.0, 50)
print(_range)
# Out:
# [0.         0.02040816 0.04081633 0.06122449 0.08163265 0.10204082
#  0.12244898 0.14285714 0.16326531 0.18367347 0.20408163 0.2244898
#  0.24489796 0.26530612 0.28571429 0.30612245 0.32653061 0.34693878
#  0.36734694 0.3877551  0.40816327 0.42857143 0.44897959 0.46938776
#  0.48979592 0.51020408 0.53061224 0.55102041 0.57142857 0.59183673
#  0.6122449  0.63265306 0.65306122 0.67346939 0.69387755 0.71428571
#  0.73469388 0.75510204 0.7755102  0.79591837 0.81632653 0.83673469
#  0.85714286 0.87755102 0.89795918 0.91836735 0.93877551 0.95918367
#  0.97959184 1.        ]

# %%
variations_via_std = []
variations_via_mean = []
for std in _range:
    variations = []
    for i in range(100):
        x = np.random.normal(loc=0.5, scale=std, size=[1, 16, 16, 16, 16])
        _y = model.layers[2](x)
        variations.append(_y)
    variations_via_std.append(np.sum(np.std(np.array(variations), axis = 0)))
    
for mean in _range:
    variations = []
    for i in range(100):
        x = np.random.normal(loc=mean, scale=0.1, size=[1, 16, 16, 16, 16])
        _y = model.layers[2](x)
        variations.append(_y)
    variations_via_mean.append(np.sum(np.std(np.array(variations), axis = 0)))

# %%
variations
# Out:
# [<tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[ 1.7604982 , -2.0594723 ,  1.9529518 ,  1.0269015 ,  5.1419644 ,
#          -3.3543172 ,  0.7944441 , -0.15525226,  5.2155275 , -3.0821025 ,
#          -1.4045485 ,  7.4899974 , -3.223249  ,  7.370831  ,  1.873654  ,
#           2.9063656 , -2.7338817 ,  2.324442  ]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[ 1.
]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[ 1.8420515 , -1.8969951 ,  2.0371656 ,  1.0742903 ,  5.2944093 ,
#          -3.3990633 ,  0.81880695, -0.17976554,  5.2156534 , -3.0945094 ,
#          -1.3378695 ,  7.577646  , -3.3395412 ,  7.4998565 ,  1.9544809 ,
#           3.1036823 , -2.7378721 ,  2.406989  ]], dtype=float32)>]

# %%
plt.ylabel("variations of motion parameters")
plt.xlabel("via sigma, mean. \n correlations are sampled from N(0.5, sigma), N(mean, 0.1)")
plt.plot(_range, variations_via_std, label='via sigma')
plt.plot(_range, variations_via_mean, label='via mean')
plt.legend()
plt.show()

# %% [markdown]
# 1. VGG16을 통한 correlations
# 2. 시각화 방식 개선
# 3. tentative penalty

# %% [markdown]
# ## b. 특징추출기의 정상 동작 검증

# %%
np.set_printoptions(formatter = {"float_kind" : lambda x : "{0:0.4f}".format(x)} )
#np.set_printoptions(formatter={'float_kind': lambda x: "{0:0.3f}".format(x)})

# %% [markdown]
# ### 동일 영상에 대한 correlation

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_A)

score = score.numpy()[0]
parameters = parameters[0]
image_A = image_A[0]
image_B = image_B[0]

print(score.shape, parameters.shape, image_A.shape)
# Out:
# (16, 16, 16, 16) (9, 2) (64, 64, 3)

# %%
def get_matching_grid_from_B(parameters, center_point):
    src_points = np.array([[0.0, 0.0], [0.5, 0.0], [1.0, 0.0],
                                   [0.0, 0.5], [0.5, 0.5], [1.0, 0.5],
                                   [0.0, 1.0], [0.5, 1.0], [1.0, 1.0]])

    dst_points = src_points +parameters

    theta = tps.tps_theta_from_points(src_points, dst_points, reduced=True)
    dshape = (64, 64)
    grid = tps.tps_grid(theta, dst_points, dshape)
    mapx, mapy = tps.tps_grid_to_remap(grid, (64, 64))
    points = np.concatenate([mapy[:,:,np.newaxis], mapx[:,:,np.newaxis]], axis=2)
    #print("points :", points)
    center_point = np.array(center_point)
    #print("grid center : ", center_point)
    center_point = center_point[np.newaxis, np.newaxis, :]
    distance = np.sum(np.power((points - center_point), 2), axis=2)
    #print("distance : ", distance)
    ri, ci = distance.argmin()//distance.shape[1], distance.argmin()%distance.shape[1]
    return (ri, ci)

# %%
def score_test(grid_coord, score, parameters, images, grid_shape=(16,16)):
    image_A, image_B = images
    score = score[grid_coord[0], grid_coord[1]]
    H, W, C = image_A.shape
    grid_size = H/grid_shape[0], W/grid_shape[1]

    start_pix_h = int(grid_size[0]*grid_coord[0])
    end_pix_h = int(grid_size[0]*(1+grid_coord[0]))
    start_pix_w = int(grid_size[1]*grid_coord[1])
    end_pix_w = int(grid_size[1]*(1+grid_coord[1]))
    
    drawn_grid_image_A = image_A.copy()
    drawn_grid_image_A[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)   
    
    expected_drawn_grid_image_B = image_B.copy()
    grid_center_A = (int(start_pix_h+grid_size[0]/2), int(start_pix_w+grid_size[1]/2))
    grid_center_B = get_matching_grid_from_B(parameters, grid_center_A)
    start_pix_h = int(grid_center_B[0] - grid_size[0]/2)
    start_pix_w = int(grid_center_B[1] - grid_size[1]/2)
    end_pix_h = int(grid_center_B[0] + grid_size[0]/2)
    end_pix_w = int(grid_center_B[1] + grid_size[1]/2)
    expected_drawn_grid_image_B[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)
    
    drawn_grid_image_B = image_B.copy()
    max_correlation_grid_index = score.argmax()//score.shape[1], score.argmax()%score.shape[1]
    start_pix_h = int(grid_size[0]*max_correlation_grid_index[0])
    end_pix_h = int(grid_size[0]*(1+max_correlation_grid_index[0]))
    start_pix_w = int(grid_size[1]*max_correlation_grid_index[1])
    end_pix_w = int(grid_size[1]*(1+max_correlation_grid_index[1]))

    drawn_grid_image_B[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)
    
    print("top 10 correlation values in descending : ", np.sort(score.flatten())[::-1][:10])
    print("standard deviation : {}".format(np.std(score)))
    return drawn_grid_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, score

# %%
def make_heatmap(patch_score):
    _min = patch_score.min()
    _max = patch_score.max()
    _range = _max - _min
    
    normalized_pathch_score = (patch_score - _min)/_range
    return normalized_pathch_score

# %%
drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, patch_score= score_test(grid_coord=(5,10), 
                                                                            score=score, 
                                                                            parameters=np.zeros([9,2]), 
                                                                            images=(image_A, image_A))
# Out:
# top 10 correlation values in descending :  [0.0039 0.0039 0.0038 0.0038 0.0036 0.0036 0.0036 0.0035 0.0035 0.0034]
# standard deviation : 0.0009366601007059216

# %%
# n, bins, patches = plt.hist(patch_score, bins=10, density=False, facecolor='blue', alpha=0.5)
# plt.xlabel('X bins')
# plt.ylabel('Frequency')
# plt.title('Histogram of correlations')


fig = plt.figure()

ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)
ax1.imshow(drawn_image_A)
ax2.imshow(expected_drawn_grid_image_B)
ax3.imshow(drawn_grid_image_B)
plt.show()
n, bins, patches = plt.hist(patch_score, bins=5, density=False, facecolor='blue', alpha=0.5)
plt.show()
heatmap = make_heatmap(patch_score)
plt.imshow(heatmap, cmap='gray')
plt.show()

# %%
drawn_image_A.shape
expected_drawn_grid_image_B.shape
drawn_grid_image_B.shape
# Out:
# (64, 64, 3)

# %% [markdown]
# ### b.1 ) 동일한 사진의 경우

# %%
for i in range(16):
    drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, patch_score= score_test(grid_coord=(i,i), 
                                                                                score=score, 
                                                                                parameters=np.zeros([9,2]), 
                                                                                images=(image_A, image_A))   
    fig = plt.figure()
    
    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)

    ax1.imshow(drawn_image_A)
    ax2.imshow(expected_drawn_grid_image_B)
    ax3.imshow(drawn_grid_image_B)

    plt.show()
    n, bins, patches = plt.hist(patch_score, bins=5, density=False, facecolor='blue', alpha=0.5)
    #plt.axis([0.0, 0.004, 0, 30])
    plt.show()
    heatmap = make_heatmap(patch_score)
    plt.imshow(heatmap, cmap='gray')
    plt.show()
# Out:
# top 10 correlation values in descending :  [0.0039 0.0031 0.0028 0.0028 0.0028 0.0028 0.0028 0.0028 0.0027 0.0027]
# standard deviation : 0.0008985703461803496
# top 10 correlation values in descending :  [0.0039 0.0031 0.0031 0.0029 0.0027 0.0027 0.0027 0.0027 0.0027 0.0026]
# standard deviation : 0.0008872940088622272
# top 10 correlation values in descending :  [0.0039 0.0035 0.0033 0.0032 0.0031 0.0030 0.0029 0.0029 0.0026 0.0025]
# standard deviation : 0.0008136408869177103
# top 10 correlation values in descending :  [0.0039 0.0035 0.0031 0.0031 0.0031 0.0030 0.0030 0.0030 0.0030 0.0030]
# standard deviation : 0.0008136499091051519
# top 10 correlation values in descending :  [0.0039 0.0038 0.0037 0.0037 0.0037 0.0036 0.0036 0.0036 0.0035 0.0035]
# standard deviation : 0.0009699989459477365
# top 10 correlation values in descending :  [0.0039 0.0038 0.0038 0.0037 0.0037 0.0037 0.0037 0.0037 0.0037 0.0035]
# standard deviation : 0.00101959309540689
# top 10 correlation values in descending :  [0.0039 0.0039 0.0037 0.0036 0.0035 0.0034 0.0034 0.0033 0.0032 0.0032]
# standard deviation : 0.0008742019417695701
# top 10 correlation values in descending :  [0.0039 0.0037 0.0037 0.0035 0.0035 0.0035 0.0033 0.0033 0.0033 0.0032]
# standard deviation : 0.0008713610586710274
# top 10 correlation values in descending :  [0.0039 0.0035 0.0034 0.0033 0.0033 0.0032 0.0031 0.0030 0.0029 0.0029]
# standard deviation : 0.0008531311177648604
# top 10 correlation values in descending :  [0.0039 0.0036 0.0033 0.0031 0.0029 0.0028 0.0028 0.0028 0.0027 0.0027]
# standard deviation : 0.0008173980168066919
# top 10 correlation values in descending :  [0.0039 0.0031 0.0025 0.0024 0.0022 0.0021 0.0021 0.0019 0.0019 0.0019]
# standard deviation : 0.0005730863194912672
# top 10 correlation values in descending :  [0.0039 0.0033 0.0031 0.0031 0.0030 0.0029 0.0026 0.0024 0.0024 0.0021]
# standard deviation : 0.0006398063851520419
# top 10 correlation values in descending :  [0.0039 0.0038 0.0033 0.0033 0.0031 0.0029 0.0028 0.0027 0.0026 0.0025]
# standard deviation : 0.0006519625894725323
# top 10 correlation values in descending :  [0.0039 0.0038 0.0035 0.0031 0.0031 0.0029 0.0029 0.0026 0.0026 0.0025]
# standard deviation : 0.0006479625008068979
# top 10 correlation values in descending :  [0.0039 0.0035 0.0033 0.0031 0.0029 0.0028 0.0026 0.0026 0.0026 0.0024]
# standard deviation : 0.0006833553197793663
# top 10 correlation values in descending :  [0.0039 0.0030 0.0026 0.0025 0.0022 0.0022 0.0021 0.0020 0.0020 0.0020]
# standard deviation : 0.0006313444464467466

# %% [markdown]
# ### b.2 ) 다른 사진의 경우

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_A)

score = score.numpy()[0]
parameters = parameters[0]
image_A = image_A[0]
image_B = image_B[0]

print(score.shape, parameters.shape, image_A.shape)
# Out:
# (16, 16, 16, 16) (9, 2) (64, 64, 3)

# %%
for i in range(16):
    drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, patch_score = score_test(grid_coord=(i,i), 
                                                                                score=score, 
                                                                                parameters=parameters, 
                                                                                images=(image_A, image_B))   
    fig = plt.figure()

    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)

    ax1.imshow(drawn_image_A)
    ax2.imshow(expected_drawn_grid_image_B)
    ax3.imshow(drawn_grid_image_B)

    plt.show()
    n, bins, patches = plt.hist(patch_score, bins=5, density=False, facecolor='blue', alpha=0.5)
    #plt.axis([0.055, 0.070, 0, 30])
    plt.show()
    heatmap = make_heatmap(patch_score)
    plt.imshow(heatmap, cmap='gray')
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0031 0.0030 0.0029 0.0028 0.0028 0.0028 0.0027 0.0027 0.0027]
# standard deviation : 0.0008597298874519765
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0032 0.0027 0.0026 0.0025 0.0024 0.0024 0.0023 0.0022 0.0022]
# standard deviation : 0.000763849588111043
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0036 0.0034 0.0033 0.0032 0.0032 0.0030 0.0025 0.0024 0.0023]
# standard deviation : 0.0007032671710476279
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0038 0.0035 0.0035 0.0035 0.0034 0.0033 0.0032 0.0028 0.0027]
# standard deviation : 0.0007822482148185372
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0036 0.0035 0.0035 0.0034 0.0032 0.0032 0.0031 0.0030 0.0030]
# standard deviation : 0.0007924443925730884
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0036 0.0034 0.0033 0.0031 0.0031 0.0031 0.0030 0.0029 0.0029]
# standard deviation : 0.0007843426428735256
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0034 0.0029 0.0028 0.0026 0.0026 0.0026 0.0026 0.0025 0.0025]
# standard deviation : 0.0006844732561148703
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0032 0.0030 0.0027 0.0026 0.0023 0.0022 0.0022 0.0022 0.0022]
# standard deviation : 0.0006606554379686713
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0035 0.0032 0.0031 0.0029 0.0029 0.0029 0.0027 0.0027 0.0026]
# standard deviation : 0.000735491921659559
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0037 0.0035 0.0034 0.0031 0.0030 0.0030 0.0030 0.0029 0.0028]
# standard deviation : 0.0007716265972703695
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0037 0.0037 0.0034 0.0032 0.0032 0.0032 0.0030 0.0030 0.0026]
# standard deviation : 0.000793860643170774
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0037 0.0037 0.0034 0.0033 0.0031 0.0030 0.0030 0.0029 0.0029]
# standard deviation : 0.0007996966014616191
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0037 0.0037 0.0034 0.0034 0.0032 0.0031 0.0030 0.0030 0.0029]
# standard deviation : 0.0007850118563510478
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0037 0.0034 0.0033 0.0033 0.0033 0.0032 0.0030 0.0030 0.0028]
# standard deviation : 0.0007535156910307705
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0033 0.0032 0.0031 0.0030 0.0030 0.0029 0.0028 0.0027 0.0027]
# standard deviation : 0.0007504483801312745
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0039 0.0030 0.0028 0.0027 0.0025 0.0025 0.0024 0.0024 0.0023 0.0023]
# standard deviation : 0.000690835586283356
