# %%
import os, sys
root_path = os.path.abspath('.').split('jupyters')[0]
sys.path.append(root_path)

# %%
import json
import argparse
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
from models.cnn_geo import CNN_geo, Spatial_transformer_regressor
from functools import partial
import simulator as sim

# %%
def gen_motion_parameter(shape):
    while True:
        yield (tf.random.uniform(shape) - 0.5) * 2 * 0.2

# %%
gen = partial(gen_motion_parameter, (9,2))
ds = tf.data.Dataset.from_generator(gen, output_types=tf.float32)

# %%
def data_process(motion_parameters, axay, map_size):
    motion_parameters = motion_parameters.numpy()
    bxby = sim.get_tgt_from_src(motion_parameters, axay, map_size)
    axybxy = np.concatenate([axay, bxby], axis = -1)
    correlations = sim.generate_correlations(axybxy, map_size)
    return motion_parameters, correlations

# %%
axay = np.array([[0.0, 0.0], [0.5, 0.0], [1.0, 0.0],
                           [0.0, 0.5], [0.5, 0.5], [1.0, 0.5],
                           [0.0, 1.0], [0.5, 1.0], [1.0, 1.0]])
map_size = (16, 16)
axay = axay*(map_size[1]-1, map_size[0]-1)
axay = axay.astype(np.int32)

py_func = partial(data_process, axay = axay, map_size = map_size)

# %%
def map_function(motion_paramters):
    return tf.py_function(py_func, [motion_paramters], [tf.float32, tf.float32])

# %%
ds = ds.map(map_function)
ds = ds.batch(16)

# %%
for mp, corr in ds.take(1):
    print(mp.shape)
    print(corr.shape)
# Out:
# (16, 9, 2)
# (16, 16, 16, 16, 16)

# %%
regressor = Spatial_transformer_regressor(18)

# %%
def loss_fn(pred, label):
    loss = tf.sqrt(tf.reduce_sum(tf.pow(pred - label, 2), axis=[-1, -2]))
    loss_mean = tf.reduce_mean(loss)
    return loss_mean

# %%
i = 0
x = []
x_loss = []
optimizer = tf.keras.optimizers.SGD(learning_rate=0.005)
for epoch in range(20000):
    i+= 1
    x.append(i)
    for mp, correlations in ds.take(1):
        with tf.GradientTape() as tape:
            pred = regressor(correlations)
            pred = tf.reshape(pred, [-1, 9, 2])
            loss = loss_fn(pred, mp)
            x_loss.append(loss)
        gradients = tape.gradient(loss, regressor.trainable_variables)
        optimizer.apply_gradients(zip(gradients, regressor.trainable_variables)) 
        if i % 100 == 0:
            print(i, "iter loss : ", loss.numpy())
# Out:
# 100 iter loss :  0.4894982
# 200 iter loss :  0.49657306
# 300 iter loss :  0.47095245
# 400 iter loss :  0.4650634
# 500 iter loss :  0.47283304
# 600 iter loss :  0.46736455
# 700 iter loss :  0.5038253
# 800 iter loss :  0.49652192
# 900 iter loss :  0.476737
# 1000 iter loss :  0.43159932
# 1100 iter loss :  0.48801678
# 1200 iter loss :  0.5001427
# 1300 iter loss :  0.49280462
# 1400 iter loss :  0.47672388
# 1500 iter loss :  0.4763243
# 1600 iter loss :  0.4747768
# 1700 iter loss :  0.49567592
# 1800 iter loss :  0.45847717
# 1900 iter loss :  0.46169654
# 2000 iter loss :  0.4581761
# 2100 iter loss :  0.4755848
# 2200 iter loss :  0.47124457
# 2300 iter loss :  0.4721744
# 2400 iter loss :  0.47461542
# 2500 iter loss :  0.4695232
# 2600 iter loss :  0.4575221
# 2700 iter loss :  0.47175425
# 2800 iter loss :  0.4458431
# 2900 iter loss :  0.44675827
# 3000 iter loss :  0.47455138
# 3100 iter loss :  0.45625246
# 3200 iter loss :  0.47848994
# 3300 iter loss :  0.4545362
# 3400 iter loss :  0.45482457
# 3500 iter loss :  0.448651
# 3600 iter loss :  0.43476734
# 3700 iter loss :  0.46949393
# 3800 iter loss :  0.45866054
# 3900 iter loss :  0.4604553
# 4000 iter loss :  0.43588543
# 4100 iter loss :  0.44302028
# 4200 iter loss :  0.44436648
# 4300 iter loss :  0.44308072
# 4400 iter loss :  0.44757086
# 4500 iter loss :  0.45479125
# 4600 iter loss :  0.45120436
# 4700 iter loss :  0.4334373
# 4800 iter loss :  0.4399739
# 4900 iter loss :  0.43386546
# 5000 iter loss :  0.43094718
# 5100 iter loss :  0.43088308
# 5200 iter loss :  0.4338622
# 5300 iter loss :  0.42755088
# 5400 iter loss :  0.41763592
# 5500 iter loss :  0.4135153
# 5600 iter loss :  0.4369733
# 5700 iter loss :  0.4177382
# 5800 iter loss :  0.41730133
# 5900 iter loss :  0.42206863
# 6000 iter loss :  0.4269186
# 6100 iter loss :  0.42916313
# 6200 iter loss :  0.41505325
# 6300 iter loss :  0.4076332
# 6400 iter loss :  0.39121187
# 6500 iter loss :  0.41007474
# 6600 iter loss :  0.3981408
# 6700 iter loss :  0.41510636
# 6800 iter loss :  0.43557373
# 6900 iter loss :  0.4178537
# 7000 iter loss :  0.40625665
# 7100 iter loss :  0.40315455
# 7200 iter loss :  0.4138485
# 7300 iter loss :  0.4276254
# 7400 iter loss :  0.3889252
# 7500 iter loss :  0.3991794
# 7600 iter loss :  0.3941481
# 7700 iter loss :  0.36604533
# 7800 iter loss :  0.4235094
# 7900 iter loss :  0.38530666
# 8000 iter loss :  0.38780862
# 8100 iter loss :  0.40013883
# 8200 iter loss :  0.37653714
# 8300 iter loss :  0.39323825
# 8400 iter loss :  0.3830574
# 8500 iter loss :  0.3874592
# 8600 iter loss :  0.37762478
# 8700 iter loss :  0.40125352
# 8800 iter loss :  0.38161147
# 8900 iter loss :  0.3736264
# 9000 iter loss :  0.375719
# 9100 iter loss :  0.38555336
# 9200 iter loss :  0.36867404
# 9300 iter loss :  0.41358808
# 9400 iter loss :  0.38337675
# 9500 iter loss :  0.37484068
# 9600 iter loss :  0.36074537
# 9700 iter loss :  0.37284234
# 9800 iter loss :  0.3851499
# 9900 iter loss :  0.37302813
# 10000 iter loss :  0.37409103
# 10100 iter loss :  0.37485525
# 10200 iter loss :  0.35274878
# 10300 iter loss :  0.3709076
# 10400 iter loss :  0.3653115
# 10500 iter loss :  0.34473276
# 10600 iter loss :  0.35892022
# 10700 iter loss :  0.3498522
# 10800 iter loss :  0.35500756
# 10900 iter loss :  0.33860743
# 11000 iter loss :  0.36285672
# 11100 iter loss :  0.34399295
# 11200 iter loss :  0.33147496
# 11300 iter loss :  0.34179312
# 11400 iter loss :  0.3263497
# 11500 iter loss :  0.347582
# 11600 iter loss :  0.3490457
# 11700 iter loss :  0.32766092
# 11800 iter loss :  0.31692034
# 11900 iter loss :  0.34646028
# 12000 iter loss :  0.3250947
# 12100 iter loss :  0.33333865
# 12200 iter loss :  0.28852463
# 12300 iter loss :  0.32961076
# 12400 iter loss :  0.34180796
# 12500 iter loss :  0.32861468
# 12600 iter loss :  0.3293504
# 12700 iter loss :  0.31291062
# 12800 iter loss :  0.32587168
# 12900 iter loss :  0.30898142
# 13000 iter loss :  0.31075633
# 13100 iter loss :  0.3161077
# 13200 iter loss :  0.29872555
# 13300 iter loss :  0.28564125
# 13400 iter loss :  0.29206136
# 13500 iter loss :  0.2969899
# 13600 iter loss :  0.31554434
# 13700 iter loss :  0.30128577
# 13800 iter loss :  0.29902285
# 13900 iter loss :  0.299973
# 14000 iter loss :  0.2895576
# 14100 iter loss :  0.2582174
# 14200 iter loss :  0.26137638
# 14300 iter loss :  0.28036654
# 14400 iter loss :  0.2828251
# 14500 iter loss :  0.29053745
# 14600 iter loss :  0.28110182
# 14700 iter loss :  0.25224492
# 14800 iter loss :  0.26003224
# 14900 iter loss :  0.2582664
# 15000 iter loss :  0.25222376
# 15100 iter loss :  0.26655698
# 15200 iter loss :  0.26585403
# 15300 iter loss :  0.25939628
# 15400 iter loss :  0.26281276
# 15500 iter loss :  0.2695977
# 15600 iter loss :  0.2757151
# 15700 iter loss :  0.26291937
# 15800 iter loss :  0.24136001
# 15900 iter loss :  0.25024363
# 16000 iter loss :  0.24462128
# 16100 iter loss :  0.23536837
# 16200 iter loss :  0.2729116
# 16300 iter loss :  0.2640552
# 16400 iter loss :  0.26226282
# 16500 iter loss :  0.2477276
# 16600 iter loss :  0.25407398
# 16700 iter loss :  0.228279
# 16800 iter loss :  0.21926066
# 16900 iter loss :  0.22889397
# 17000 iter loss :  0.2174369
# 17100 iter loss :  0.24146947
# 17200 iter loss :  0.22662969
# 17300 iter loss :  0.24755765
# 17400 iter loss :  0.23527212
# 17500 iter loss :  0.21914843
# 17600 iter loss :  0.21889095
# 17700 iter loss :  0.21998009
# 17800 iter loss :  0.21580094
# 17900 iter loss :  0.21189915
# 18000 iter loss :  0.22176182
# 18100 iter loss :  0.2035221
# 18200 iter loss :  0.21966328
# 18300 iter loss :  0.22614741
# 18400 iter loss :  0.22824264
# 18500 iter loss :  0.22571737
# 18600 iter loss :  0.22681388
# 18700 iter loss :  0.22441398
# 18800 iter loss :  0.23290788
# 18900 iter loss :  0.22147638
# 19000 iter loss :  0.22344299
# 19100 iter loss :  0.21746424
# 19200 iter loss :  0.22556257
# 19300 iter loss :  0.25397676
# 19400 iter loss :  0.22800672
# 19500 iter loss :  0.22322944
# 19600 iter loss :  0.21477903
# 19700 iter loss :  0.22425516
# 19800 iter loss :  0.2407877
# 19900 iter loss :  0.21470344
# 20000 iter loss :  0.21668221

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
#ax2 = fig.add_subplot(122)
ax1.title.set_text("training loss")
ax1.set_xlabel("epoch")
ax1.set_ylabel("training loss")
ax1.plot(np.array(x), np.array(x_loss))

# ax2.title.set_text("std-dev of correlations")
# ax2.set_xlabel("epoch")
# ax2.set_ylabel("std-dev")
# ax2.plot(np.array(x), np.array(y_score_std))

# %%
x = []
x_loss = []
optimizer = tf.keras.optimizers.SGD(learning_rate=0.005)
for epoch in range(20000):
    i+= 1
    x.append(i)
    for mp, correlations in ds.take(1):
        with tf.GradientTape() as tape:
            pred = regressor(correlations)
            pred = tf.reshape(pred, [-1, 9, 2])
            loss = loss_fn(pred, mp)
            x_loss.append(loss)
        gradients = tape.gradient(loss, regressor.trainable_variables)
        optimizer.apply_gradients(zip(gradients, regressor.trainable_variables)) 
        if i % 100 == 0:
            print(i, "iter loss : ", loss.numpy())
# Out:
# 20100 iter loss :  0.2374729
# 20200 iter loss :  0.22262985
# 20300 iter loss :  0.21556354
# 20400 iter loss :  0.23469731
# 20500 iter loss :  0.2148498
# 20600 iter loss :  0.21814314
# 20700 iter loss :  0.22442773
# 20800 iter loss :  0.21857516
# 20900 iter loss :  0.22869805
# 21000 iter loss :  0.21166317
# 21100 iter loss :  0.23177499
# 21200 iter loss :  0.21156915
# 21300 iter loss :  0.2214749
# 21400 iter loss :  0.22012213
# 21500 iter loss :  0.20719472
# 21600 iter loss :  0.20319337
# 21700 iter loss :  0.20400316
# 21800 iter loss :  0.21340023
# 21900 iter loss :  0.21535689
# 22000 iter loss :  0.21087441
# 22100 iter loss :  0.19513072
# 22200 iter loss :  0.20228948
# 22300 iter loss :  0.22795828
# 22400 iter loss :  0.21632868
# 22500 iter loss :  0.21533869
# 22600 iter loss :  0.21302697
# 22700 iter loss :  0.21417364
# 22800 iter loss :  0.20844454
# 22900 iter loss :  0.22659487
# 23000 iter loss :  0.19249186
# 23100 iter loss :  0.21892522
# 23200 iter loss :  0.22243379
# 23300 iter loss :  0.20381536
# 23400 iter loss :  0.21607658
# 23500 iter loss :  0.20245306
# 23600 iter loss :  0.2201101
# 23700 iter loss :  0.20300022
# 23800 iter loss :  0.22083002
# 23900 iter loss :  0.21190442
# 24000 iter loss :  0.23273118
# 24100 iter loss :  0.1978749
# 24200 iter loss :  0.21856013
# 24300 iter loss :  0.21580343
# 24400 iter loss :  0.20423532
# 24500 iter loss :  0.22442469
# 24600 iter loss :  0.21310897
# 24700 iter loss :  0.18613657
# 24800 iter loss :  0.2092439
# 24900 iter loss :  0.2163643
# 25000 iter loss :  0.20787704
# 25100 iter loss :  0.22445379
# 25200 iter loss :  0.22382167
# 25300 iter loss :  0.22046337
# 25400 iter loss :  0.20983508
# 25500 iter loss :  0.2023215
# 25600 iter loss :  0.2175776
# 25700 iter loss :  0.19425228
# 25800 iter loss :  0.23718062
# 25900 iter loss :  0.2376827
# 26000 iter loss :  0.23694901
# 26100 iter loss :  0.22747576
# 26200 iter loss :  0.2193794
# 26300 iter loss :  0.21026199
# 26400 iter loss :  0.20252325
# 26500 iter loss :  0.24215588
# 26600 iter loss :  0.22716996
# 26700 iter loss :  0.19933787
# 26800 iter loss :  0.21415831
# 26900 iter loss :  0.21857852
# 27000 iter loss :  0.21196896
# 27100 iter loss :  0.19055367
# 27200 iter loss :  0.20819575
# 27300 iter loss :  0.20612592
# 27400 iter loss :  0.21041943
# 27500 iter loss :  0.23226833
# 27600 iter loss :  0.21292089
# 27700 iter loss :  0.2109247
# 27800 iter loss :  0.20233431
# 27900 iter loss :  0.20595115
# 28000 iter loss :  0.19913696
# 28100 iter loss :  0.21628156
# 28200 iter loss :  0.19590876
# 28300 iter loss :  0.20950566
# 28400 iter loss :  0.21328396
# 28500 iter loss :  0.20397611
# 28600 iter loss :  0.2018266
# 28700 iter loss :  0.19656754
# 28800 iter loss :  0.21407802
# 28900 iter loss :  0.21991861
# 29000 iter loss :  0.24840118
# 29100 iter loss :  0.22666132
# 29200 iter loss :  0.20935628
# 29300 iter loss :  0.21962269
# 29400 iter loss :  0.20649606
# 29500 iter loss :  0.20853671
# 29600 iter loss :  0.2093122
# 29700 iter loss :  0.21644308
# 29800 iter loss :  0.2247345
# 29900 iter loss :  0.21190804
# 30000 iter loss :  0.20910819
# 30100 iter loss :  0.20176557
# 30200 iter loss :  0.20409183
# 30300 iter loss :  0.22474618
# 30400 iter loss :  0.22204974
# 30500 iter loss :  0.21486911
# 30600 iter loss :  0.21542896
# 30700 iter loss :  0.19913174
# 30800 iter loss :  0.19496137
# 30900 iter loss :  0.22579624
# 31000 iter loss :  0.1988127
# 31100 iter loss :  0.20491096
# 31200 iter loss :  0.20284341
# 31300 iter loss :  0.21501316
# 31400 iter loss :  0.20584719
# 31500 iter loss :  0.19391984
# 31600 iter loss :  0.22117007
# 31700 iter loss :  0.1909177
# 31800 iter loss :  0.23469752
# 31900 iter loss :  0.22674641
# 32000 iter loss :  0.20916654
# 32100 iter loss :  0.21493095
# 32200 iter loss :  0.21457973
# 32300 iter loss :  0.18933952
# 32400 iter loss :  0.20394522
# 32500 iter loss :  0.20798133
# 32600 iter loss :  0.2142879
# 32700 iter loss :  0.21280569
# 32800 iter loss :  0.21726164
# 32900 iter loss :  0.22963849
# 33000 iter loss :  0.21525578
# 33100 iter loss :  0.21367827
# 33200 iter loss :  0.2227852
# 33300 iter loss :  0.22348158
# 33400 iter loss :  0.19832572
# 33500 iter loss :  0.17923467
# 33600 iter loss :  0.20451377
# 33700 iter loss :  0.21900925
# 33800 iter loss :  0.2064543
# 33900 iter loss :  0.2035664
# 34000 iter loss :  0.2174176
# 34100 iter loss :  0.20076966
# 34200 iter loss :  0.21051335
# 34300 iter loss :  0.22244367
# 34400 iter loss :  0.22615823
# 34500 iter loss :  0.20893534
# 34600 iter loss :  0.21712653
# 34700 iter loss :  0.18159139
# 34800 iter loss :  0.22617857
# 34900 iter loss :  0.2115628
# 35000 iter loss :  0.18316567
# 35100 iter loss :  0.21337356
# 35200 iter loss :  0.23498431
# 35300 iter loss :  0.20747943
# 35400 iter loss :  0.19851188
# 35500 iter loss :  0.19139448
# 35600 iter loss :  0.21718302
# 35700 iter loss :  0.20864023
# 35800 iter loss :  0.20659918
# 35900 iter loss :  0.2174442
# 36000 iter loss :  0.21315561
# 36100 iter loss :  0.23302454
# 36200 iter loss :  0.218594
# 36300 iter loss :  0.22835541
# 36400 iter loss :  0.2086829
# 36500 iter loss :  0.21338263
# 36600 iter loss :  0.19469348
# 36700 iter loss :  0.20932414
# 36800 iter loss :  0.20891047
# 36900 iter loss :  0.21697813
# 37000 iter loss :  0.20349416
# 37100 iter loss :  0.20340791
# 37200 iter loss :  0.22460684
# 37300 iter loss :  0.22145157
# 37400 iter loss :  0.22025253
# 37500 iter loss :  0.20836106
# 37600 iter loss :  0.21398841
# 37700 iter loss :  0.19198164
# 37800 iter loss :  0.19834821
# 37900 iter loss :  0.23580718
# 38000 iter loss :  0.19864595
# 38100 iter loss :  0.21440814
# 38200 iter loss :  0.20411062
# 38300 iter loss :  0.23137248
# 38400 iter loss :  0.20211515
# 38500 iter loss :  0.20385571
# 38600 iter loss :  0.22737932
# 38700 iter loss :  0.20656303
# 38800 iter loss :  0.22807749
# 38900 iter loss :  0.20392704
# 39000 iter loss :  0.21480276
# 39100 iter loss :  0.19290057
# 39200 iter loss :  0.19715782
# 39300 iter loss :  0.2160485
# 39400 iter loss :  0.22307396
# 39500 iter loss :  0.2055975
# 39600 iter loss :  0.21027885
# 39700 iter loss :  0.20818526
# 39800 iter loss :  0.20090404
# 39900 iter loss :  0.22159475
# 40000 iter loss :  0.2166965

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
#ax2 = fig.add_subplot(122)
ax1.title.set_text("training loss")
ax1.set_xlabel("epoch")
ax1.set_ylabel("training loss")
ax1.plot(np.array(x), np.array(x_loss))

# ax2.title.set_text("std-dev of correlations")
# ax2.set_xlabel("epoch")
# ax2.set_ylabel("std-dev")
# ax2.plot(np.array(x), np.array(y_score_std))

# %%
x = []
x_loss = []
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
for epoch in range(20000):
    i+= 1
    x.append(i)
    for mp, correlations in ds.take(1):
        with tf.GradientTape() as tape:
            pred = regressor(correlations)
            pred = tf.reshape(pred, [-1, 9, 2])
            loss = loss_fn(pred, mp)
            x_loss.append(loss)
        gradients = tape.gradient(loss, regressor.trainable_variables)
        optimizer.apply_gradients(zip(gradients, regressor.trainable_variables)) 
        if i % 100 == 0:
            print(i, "iter loss : ", loss.numpy())
# Out:
# 40100 iter loss :  0.22739604
# 40200 iter loss :  0.21820572
# 40300 iter loss :  0.21363264
# 40400 iter loss :  0.20805939
# 40500 iter loss :  0.21957815
# 40600 iter loss :  0.2022327
# 40700 iter loss :  0.20510727
# 40800 iter loss :  0.21470425
# 40900 iter loss :  0.24120781
# 41000 iter loss :  0.1949597
# 41100 iter loss :  0.21153572
# 41200 iter loss :  0.18609458
# 41300 iter loss :  0.20558469
# 41400 iter loss :  0.20888291
# 41500 iter loss :  0.19729498
# 41600 iter loss :  0.20114234
# 41700 iter loss :  0.21992655
# 41800 iter loss :  0.20823932
# 41900 iter loss :  0.20997265
# 42000 iter loss :  0.22259411
# 42100 iter loss :  0.20096397
# 42200 iter loss :  0.22191867
# 42300 iter loss :  0.21300426
# 42400 iter loss :  0.21424651
# 42500 iter loss :  0.18576592
# 42600 iter loss :  0.1904056
# 42700 iter loss :  0.24717146
# 42800 iter loss :  0.22062984
# 42900 iter loss :  0.20854253
# 43000 iter loss :  0.19214538
# 43100 iter loss :  0.22109157
# 43200 iter loss :  0.21592522
# 43300 iter loss :  0.2216109
# 43400 iter loss :  0.20919466
# 43500 iter loss :  0.20813283
# 43600 iter loss :  0.21338655
# 43700 iter loss :  0.21695426
# 43800 iter loss :  0.20858878
# 43900 iter loss :  0.19437537
# 44000 iter loss :  0.2115733
# 44100 iter loss :  0.21712747
# 44200 iter loss :  0.18917906
# 44300 iter loss :  0.20935717
# 44400 iter loss :  0.23389585
# 44500 iter loss :  0.20522842
# 44600 iter loss :  0.21085203
# 44700 iter loss :  0.22604471
# 44800 iter loss :  0.22821279
# 44900 iter loss :  0.22068954
# 45000 iter loss :  0.18147345
# 45100 iter loss :  0.21560532
# 45200 iter loss :  0.19948441
# 45300 iter loss :  0.19592565
# 45400 iter loss :  0.20277521
# 45500 iter loss :  0.21274553
# 45600 iter loss :  0.2266292
# 45700 iter loss :  0.19142449
# 45800 iter loss :  0.20539773
# 45900 iter loss :  0.21610303
# 46000 iter loss :  0.22760493
# 46100 iter loss :  0.20071578
# 46200 iter loss :  0.20415074
# 46300 iter loss :  0.20552807
# 46400 iter loss :  0.2015846
# 46500 iter loss :  0.21486473
# 46600 iter loss :  0.18428816
# 46700 iter loss :  0.22878756
# 46800 iter loss :  0.21880767
# 46900 iter loss :  0.2069157
# 47000 iter loss :  0.22700258
# 47100 iter loss :  0.19592863
# 47200 iter loss :  0.20327634
# 47300 iter loss :  0.21966133
# 47400 iter loss :  0.2170737
# 47500 iter loss :  0.19601716
# 47600 iter loss :  0.21591082
# 47700 iter loss :  0.21122015
# 47800 iter loss :  0.20082535
# 47900 iter loss :  0.21549642
# 48000 iter loss :  0.20071252
# 48100 iter loss :  0.23270865
# 48200 iter loss :  0.21305704
# 48300 iter loss :  0.22050795
# 48400 iter loss :  0.23224682
# 48500 iter loss :  0.20415774
# 48600 iter loss :  0.21102276
# 48700 iter loss :  0.23186034
# 48800 iter loss :  0.22404525
# 48900 iter loss :  0.21979308
# 49000 iter loss :  0.1946331
# 49100 iter loss :  0.21937501
# 49200 iter loss :  0.20695269
# 49300 iter loss :  0.20706162
# 49400 iter loss :  0.20880136
# 49500 iter loss :  0.20907857
# 49600 iter loss :  0.20353758
# 49700 iter loss :  0.2024225
# 49800 iter loss :  0.20279177
# 49900 iter loss :  0.2154447
# 50000 iter loss :  0.23374498
# 50100 iter loss :  0.22812393
# 50200 iter loss :  0.23437577
# 50300 iter loss :  0.22128022
# 50400 iter loss :  0.19841379
# 50500 iter loss :  0.22023112
# 50600 iter loss :  0.19684118
# 50700 iter loss :  0.21913216
# 50800 iter loss :  0.22830337
# 50900 iter loss :  0.22930904
# 51000 iter loss :  0.23126028
# 51100 iter loss :  0.19780305
# 51200 iter loss :  0.23806672
# 51300 iter loss :  0.20560485
# 51400 iter loss :  0.20432997
# 51500 iter loss :  0.18493271
# 51600 iter loss :  0.20259172
# 51700 iter loss :  0.19000976
# 51800 iter loss :  0.20976101
# 51900 iter loss :  0.20922628
# 52000 iter loss :  0.22950011
# 52100 iter loss :  0.22454973
# 52200 iter loss :  0.24469039
# 52300 iter loss :  0.22290164
# 52400 iter loss :  0.21729383
# 52500 iter loss :  0.20636155
# 52600 iter loss :  0.20881748
# 52700 iter loss :  0.20029855
# 52800 iter loss :  0.18489847
# 52900 iter loss :  0.20946325
# 53000 iter loss :  0.21026334
# 53100 iter loss :  0.21304084
# 53200 iter loss :  0.20146078
# 53300 iter loss :  0.19828543
# 53400 iter loss :  0.20255192
# 53500 iter loss :  0.17982918
# 53600 iter loss :  0.21813254
# 53700 iter loss :  0.21420638
# 53800 iter loss :  0.21690018
# 53900 iter loss :  0.1952764
# 54000 iter loss :  0.2298196
# 54100 iter loss :  0.20012577
# 54200 iter loss :  0.19772176
# 54300 iter loss :  0.21520169
# 54400 iter loss :  0.21904702
# 54500 iter loss :  0.20743027
# 54600 iter loss :  0.22593129
# 54700 iter loss :  0.22096284
# 54800 iter loss :  0.21660474
# 54900 iter loss :  0.21565448
# 55000 iter loss :  0.21777725
# 55100 iter loss :  0.20651677
# 55200 iter loss :  0.22084346
# 55300 iter loss :  0.20879804
# 55400 iter loss :  0.2144481
# 55500 iter loss :  0.2209555
# 55600 iter loss :  0.21704009
# 55700 iter loss :  0.22413778
# 55800 iter loss :  0.20714487
# 55900 iter loss :  0.21938807
# 56000 iter loss :  0.20522797
# 56100 iter loss :  0.22315925
# 56200 iter loss :  0.209483
# 56300 iter loss :  0.18112019
# 56400 iter loss :  0.20370424
# 56500 iter loss :  0.2006804
# 56600 iter loss :  0.19400917
# 56700 iter loss :  0.20509148
# 56800 iter loss :  0.235933
# 56900 iter loss :  0.19456147
# 57000 iter loss :  0.19874379
# 57100 iter loss :  0.21181612
# 57200 iter loss :  0.19831066
# 57300 iter loss :  0.19772404
# 57400 iter loss :  0.20429859
# 57500 iter loss :  0.22289068
# 57600 iter loss :  0.21367332
# 57700 iter loss :  0.19268425
# 57800 iter loss :  0.19698486
# 57900 iter loss :  0.23457289
# 58000 iter loss :  0.18143028
# 58100 iter loss :  0.18867987
# 58200 iter loss :  0.217554
# 58300 iter loss :  0.24704018
# 58400 iter loss :  0.19556648
# 58500 iter loss :  0.19763088
# 58600 iter loss :  0.22603989
# 58700 iter loss :  0.26010984
# 58800 iter loss :  0.20522934
# 58900 iter loss :  0.21374059
# 59000 iter loss :  0.22706008
# 59100 iter loss :  0.21151471
# 59200 iter loss :  0.18731098
# 59300 iter loss :  0.22481519
# 59400 iter loss :  0.19544935
# 59500 iter loss :  0.23940973
# 59600 iter loss :  0.20062724
# 59700 iter loss :  0.19190739
# 59800 iter loss :  0.22433148
# 59900 iter loss :  0.20376357
# 60000 iter loss :  0.19110546

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
#ax2 = fig.add_subplot(122)
ax1.title.set_text("training loss")
ax1.set_xlabel("epoch")
ax1.set_ylabel("training loss")
ax1.plot(np.array(x), np.array(x_loss))

# ax2.title.set_text("std-dev of correlations")
# ax2.set_xlabel("epoch")
# ax2.set_ylabel("std-dev")
# ax2.plot(np.array(x), np.array(y_score_std))

# %%
for mp, corr in ds.take(1):
    pred = regressor(corr)
    pred = tf.reshape(pred, [-1, 9, 2])

# %%
pred[0]
# Out:
# <tf.Tensor: shape=(9, 2), dtype=float32, numpy=
# array([[ 0.1883005 ,  0.1433503 ],
#        [ 0.00413249, -0.10001589],
#        [ 0.08948354, -0.06716209],
#        [-0.09269941,  0.06156114],
#        [-0.14597961,  0.13638309],
#        [-0.05778319, -0.07614674],
#        [-0.06821522, -0.07332332],
#        [-0.1127115 ,  0.07403905],
#        [ 0.0797099 ,  0.08333907]], dtype=float32)>

# %%
mp[0]
# Out:
# <tf.Tensor: shape=(9, 2), dtype=float32, numpy=
# array([[ 0.17069522,  0.16263328],
#        [-0.03232708, -0.13009273],
#        [ 0.0748085 , -0.09620815],
#        [-0.05732775,  0.02519917],
#        [-0.15379277,  0.1483715 ],
#        [-0.0596693 , -0.09356704],
#        [-0.05032959, -0.12859593],
#        [-0.03580518,  0.13290448],
#        [ 0.05473471, -0.02192111]], dtype=float32)>

# %%
tf.sqrt(tf.reduce_sum(tf.pow(pred[0] - mp[0], 2), axis=[-1, -2]))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.17753312>

# %%
pred[0]*mp[0] > 0
# Out:
# <tf.Tensor: shape=(9, 2), dtype=bool, numpy=
# array([[ True,  True],
#        [False,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True, False]])>

# %%
def loss_fn(pred, label):
    loss = tf.sqrt(tf.reduce_sum(tf.pow(pred - label, 2), axis=[-1, -2]))
    loss_mean = tf.reduce_mean(loss)
    return loss_mean

# %% [markdown]
# # Smaller grid map

# %%
map_size = (3,3)

# %%
gen = partial(gen_motion_parameter, (9,2))
ds = tf.data.Dataset.from_generator(gen, output_types=tf.float32)
