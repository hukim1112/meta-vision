# %%
import os, sys
root_path = os.path.abspath('.').split('jupyters')[0]
sys.path.append(root_path)

# %%
import json
import argparse
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

from data_loader import load_data
from models.cnn_geo import CNN_geo

from debug_tools import data, train, visualize
from utils import image
import geo_transform as tps
import CNNgeo_debug

# %% [markdown]
# # 1. Read configuration file

# %%
with open('../overfit.json') as fp:
    config = json.load(fp)
split = 'val'

# %%
print(config)
# Out:
# {'exp_desc': '200507_regressor_filter_size_up', 'dataset_name': 'mini_imagenet', 'data_dir': '/home/files/datasets/mini_imagenet', 'image_shape': [64, 64, 3], 'model_name': 'CNNgeo', 'backbone': 'prototypical_network', 'data': {'method': 'synthesized_pair', 'tps_random_rate': 0.2, 'pad_ratio': 0.2}, 'ckpt': {'save_type': 'latest', 'max_to_keep': 10}, 'train': {'n_examples': 1, 'learning_rate': 0.0001, 'batch_size': 1, 'epochs': 200, 'print_step': 10}, 'val': {'n_examples': 1, 'batch_size': 1}, 'test': {'n_examples': -1, 'batch_size': 128}}

# %%
print(config['train'])
# Out:
# {'n_examples': 1, 'learning_rate': 0.0001, 'batch_size': 1, 'epochs': 200, 'print_step': 10}

# %%
config['backbone'] = 'vgg16'
config['train']['epochs'] = 200

# %%
print("backbone : ", config['backbone'])
print("n_examples : ", config['train']['n_examples'])
print("learning_rate : ", config['train']['learning_rate'])
print("batch_size : ", config['train']['batch_size'])
print("epoch num : ", config['train']['epochs'])
# Out:
# backbone :  vgg16
# n_examples :  1
# learning_rate :  0.0001
# batch_size :  1
# epoch num :  200

# %% [markdown]
# # 2. Train model on the config parameters

# %%
model = CNNgeo_debug.train(config)
# Out:
# train dataset amount : 1
# val dataset amount : 1
# start of epoch 1
# Training loss (for one batch) at step 0: 0.5724835395812988
# Epoch 1, Loss: 0.5724835395812988, Val Loss: 0.635546863079071
# end of epoch.
# start of epoch 2
# Training loss (for one batch) at step 0: 0.5602666735649109
# Epoch 2, Loss: 0.5602666735649109, Val Loss: 0.514857828617096
# end of epoch.
# start of epoch 3
# Training loss (for one batch) at step 0: 0.4802684485912323
# Epoch 3, Loss: 0.4802684485912323, Val Loss: 0.6067610383033752
# end of epoch.
# start of epoch 4
# Training loss (for one batch) at step 0: 0.44086670875549316
# Epoch 4, Loss: 0.44086670875549316, Val Loss: 0.5543524622917175
# end of epoch.
# start of epoch 5
# Training loss (for one batch) at step 0: 0.651846706867218
# Epoch 5, Loss: 0.651846706867218, Val Loss: 0.5371522307395935
# end of epoch.
# start of epoch 6
# Training loss (for one batch) at step 0: 0.6490335464477539
# Epoch 6, Loss: 0.6490335464477539, Val Loss: 0.5638830661773682
# end of epoch.
# start of epoch 7
# Training loss (for one batch) at step 0: 0.5020908117294312
# Epoch 7, Loss: 0.5020908117294312, Val Loss: 0.5251038074493408
# end of epoch.
# start of epoch 8
# Training loss (for one batch) at step 0: 0.6314242482185364
# Epoch 8, Loss: 0.6314242482185364, Val Loss: 0.6016003489494324
# end of epoch.
# start of epoch 9
# Training loss (for one batch) at step 0: 0.5180094242095947
# Epoch 9, Loss: 0.5180094242095947, Val Loss: 0.5658434629440308
# end of epoch.
# start of epoch 10
# Training loss (for one batch) at step 0: 0.44083988666534424
# Epoch 10, Loss: 0.44083988666534424, Val Loss: 0.45276781916618347
# end of epoch.
# start of epoch 11
# Training loss (for one batch) at step 0: 0.43002328276634216
# Epoch 11, Loss: 0.43002328276634216, Val Loss: 0.42749035358428955
# end of epoch.
# start of epoch 12
# Training loss (for one batch) at step 0: 0.4309091567993164
# Epoch 12, Loss: 0.4309091567993164, Val Loss: 0.549156904220581
# end of epoch.
# start of epoch 13
# Training loss (for one batch) at step 0: 0.5598063468933105
# Epoch 13, Loss: 0.5598063468933105, Val Loss: 0.6276618242263794
# end of epoch.
# start of epoch 14
# Training loss (for one batch) at step 0: 0.5595912337303162
# Epoch 14, Loss: 0.5595912337303162, Val Loss: 0.6266000866889954
# end of epoch.
# start of epoch 15
# Training loss (for one batch) at step 0: 0.47397860884666443
# Epoch 15, Loss: 0.47397860884666443, Val Loss: 0.551529049873352
# end of epoch.
# start of epoch 16
# Training loss (for one batch) at step 0: 0.5834795832633972
# Epoch 16, Loss: 0.5834795832633972, Val Loss: 0.41078779101371765
# end of epoch.
# start of epoch 17
# Training loss (for one batch) at step 0: 0.4056417644023895
# Epoch 17, Loss: 0.4056417644023895, Val Loss: 0.5093507766723633
# end of epoch.
# start of epoch 18
# Training loss (for one batch) at step 0: 0.4545764923095703
# Epoch 18, Loss: 0.4545764923095703, Val Loss: 0.5850673913955688
# end of epoch.
# start of epoch 19
# Training loss (for one batch) at step 0: 0.44214504957199097
# Epoch 19, Loss: 0.44214504957199097, Val Loss: 0.46583452820777893
# end of epoch.
# start of epoch 20
# Training loss (for one batch) at step 0: 0.5381837487220764
# Epoch 20, Loss: 0.5381837487220764, Val Loss: 0.5136317610740662
# end of epoch.
# start of epoch 21
# Training loss (for one batch) at step 0: 0.47846299409866333
# Epoch 21, Loss: 0.47846299409866333, Val Loss: 0.4947682023048401
# end of epoch.
# start of epoch 22
# Training loss (for one batch) at step 0: 0.49380823969841003
# Epoch 22, Loss: 0.49380823969841003, Val Loss: 0.5106778740882874
# end of epoch.
# start of epoch 23
# Training loss (for one batch) at step 0: 0.527641773223877
# Epoch 23, Loss: 0.527641773223877, Val Loss: 0.500295102596283
# end of epoch.
# start of epoch 24
# Training loss (for one batch) at step 0: 0.5072935223579407
# Epoch 24, Loss: 0.5072935223579407, Val Loss: 0.5061391592025757
# end of epoch.
# start of epoch 25
# Training loss (for one batch) at step 0: 0.5585676431655884
# Epoch 25, Loss: 0.5585676431655884, Val Loss: 0.49938684701919556
# end of epoch.
# start of epoch 26
# Training loss (for one batch) at step 0: 0.5638230443000793
# Epoch 26, Loss: 0.5638230443000793, Val Loss: 0.5351771116256714
# end of epoch.
# start of epoch 27
# Training loss (for one batch) at step 0: 0.3818694055080414
# Epoch 27, Loss: 0.3818694055080414, Val Loss: 0.5522785186767578
# end of epoch.
# start of epoch 28
# Training loss (for one batch) at step 0: 0.5663398504257202
# Epoch 28, Loss: 0.5663398504257202, Val Loss: 0.5366557240486145
# end of epoch.
# start of epoch 29
# Training loss (for one batch) at step 0: 0.40704673528671265
# Epoch 29, Loss: 0.40704673528671265, Val Loss: 0.5310126543045044
# end of epoch.
# start of epoch 30
# Training loss (for one batch) at step 0: 0.5247408747673035
# Epoch 30, Loss: 0.5247408747673035, Val Loss: 0.4600290060043335
# end of epoch.
# start of epoch 31
# Training loss (for one batch) at step 0: 0.4438265264034271
# Epoch 31, Loss: 0.4438265264034271, Val Loss: 0.5357942581176758
# end of epoch.
# start of epoch 32
# Training loss (for one batch) at step 0: 0.505274772644043
# Epoch 32, Loss: 0.505274772644043, Val Loss: 0.5454487800598145
# end of epoch.
# start of epoch 33
# Training loss (for one batch) at step 0: 0.4963686764240265
# Epoch 33, Loss: 0.4963686764240265, Val Loss: 0.5193508863449097
# end of epoch.
# start of epoch 34
# Training loss (for one batch) at step 0: 0.5760108828544617
# Epoch 34, Loss: 0.5760108828544617, Val Loss: 0.65716153383255
# end of epoch.
# start of epoch 35
# Training loss (for one batch) at step 0: 0.45723581314086914
# Epoch 35, Loss: 0.45723581314086914, Val Loss: 0.4234031140804291
# end of epoch.
# start of epoch 36
# Training loss (for one batch) at step 0: 0.46393415331840515
# Epoch 36, Loss: 0.46393415331840515, Val Loss: 0.4952993094921112
# end of epoch.
# start of epoch 37
# Training loss (for one batch) at step 0: 0.4165615439414978
# Epoch 37, Loss: 0.4165615439414978, Val Loss: 0.4867374300956726
# end of epoch.
# start of epoch 38
# Training loss (for one batch) at step 0: 0.5204523205757141
# Epoch 38, Loss: 0.5204523205757141, Val Loss: 0.4985165297985077
# end of epoch.
# start of epoch 39
# Training loss (for one batch) at step 0: 0.5775829553604126
# Epoch 39, Loss: 0.5775829553604126, Val Loss: 0.590719997882843
# end of epoch.
# start of epoch 40
# Training loss (for one batch) at step 0: 0.5207250714302063
# Epoch 40, Loss: 0.5207250714302063, Val Loss: 0.5194852948188782
# end of epoch.
# start of epoch 41
# Training loss (for one batch) at step 0: 0.505877673625946
# Epoch 41, Loss: 0.505877673625946, Val Loss: 0.4771094024181366
# end of epoch.
# start of epoch 42
# Training loss (for one batch) at step 0: 0.5145263075828552
# Epoch 42, Loss: 0.5145263075828552, Val Loss: 0.5335949659347534
# end of epoch.
# start of epoch 43
# Training loss (for one batch) at step 0: 0.5333780646324158
# Epoch 43, Loss: 0.5333780646324158, Val Loss: 0.5229541659355164
# end of epoch.
# start of epoch 44
# Training loss (for one batch) at step 0: 0.5718133449554443
# Epoch 44, Loss: 0.5718133449554443, Val Loss: 0.6672825813293457
# end of epoch.
# start of epoch 45
# Training loss (for one batch) at step 0: 0.5359415411949158
# Epoch 45, Loss: 0.5359415411949158, Val Loss: 0.39468061923980713
# end of epoch.
# start of epoch 46
# Training loss (for one batch) at step 0: 0.5376120805740356
# Epoch 46, Loss: 0.5376120805740356, Val Loss: 0.5472399592399597
# end of epoch.
# start of epoch 47
# Training loss (for one batch) at step 0: 0.5444527268409729
# Epoch 47, Loss: 0.5444527268409729, Val Loss: 0.49973228573799133
# end of epoch.
# start of epoch 48
# Training loss (for one batch) at step 0: 0.48962265253067017
# Epoch 48, Loss: 0.48962265253067017, Val Loss: 0.5391849279403687
# end of epoch.
# start of epoch 49
# Training loss (for one batch) at step 0: 0.5607568621635437
# Epoch 49, Loss: 0.5607568621635437, Val Loss: 0.519669234752655
# end of epoch.
# start of epoch 50
# Training loss (for one batch) at step 0: 0.5501871109008789
# Epoch 50, Loss: 0.5501871109008789, Val Loss: 0.5590235590934753
# end of epoch.
# start of epoch 51
# Training loss (for one batch) at step 0: 0.4578462243080139
# Epoch 51, Loss: 0.4578462243080139, Val Loss: 0.4890090525150299
# end of epoch.
# start of epoch 52
# Training loss (for one batch) at step 0: 0.41607463359832764
# Epoch 52, Loss: 0.41607463359832764, Val Loss: 0.5942156910896301
# end of epoch.
# start of epoch 53
# Training loss (for one batch) at step 0: 0.5029325485229492
# Epoch 53, Loss: 0.5029325485229492, Val Loss: 0.5598888397216797
# end of epoch.
# start of epoch 54
# Training loss (for one batch) at step 0: 0.49288418889045715
# Epoch 54, Loss: 0.49288418889045715, Val Loss: 0.456519216299057
# end of epoch.
# start of epoch 55
# Training loss (for one batch) at step 0: 0.43010109663009644
# Epoch 55, Loss: 0.43010109663009644, Val Loss: 0.4861908257007599
# end of epoch.
# start of epoch 56
# Training loss (for one batch) at step 0: 0.424308180809021
# Epoch 56, Loss: 0.424308180809021, Val Loss: 0.5463502407073975
# end of epoch.
# start of epoch 57
# Training loss (for one batch) at step 0: 0.5397616624832153
# Epoch 57, Loss: 0.5397616624832153, Val Loss: 0.5771967172622681
# end of epoch.
# start of epoch 58
# Training loss (for one batch) at step 0: 0.44039979577064514
# Epoch 58, Loss: 0.44039979577064514, Val Loss: 0.46215489506721497
# end of epoch.
# start of epoch 59
# Training loss (for one batch) at step 0: 0.46592211723327637
# Epoch 59, Loss: 0.46592211723327637, Val Loss: 0.5608147382736206
# end of epoch.
# start of epoch 60
# Training loss (for one batch) at step 0: 0.6422201991081238
# Epoch 60, Loss: 0.6422201991081238, Val Loss: 0.48784807324409485
# end of epoch.
# start of epoch 61
# Training loss (for one batch) at step 0: 0.4675610661506653
# Epoch 61, Loss: 0.4675610661506653, Val Loss: 0.44121071696281433
# end of epoch.
# start of epoch 62
# Training loss (for one batch) at step 0: 0.4821939766407013
# Epoch 62, Loss: 0.4821939766407013, Val Loss: 0.5082603096961975
# end of epoch.
# start of epoch 63
# Training loss (for one batch) at step 0: 0.46120166778564453
# Epoch 63, Loss: 0.46120166778564453, Val Loss: 0.5087276697158813
# end of epoch.
# start of epoch 64
# Training loss (for one batch) at step 0: 0.4580618143081665
# Epoch 64, Loss: 0.4580618143081665, Val Loss: 0.48366060853004456
# end of epoch.
# start of epoch 65
# Training loss (for one batch) at step 0: 0.5645173788070679
# Epoch 65, Loss: 0.5645173788070679, Val Loss: 0.3914938271045685
# end of epoch.
# start of epoch 66
# Training loss (for one batch) at step 0: 0.5354036688804626
# Epoch 66, Loss: 0.5354036688804626, Val Loss: 0.47486382722854614
# end of epoch.
# start of epoch 67
# Training loss (for one batch) at step 0: 0.48223400115966797
# Epoch 67, Loss: 0.48223400115966797, Val Loss: 0.44417738914489746
# end of epoch.
# start of epoch 68
# Training loss (for one batch) at step 0: 0.5752511620521545
# Epoch 68, Loss: 0.5752511620521545, Val Loss: 0.4703682065010071
# end of epoch.
# start of epoch 69
# Training loss (for one batch) at step 0: 0.3969525992870331
# Epoch 69, Loss: 0.3969525992870331, Val Loss: 0.45915231108665466
# end of epoch.
# start of epoch 70
# Training loss (for one batch) at step 0: 0.4951551556587219
# Epoch 70, Loss: 0.4951551556587219, Val Loss: 0.5372950434684753
# end of epoch.
# start of epoch 71
# Training loss (for one batch) at step 0: 0.5170403718948364
# Epoch 71, Loss: 0.5170403718948364, Val Loss: 0.39257580041885376
# end of epoch.
# start of epoch 72
# Training loss (for one batch) at step 0: 0.5208519101142883
# Epoch 72, Loss: 0.5208519101142883, Val Loss: 0.38565951585769653
# end of epoch.
# start of epoch 73
# Training loss (for one batch) at step 0: 0.5376977324485779
# Epoch 73, Loss: 0.5376977324485779, Val Loss: 0.5000608563423157
# end of epoch.
# start of epoch 74
# Training loss (for one batch) at step 0: 0.5540956854820251
# Epoch 74, Loss: 0.5540956854820251, Val Loss: 0.4869617819786072
# end of epoch.
# start of epoch 75
# Training loss (for one batch) at step 0: 0.389097660779953
# Epoch 75, Loss: 0.389097660779953, Val Loss: 0.5714792013168335
# end of epoch.
# start of epoch 76
# Training loss (for one batch) at step 0: 0.52662193775177
# Epoch 76, Loss: 0.52662193775177, Val Loss: 0.4772428274154663
# end of epoch.
# start of epoch 77
# Training loss (for one batch) at step 0: 0.47741925716400146
# Epoch 77, Loss: 0.47741925716400146, Val Loss: 0.4890412986278534
# end of epoch.
# start of epoch 78
# Training loss (for one batch) at step 0: 0.4990209937095642
# Epoch 78, Loss: 0.4990209937095642, Val Loss: 0.4556843638420105
# end of epoch.
# start of epoch 79
# Training loss (for one batch) at step 0: 0.5158437490463257
# Epoch 79, Loss: 0.5158437490463257, Val Loss: 0.5496476888656616
# end of epoch.
# start of epoch 80
# Training loss (for one batch) at step 0: 0.4437708556652069
# Epoch 80, Loss: 0.4437708556652069, Val Loss: 0.4001777768135071
# end of epoch.
# start of epoch 81
# Training loss (for one batch) at step 0: 0.4967809319496155
# Epoch 81, Loss: 0.4967809319496155, Val Loss: 0.5143678784370422
# end of epoch.
# start of epoch 82
# Training loss (for one batch) at step 0: 0.4670211970806122
# Epoch 82, Loss: 0.4670211970806122, Val Loss: 0.5133017301559448
# end of epoch.
# start of epoch 83
# Training loss (for one batch) at step 0: 0.5115529894828796
# Epoch 83, Loss: 0.5115529894828796, Val Loss: 0.5478582382202148
# end of epoch.
# start of epoch 84
# Training loss (for one batch) at step 0: 0.49062827229499817
# Epoch 84, Loss: 0.49062827229499817, Val Loss: 0.45307472348213196
# end of epoch.
# start of epoch 85
# Training loss (for one batch) at step 0: 0.48031187057495117
# Epoch 85, Loss: 0.48031187057495117, Val Loss: 0.5731782913208008
# end of epoch.
# start of epoch 86
# Training loss (for one batch) at step 0: 0.33830177783966064
# Epoch 86, Loss: 0.33830177783966064, Val Loss: 0.5278561115264893
# end of epoch.
# start of epoch 87
# Training loss (for one batch) at step 0: 0.4988441467285156
# Epoch 87, Loss: 0.4988441467285156, Val Loss: 0.5755049586296082
# end of epoch.
# start of epoch 88
# Training loss (for one batch) at step 0: 0.5475529432296753
# Epoch 88, Loss: 0.5475529432296753, Val Loss: 0.4359440505504608
# end of epoch.
# start of epoch 89
# Training loss (for one batch) at step 0: 0.5030183792114258
# Epoch 89, Loss: 0.5030183792114258, Val Loss: 0.48261696100234985
# end of epoch.
# start of epoch 90
# Training loss (for one batch) at step 0: 0.46115681529045105
# Epoch 90, Loss: 0.46115681529045105, Val Loss: 0.584651529788971
# end of epoch.
# start of epoch 91
# Training loss (for one batch) at step 0: 0.526260256767273
# Epoch 91, Loss: 0.526260256767273, Val Loss: 0.47339415550231934
# end of epoch.
# start of epoch 92
# Training loss (for one batch) at step 0: 0.46511074900627136
# Epoch 92, Loss: 0.46511074900627136, Val Loss: 0.4828987717628479
# end of epoch.
# start of epoch 93
# Training loss (for one batch) at step 0: 0.5313739776611328
# Epoch 93, Loss: 0.5313739776611328, Val Loss: 0.5453634262084961
# end of epoch.
# start of epoch 94
# Training loss (for one batch) at step 0: 0.42980343103408813
# Epoch 94, Loss: 0.42980343103408813, Val Loss: 0.5605224967002869
# end of epoch.
# start of epoch 95
# Training loss (for one batch) at step 0: 0.5100942850112915
# Epoch 95, Loss: 0.5100942850112915, Val Loss: 0.44514113664627075
# end of epoch.
# start of epoch 96
# Training loss (for one batch) at step 0: 0.44460931420326233
# Epoch 96, Loss: 0.44460931420326233, Val Loss: 0.4647176265716553
# end of epoch.
# start of epoch 97
# Training loss (for one batch) at step 0: 0.43305835127830505
# Epoch 97, Loss: 0.43305835127830505, Val Loss: 0.6002220511436462
# end of epoch.
# start of epoch 98
# Training loss (for one batch) at step 0: 0.45551955699920654
# Epoch 98, Loss: 0.45551955699920654, Val Loss: 0.5264186859130859
# end of epoch.
# start of epoch 99
# Training loss (for one batch) at step 0: 0.4690915048122406
# Epoch 99, Loss: 0.4690915048122406, Val Loss: 0.410086989402771
# end of epoch.
# start of epoch 100
# Training loss (for one batch) at step 0: 0.4581485092639923
# Epoch 100, Loss: 0.4581485092639923, Val Loss: 0.4870257079601288
# end of epoch.
# start of epoch 101
# Training loss (for one batch) at step 0: 0.5501459240913391
# Epoch 101, Loss: 0.5501459240913391, Val Loss: 0.5619952082633972
# end of epoch.
# start of epoch 102
# Training loss (for one batch) at step 0: 0.45396947860717773
# Epoch 102, Loss: 0.45396947860717773, Val Loss: 0.47857236862182617
# end of epoch.
# start of epoch 103
# Training loss (for one batch) at step 0: 0.5048078894615173
# Epoch 103, Loss: 0.5048078894615173, Val Loss: 0.4358414113521576
# end of epoch.
# start of epoch 104
# Training loss (for one batch) at step 0: 0.4647451937198639
# Epoch 104, Loss: 0.4647451937198639, Val Loss: 0.43244653940200806
# end of epoch.
# start of epoch 105
# Training loss (for one batch) at step 0: 0.5257138609886169
# Epoch 105, Loss: 0.5257138609886169, Val Loss: 0.5725567936897278
# end of epoch.
# start of epoch 106
# Training loss (for one batch) at step 0: 0.4557155668735504
# Epoch 106, Loss: 0.4557155668735504, Val Loss: 0.4866972863674164
# end of epoch.
# start of epoch 107
# Training loss (for one batch) at step 0: 0.466632217168808
# Epoch 107, Loss: 0.466632217168808, Val Loss: 0.4198414087295532
# end of epoch.
# start of epoch 108
# Training loss (for one batch) at step 0: 0.40388572216033936
# Epoch 108, Loss: 0.40388572216033936, Val Loss: 0.40880346298217773
# end of epoch.
# start of epoch 109
# Training loss (for one batch) at step 0: 0.44005781412124634
# Epoch 109, Loss: 0.44005781412124634, Val Loss: 0.47003674507141113
# end of epoch.
# start of epoch 110
# Training loss (for one batch) at step 0: 0.4858703911304474
# Epoch 110, Loss: 0.4858703911304474, Val Loss: 0.4556584060192108
# end of epoch.
# start of epoch 111
# Training loss (for one batch) at step 0: 0.5236947536468506
# Epoch 111, Loss: 0.5236947536468506, Val Loss: 0.44007596373558044
# end of epoch.
# start of epoch 112
# Training loss (for one batch) at step 0: 0.5022910833358765
# Epoch 112, Loss: 0.5022910833358765, Val Loss: 0.49993592500686646
# end of epoch.
# start of epoch 113
# Training loss (for one batch) at step 0: 0.5495581030845642
# Epoch 113, Loss: 0.5495581030845642, Val Loss: 0.44392460584640503
# end of epoch.
# start of epoch 114
# Training loss (for one batch) at step 0: 0.4707641899585724
# Epoch 114, Loss: 0.4707641899585724, Val Loss: 0.536835789680481
# end of epoch.
# start of epoch 115
# Training loss (for one batch) at step 0: 0.5508490800857544
# Epoch 115, Loss: 0.5508490800857544, Val Loss: 0.48437824845314026
# end of epoch.
# start of epoch 116
# Training loss (for one batch) at step 0: 0.37907639145851135
# Epoch 116, Loss: 0.37907639145851135, Val Loss: 0.4284992516040802
# end of epoch.
# start of epoch 117
# Training loss (for one batch) at step 0: 0.47808754444122314
# Epoch 117, Loss: 0.47808754444122314, Val Loss: 0.5127130746841431
# end of epoch.
# start of epoch 118
# Training loss (for one batch) at step 0: 0.5357463359832764
# Epoch 118, Loss: 0.5357463359832764, Val Loss: 0.5120741724967957
# end of epoch.
# start of epoch 119
# Training loss (for one batch) at step 0: 0.4318302571773529
# Epoch 119, Loss: 0.4318302571773529, Val Loss: 0.4902646839618683
# end of epoch.
# start of epoch 120
# Training loss (for one batch) at step 0: 0.40254396200180054
# Epoch 120, Loss: 0.40254396200180054, Val Loss: 0.40595218539237976
# end of epoch.
# start of epoch 121
# Training loss (for one batch) at step 0: 0.5297353267669678
# Epoch 121, Loss: 0.5297353267669678, Val Loss: 0.4987376034259796
# end of epoch.
# start of epoch 122
# Training loss (for one batch) at step 0: 0.5227851271629333
# Epoch 122, Loss: 0.5227851271629333, Val Loss: 0.5141240358352661
# end of epoch.
# start of epoch 123
# Training loss (for one batch) at step 0: 0.5777808427810669
# Epoch 123, Loss: 0.5777808427810669, Val Loss: 0.583672821521759
# end of epoch.
# start of epoch 124
# Training loss (for one batch) at step 0: 0.4111538529396057
# Epoch 124, Loss: 0.4111538529396057, Val Loss: 0.5733217597007751
# end of epoch.
# start of epoch 125
# Training loss (for one batch) at step 0: 0.47491565346717834
# Epoch 125, Loss: 0.47491565346717834, Val Loss: 0.5129011273384094
# end of epoch.
# start of epoch 126
# Training loss (for one batch) at step 0: 0.5525668263435364
# Epoch 126, Loss: 0.5525668263435364, Val Loss: 0.5513275861740112
# end of epoch.
# start of epoch 127
# Training loss (for one batch) at step 0: 0.49192923307418823
# Epoch 127, Loss: 0.49192923307418823, Val Loss: 0.5406410098075867
# end of epoch.
# start of epoch 128
# Training loss (for one batch) at step 0: 0.4973302483558655
# Epoch 128, Loss: 0.4973302483558655, Val Loss: 0.45973676443099976
# end of epoch.
# start of epoch 129
# Training loss (for one batch) at step 0: 0.5017293691635132
# Epoch 129, Loss: 0.5017293691635132, Val Loss: 0.4903828501701355
# end of epoch.
# start of epoch 130
# Training loss (for one batch) at step 0: 0.502376914024353
# Epoch 130, Loss: 0.502376914024353, Val Loss: 0.5153467655181885
# end of epoch.
# start of epoch 131
# Training loss (for one batch) at step 0: 0.4642278552055359
# Epoch 131, Loss: 0.4642278552055359, Val Loss: 0.5703239440917969
# end of epoch.
# start of epoch 132
# Training loss (for one batch) at step 0: 0.44195422530174255
# Epoch 132, Loss: 0.44195422530174255, Val Loss: 0.4897497594356537
# end of epoch.
# start of epoch 133
# Training loss (for one batch) at step 0: 0.5072903633117676
# Epoch 133, Loss: 0.5072903633117676, Val Loss: 0.4662531018257141
# end of epoch.
# start of epoch 134
# Training loss (for one batch) at step 0: 0.47425147891044617
# Epoch 134, Loss: 0.47425147891044617, Val Loss: 0.5527052283287048
# end of epoch.
# start of epoch 135
# Training loss (for one batch) at step 0: 0.6168490648269653
# Epoch 135, Loss: 0.6168490648269653, Val Loss: 0.4840916097164154
# end of epoch.
# start of epoch 136
# Training loss (for one batch) at step 0: 0.39742138981819153
# Epoch 136, Loss: 0.39742138981819153, Val Loss: 0.48474738001823425
# end of epoch.
# start of epoch 137
# Training loss (for one batch) at step 0: 0.5002275109291077
# Epoch 137, Loss: 0.5002275109291077, Val Loss: 0.36142632365226746
# end of epoch.
# start of epoch 138
# Training loss (for one batch) at step 0: 0.4585976004600525
# Epoch 138, Loss: 0.4585976004600525, Val Loss: 0.5280097723007202
# end of epoch.
# start of epoch 139
# Training loss (for one batch) at step 0: 0.44836878776550293
# Epoch 139, Loss: 0.44836878776550293, Val Loss: 0.4449610114097595
# end of epoch.
# start of epoch 140
# Training loss (for one batch) at step 0: 0.5448358058929443
# Epoch 140, Loss: 0.5448358058929443, Val Loss: 0.48569393157958984
# end of epoch.
# start of epoch 141
# Training loss (for one batch) at step 0: 0.4959080219268799
# Epoch 141, Loss: 0.4959080219268799, Val Loss: 0.5332124829292297
# end of epoch.
# start of epoch 142
# Training loss (for one batch) at step 0: 0.462250292301178
# Epoch 142, Loss: 0.462250292301178, Val Loss: 0.5611528754234314
# end of epoch.
# start of epoch 143
# Training loss (for one batch) at step 0: 0.5182279348373413
# Epoch 143, Loss: 0.5182279348373413, Val Loss: 0.4275070130825043
# end of epoch.
# start of epoch 144
# Training loss (for one batch) at step 0: 0.40341681241989136
# Epoch 144, Loss: 0.40341681241989136, Val Loss: 0.4642099440097809
# end of epoch.
# start of epoch 145
# Training loss (for one batch) at step 0: 0.5323646664619446
# Epoch 145, Loss: 0.5323646664619446, Val Loss: 0.3617703914642334
# end of epoch.
# start of epoch 146
# Training loss (for one batch) at step 0: 0.44383561611175537
# Epoch 146, Loss: 0.44383561611175537, Val Loss: 0.5160815119743347
# end of epoch.
# start of epoch 147
# Training loss (for one batch) at step 0: 0.3817196488380432
# Epoch 147, Loss: 0.3817196488380432, Val Loss: 0.48414942622184753
# end of epoch.
# start of epoch 148
# Training loss (for one batch) at step 0: 0.4891972541809082
# Epoch 148, Loss: 0.4891972541809082, Val Loss: 0.4660921096801758
# end of epoch.
# start of epoch 149
# Training loss (for one batch) at step 0: 0.418556809425354
# Epoch 149, Loss: 0.418556809425354, Val Loss: 0.4123014807701111
# end of epoch.
# start of epoch 150
# Training loss (for one batch) at step 0: 0.3802849352359772
# Epoch 150, Loss: 0.3802849352359772, Val Loss: 0.4404027760028839
# end of epoch.
# start of epoch 151
# Training loss (for one batch) at step 0: 0.4234965443611145
# Epoch 151, Loss: 0.4234965443611145, Val Loss: 0.5042905807495117
# end of epoch.
# start of epoch 152
# Training loss (for one batch) at step 0: 0.4452180564403534
# Epoch 152, Loss: 0.4452180564403534, Val Loss: 0.5055826306343079
# end of epoch.
# start of epoch 153
# Training loss (for one batch) at step 0: 0.49446842074394226
# Epoch 153, Loss: 0.49446842074394226, Val Loss: 0.4356900453567505
# end of epoch.
# start of epoch 154
# Training loss (for one batch) at step 0: 0.47574904561042786
# Epoch 154, Loss: 0.47574904561042786, Val Loss: 0.3699393570423126
# end of epoch.
# start of epoch 155
# Training loss (for one batch) at step 0: 0.5340822339057922
# Epoch 155, Loss: 0.5340822339057922, Val Loss: 0.5008600354194641
# end of epoch.
# start of epoch 156
# Training loss (for one batch) at step 0: 0.43383604288101196
# Epoch 156, Loss: 0.43383604288101196, Val Loss: 0.5305761098861694
# end of epoch.
# start of epoch 157
# Training loss (for one batch) at step 0: 0.5201013088226318
# Epoch 157, Loss: 0.5201013088226318, Val Loss: 0.4508971571922302
# end of epoch.
# start of epoch 158
# Training loss (for one batch) at step 0: 0.544403612613678
# Epoch 158, Loss: 0.544403612613678, Val Loss: 0.512911856174469
# end of epoch.
# start of epoch 159
# Training loss (for one batch) at step 0: 0.4522298574447632
# Epoch 159, Loss: 0.4522298574447632, Val Loss: 0.4457029402256012
# end of epoch.
# start of epoch 160
# Training loss (for one batch) at step 0: 0.5630301237106323
# Epoch 160, Loss: 0.5630301237106323, Val Loss: 0.51612788438797
# end of epoch.
# start of epoch 161
# Training loss (for one batch) at step 0: 0.451201856136322
# Epoch 161, Loss: 0.451201856136322, Val Loss: 0.4600612223148346
# end of epoch.
# start of epoch 162
# Training loss (for one batch) at step 0: 0.39737170934677124
# Epoch 162, Loss: 0.39737170934677124, Val Loss: 0.42881157994270325
# end of epoch.
# start of epoch 163
# Training loss (for one batch) at step 0: 0.4796484708786011
# Epoch 163, Loss: 0.4796484708786011, Val Loss: 0.5052965879440308
# end of epoch.
# start of epoch 164
# Training loss (for one batch) at step 0: 0.5284420251846313
# Epoch 164, Loss: 0.5284420251846313, Val Loss: 0.5419691801071167
# end of epoch.
# start of epoch 165
# Training loss (for one batch) at step 0: 0.44527584314346313
# Epoch 165, Loss: 0.44527584314346313, Val Loss: 0.5894359946250916
# end of epoch.
# start of epoch 166
# Training loss (for one batch) at step 0: 0.48483940958976746
# Epoch 166, Loss: 0.48483940958976746, Val Loss: 0.4882361888885498
# end of epoch.
# start of epoch 167
# Training loss (for one batch) at step 0: 0.4105525016784668
# Epoch 167, Loss: 0.4105525016784668, Val Loss: 0.5738953948020935
# end of epoch.
# start of epoch 168
# Training loss (for one batch) at step 0: 0.5202683210372925
# Epoch 168, Loss: 0.5202683210372925, Val Loss: 0.5599968433380127
# end of epoch.
# start of epoch 169
# Training loss (for one batch) at step 0: 0.4054313898086548
# Epoch 169, Loss: 0.4054313898086548, Val Loss: 0.44388291239738464
# end of epoch.
# start of epoch 170
# Training loss (for one batch) at step 0: 0.5834378600120544
# Epoch 170, Loss: 0.5834378600120544, Val Loss: 0.4303080141544342
# end of epoch.
# start of epoch 171
# Training loss (for one batch) at step 0: 0.4972909390926361
# Epoch 171, Loss: 0.4972909390926361, Val Loss: 0.5445277690887451
# end of epoch.
# start of epoch 172
# Training loss (for one batch) at step 0: 0.49657729268074036
# Epoch 172, Loss: 0.49657729268074036, Val Loss: 0.3618723154067993
# end of epoch.
# start of epoch 173
# Training loss (for one batch) at step 0: 0.520129382610321
# Epoch 173, Loss: 0.520129382610321, Val Loss: 0.5094975233078003
# end of epoch.
# start of epoch 174
# Training loss (for one batch) at step 0: 0.5406347513198853
# Epoch 174, Loss: 0.5406347513198853, Val Loss: 0.3407149910926819
# end of epoch.
# start of epoch 175
# Training loss (for one batch) at step 0: 0.5518816113471985
# Epoch 175, Loss: 0.5518816113471985, Val Loss: 0.42787012457847595
# end of epoch.
# start of epoch 176
# Training loss (for one batch) at step 0: 0.5033969879150391
# Epoch 176, Loss: 0.5033969879150391, Val Loss: 0.5381730794906616
# end of epoch.
# start of epoch 177
# Training loss (for one batch) at step 0: 0.48076221346855164
# Epoch 177, Loss: 0.48076221346855164, Val Loss: 0.49043354392051697
# end of epoch.
# start of epoch 178
# Training loss (for one batch) at step 0: 0.5032222270965576
# Epoch 178, Loss: 0.5032222270965576, Val Loss: 0.4361500144004822
# end of epoch.
# start of epoch 179
# Training loss (for one batch) at step 0: 0.42396295070648193
# Epoch 179, Loss: 0.42396295070648193, Val Loss: 0.45760470628738403
# end of epoch.
# start of epoch 180
# Training loss (for one batch) at step 0: 0.47974449396133423
# Epoch 180, Loss: 0.47974449396133423, Val Loss: 0.40635859966278076
# end of epoch.
# start of epoch 181
# Training loss (for one batch) at step 0: 0.533750057220459
# Epoch 181, Loss: 0.533750057220459, Val Loss: 0.46493494510650635
# end of epoch.
# start of epoch 182
# Training loss (for one batch) at step 0: 0.5062961578369141
# Epoch 182, Loss: 0.5062961578369141, Val Loss: 0.5007968544960022
# end of epoch.
# start of epoch 183
# Training loss (for one batch) at step 0: 0.523074746131897
# Epoch 183, Loss: 0.523074746131897, Val Loss: 0.5662159323692322
# end of epoch.
# start of epoch 184
# Training loss (for one batch) at step 0: 0.44575363397598267
# Epoch 184, Loss: 0.44575363397598267, Val Loss: 0.575416624546051
# end of epoch.
# start of epoch 185
# Training loss (for one batch) at step 0: 0.4862578511238098
# Epoch 185, Loss: 0.4862578511238098, Val Loss: 0.4548054337501526
# end of epoch.
# start of epoch 186
# Training loss (for one batch) at step 0: 0.522618293762207
# Epoch 186, Loss: 0.522618293762207, Val Loss: 0.5030699372291565
# end of epoch.
# start of epoch 187
# Training loss (for one batch) at step 0: 0.3708505630493164
# Epoch 187, Loss: 0.3708505630493164, Val Loss: 0.3942575454711914
# end of epoch.
# start of epoch 188
# Training loss (for one batch) at step 0: 0.46518969535827637
# Epoch 188, Loss: 0.46518969535827637, Val Loss: 0.4419423043727875
# end of epoch.
# start of epoch 189
# Training loss (for one batch) at step 0: 0.3980619013309479
# Epoch 189, Loss: 0.3980619013309479, Val Loss: 0.4459337294101715
# end of epoch.
# start of epoch 190
# Training loss (for one batch) at step 0: 0.5737614035606384
# Epoch 190, Loss: 0.5737614035606384, Val Loss: 0.5810015201568604
# end of epoch.
# start of epoch 191
# Training loss (for one batch) at step 0: 0.42541831731796265
# Epoch 191, Loss: 0.42541831731796265, Val Loss: 0.4672681391239166
# end of epoch.
# start of epoch 192
# Training loss (for one batch) at step 0: 0.5374491810798645
# Epoch 192, Loss: 0.5374491810798645, Val Loss: 0.48562192916870117
# end of epoch.
# start of epoch 193
# Training loss (for one batch) at step 0: 0.4802311956882477
# Epoch 193, Loss: 0.4802311956882477, Val Loss: 0.5377570986747742
# end of epoch.
# start of epoch 194
# Training loss (for one batch) at step 0: 0.42779281735420227
# Epoch 194, Loss: 0.42779281735420227, Val Loss: 0.38806620240211487
# end of epoch.
# start of epoch 195
# Training loss (for one batch) at step 0: 0.4763513505458832
# Epoch 195, Loss: 0.4763513505458832, Val Loss: 0.46058350801467896
# end of epoch.
# start of epoch 196
# Training loss (for one batch) at step 0: 0.5268334746360779
# Epoch 196, Loss: 0.5268334746360779, Val Loss: 0.5445787906646729
# end of epoch.
# start of epoch 197
# Training loss (for one batch) at step 0: 0.5127484202384949
# Epoch 197, Loss: 0.5127484202384949, Val Loss: 0.5736172199249268
# end of epoch.
# start of epoch 198
# Training loss (for one batch) at step 0: 0.5505674481391907
# Epoch 198, Loss: 0.5505674481391907, Val Loss: 0.5132521986961365
# end of epoch.
# start of epoch 199
# Training loss (for one batch) at step 0: 0.4330838620662689
# Epoch 199, Loss: 0.4330838620662689, Val Loss: 0.5379854440689087
# end of epoch.
# start of epoch 200
# Training loss (for one batch) at step 0: 0.5290811061859131
# Epoch 200, Loss: 0.5290811061859131, Val Loss: 0.44653066992759705
# end of epoch.
# Checkpoint directory :  checkpoints/CNNgeo/200507_regressor_filter_size_up
# Tensorboard log directory :  logs/CNNgeo/200507_regressor_filter_size_up

# %%
model.summary()
# Out:
# Model: "cnn_geo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature__extractor (Feature_ multiple                  1735488
# _________________________________________________________________
# correlation_network (Correla multiple                  0
# _________________________________________________________________
# spatial_transformer_regresso multiple                  875250
# =================================================================
# Total params: 2,610,738
# Trainable params: 2,610,546
# Non-trainable params: 192
# _________________________________________________________________

# %% [markdown]
# # 3. Debug

# %%
datasets = load_data(['train'], config)
ds = datasets['train'].batch(1)
# Out:
# train dataset amount : 1

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
#image_B_hat = np.ones([1, 64, 64, 3])
pred, score = model(image_A, image_B)

# %%
print("parameter shape", pred.shape)
print("score shape", score.shape)
print(image_A.shape)
# Out:
# parameter shape (1, 9, 2)
# score shape (1, 16, 16, 16, 16)
# (1, 64, 64, 3)

# %% [markdown]
# ## 3.1. 입력 영상에 따른 모델 추정 확인

# %% [markdown]
# ### case 1) 임의의 기하관계를 갖는 영상 쌍 (image A, image B)

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred1 = pred.copy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[ 0.02291393  0.16441026]
#   [ 0.14782949  0.15543643]
#   [-0.12268796 -0.00883341]
#   [ 0.15083037  0.10863929]
#   [ 0.02280626 -0.03942738]
#   [ 0.04691606  0.12204056]
#   [ 0.16472816 -0.19436288]
#   [-0.12579012  0.18323751]
#   [-0.15466824  0.0971684 ]]] and
#  pred : [[[-0.00340199 -0.00029874]
#   [-0.00251736 -0.00226504]
#   [ 0.00131492 -0.00710203]
#   [-0.00584347  0.0082603 ]
#   [ 0.00400248  0.00445973]
#   [ 0.0045121  -0.00274657]
#   [-0.00816929  0.00158079]
#   [ 0.00496169  0.00578323]
#   [-0.00548967  0.00880687]]]
# loss : [0.14594148]

# %% [markdown]
# ### case 2) 임의의 다른 기하관계를 갖는 영상 쌍 (image A, image B)

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred2 = pred.copy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.18684964  0.18294297]
#   [-0.04890366  0.14924188]
#   [-0.19890462 -0.11518369]
#   [-0.08419662 -0.05003095]
#   [ 0.16027002  0.02840371]
#   [-0.0390625  -0.00213156]
#   [ 0.04659858 -0.14635877]
#   [ 0.04882169  0.01984181]
#   [ 0.00141268  0.16999064]]] and
#  pred : [[[-0.00352923 -0.00014176]
#   [-0.00238805 -0.00216887]
#   [ 0.00131273 -0.00710508]
#   [-0.00599332  0.00806227]
#   [ 0.00356564  0.00457663]
#   [ 0.00433225 -0.00257293]
#   [-0.00796913  0.00167577]
#   [ 0.00495961  0.0059287 ]
#   [-0.00541328  0.00868221]]]
# loss : [0.11677873]

# %% [markdown]
# ### case 3) Image A와 연관 없는 image B(백색 사진)의 영상 쌍

# %%
image_B = np.ones([1, 64, 64, 3])
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred3 = pred.copy()
# Out:
# WARNING:tensorflow:Layer feature__extractor is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.18684964  0.18294297]
#   [-0.04890366  0.14924188]
#   [-0.19890462 -0.11518369]
#   [-0.08419662 -0.05003095]
#   [ 0.16027002  0.02840371]
#   [-0.0390625  -0.00213156]
#   [ 0.04659858 -0.14635877]
#   [ 0.04882169  0.01984181]
#   [ 0.00141268  0.16999064]]] and
#  pred : [[[-0.00350417 -0.00027221]
#   [-0.00236714 -0.00226336]
#   [ 0.00118624 -0.00703663]
#   [-0.00598961  0.00820033]
#   [ 0.00381567  0.00453796]
#   [ 0.00444574 -0.00263948]
#   [-0.00822114  0.00153671]
#   [ 0.00489958  0.00577509]
#   [-0.00559039  0.00867506]]]
# loss : [0.11678]

# %%
print(pred1, "\n", pred2, "\n", pred3)
# Out:
# [[[-0.00340199 -0.00029874]
#   [-0.00251736 -0.00226504]
#   [ 0.00131492 -0.00710203]
#   [-0.00584347  0.0082603 ]
#   [ 0.00400248  0.00445973]
#   [ 0.0045121  -0.00274657]
#   [-0.00816929  0.00158079]
#   [ 0.00496169  0.00578323]
#   [-0.00548967  0.00880687]]]
#  [[[-0.00352923 -0.00014176]
#   [-0.00238805 -0.00216887]
#   [ 0.00131273 -0.00710508]
#   [-0.00599332  0.00806227]
#   [ 0.00356564  0.00457663]
#   [ 0.00433225 -0.00257293]
#   [-0.00796913  0.00167577]
#   [ 0.00495961  0.0059287 ]
#   [-0.00541328  0.00868221]]]
#  [[[-0.00350417 -0.00027221]
#   [-0.00236714 -0.00226336]
#   [ 0.00118624 -0.00703663]
#   [-0.00598961  0.00820033]
#   [ 0.00381567  0.00453796]
#   [ 0.00444574 -0.00263948]
#   [-0.00822114  0.00153671]
#   [ 0.00489958  0.00577509]
#   [-0.00559039  0.00867506]]]

# %% [markdown]
# case 1)와 case 2)는 동일한 영상을 다른 기하관계를 사용하여 두 개의 영상쌍(image pair)을 만든 경우를 말한다. 모델이 정상적이라면 각 영상쌍의 기하관계를 추정할 수 있을 것이다. 그러나 두 영상쌍이 다른 기하관계를 갖음에도 동일한 모션파라미터를 추정하였다. case 3)에서는 전혀 연관 없는 영상을 image B로 사용하였다. image B는 어떤 특징 정보도 없는 백색 사진임에도 불구하고 모델은 case 1)과 case 2)에서와 같은 모션파라미터를 추정하였다.

# %%
model.summary()
# Out:
# Model: "cnn_geo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature__extractor (Feature_ multiple                  1735488
# _________________________________________________________________
# correlation_network (Correla multiple                  0
# _________________________________________________________________
# spatial_transformer_regresso multiple                  875250
# =================================================================
# Total params: 2,610,738
# Trainable params: 2,610,546
# Non-trainable params: 192
# _________________________________________________________________

# %% [markdown]
# ## 3.2 Correlation 분포에 따른 Regressor 예측

# %% [markdown]
# 3.1의 case 1, 2, 3에서 Regressor은 같은 모션파라미터를 예측했다. 명확한 이유를 파악하기 위해 입력 correlation(matching scores)를 제어하며 spatial parameter regressor의 출력을 분석했다.

# %%
x = np.zeros([1, 16, 16, 16, 16]) # all correlations are zero
y = model.layers[2](x)
print(y)
# Out:
# WARNING:tensorflow:Layer spatial_transformer_regressor is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# tf.Tensor(
# [[-0.00350417 -0.00027221 -0.00236714 -0.00226336  0.00118624 -0.00703663
#   -0.00598961  0.00820033  0.00381567  0.00453796  0.00444574 -0.00263948
#   -0.00822114  0.00153671  0.00489958  0.00577509 -0.00559039  0.00867506]], shape=(1, 18), dtype=float32)

# %%
x = np.ones([1, 16, 16, 16, 16]) # all correlations are one
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[-0.00350417 -0.00027221 -0.00236714 -0.00226336  0.00118624 -0.00703663
#   -0.00598961  0.00820033  0.00381567  0.00453796  0.00444574 -0.00263948
#   -0.00822114  0.00153671  0.00489958  0.00577509 -0.00559039  0.00867506]], shape=(1, 18), dtype=float32)

# %%
x = np.random.normal(loc=0.5, scale=0.0, size=[1, 16, 16, 16, 16])
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[-0.00350417 -0.00027221 -0.00236714 -0.00226336  0.00118624 -0.00703663
#   -0.00598961  0.00820033  0.00381567  0.00453796  0.00444574 -0.00263948
#   -0.00822114  0.00153671  0.00489958  0.00577509 -0.00559039  0.00867506]], shape=(1, 18), dtype=float32)

# %%
x = np.random.normal(loc=0.5, scale=0.3, size=[1, 16, 16, 16, 16])
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[-0.00379181  0.0013846  -0.00361848 -0.00070807 -0.00246227 -0.00867656
#   -0.00345001  0.01026055  0.00699276  0.00450982  0.00885163 -0.0008094
#   -0.01597588  0.00283656  0.00609372  0.00242366 -0.00568608  0.01069219]], shape=(1, 18), dtype=float32)

# %% [markdown]
# 위 실험의 결과를 토대로 확인할 수 있는 것은 regressor의 출력은 입력 correlation의 크기가 아닌 편차에 따라 달라진다는 것이다. correlation의 분포의 표준편차를 변화시키며 출력의 변화 정도를 추정해주었다.

# %%
_range = np.linspace(0, 1.0, 50)
print(_range)
# Out:
# [0.         0.02040816 0.04081633 0.06122449 0.08163265 0.10204082
#  0.12244898 0.14285714 0.16326531 0.18367347 0.20408163 0.2244898
#  0.24489796 0.26530612 0.28571429 0.30612245 0.32653061 0.34693878
#  0.36734694 0.3877551  0.40816327 0.42857143 0.44897959 0.46938776
#  0.48979592 0.51020408 0.53061224 0.55102041 0.57142857 0.59183673
#  0.6122449  0.63265306 0.65306122 0.67346939 0.69387755 0.71428571
#  0.73469388 0.75510204 0.7755102  0.79591837 0.81632653 0.83673469
#  0.85714286 0.87755102 0.89795918 0.91836735 0.93877551 0.95918367
#  0.97959184 1.        ]

# %%
variations_via_std = []
variations_via_mean = []
for std in _range:
    variations = []
    for i in range(1000):
        x = np.random.normal(loc=0.5, scale=std, size=[1, 16, 16, 16, 16])
        _y = model.layers[2](x)
        variations.append(_y)
    variations_via_std.append(np.sum(np.std(np.array(variations), axis = 0)))
    
for mean in _range:
    variations = []
    for i in range(1000):
        x = np.random.normal(loc=mean, scale=0.1, size=[1, 16, 16, 16, 16])
        _y = model.layers[2](x)
        variations.append(_y)
    variations_via_mean.append(np.sum(np.std(np.array(variations), axis = 0)))

# %%
variations
# Out:
# [<tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
# ...
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.00350417, -0.00027221, -0.00236714, -0.00226336,  0.00118624,
#          -0.00703663, -0.00598961,  0.00820033,  0.00381567,  0.00453796,
#           0.00444574, -0.00263948, -0.00822114,  0.00153671,  0.00489958,
#           0.00577509, -0.00559039,  0.00867506]], dtype=float32)>]

# %%
plt.ylabel("variations of motion parameters")
plt.xlabel("via sigma, mean. \n correlations are sampled from N(0.5, sigma), N(mean, 0.1)")
plt.plot(_range, variations_via_std, label='via sigma')
plt.plot(_range, variations_via_mean, label='via mean')
plt.legend()
plt.show()

# %% [markdown]
# 1. VGG16을 통한 correlations
# 2. 시각화 방식 개선
# 3. tentative penalty

# %% [markdown]
# ## b. 특징추출기의 정상 동작 검증

# %%
np.set_printoptions(formatter = {"float_kind" : lambda x : "{0:0.4f}".format(x)} )
#np.set_printoptions(formatter={'float_kind': lambda x: "{0:0.3f}".format(x)})

# %% [markdown]
# ### 동일 영상에 대한 correlation

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_A)

score = score.numpy()[0]
parameters = parameters[0]
image_A = image_A[0]
image_B = image_B[0]

print(score.shape, parameters.shape, image_A.shape)
# Out:
# (16, 16, 16, 16) (9, 2) (64, 64, 3)

# %%
def get_matching_grid_from_B(parameters, center_point):
    src_points = np.array([[0.0, 0.0], [0.5, 0.0], [1.0, 0.0],
                                   [0.0, 0.5], [0.5, 0.5], [1.0, 0.5],
                                   [0.0, 1.0], [0.5, 1.0], [1.0, 1.0]])

    dst_points = src_points +parameters

    theta = tps.tps_theta_from_points(src_points, dst_points, reduced=True)
    dshape = (64, 64)
    grid = tps.tps_grid(theta, dst_points, dshape)
    mapx, mapy = tps.tps_grid_to_remap(grid, (64, 64))
    points = np.concatenate([mapy[:,:,np.newaxis], mapx[:,:,np.newaxis]], axis=2)
    #print("points :", points)
    center_point = np.array(center_point)
    #print("grid center : ", center_point)
    center_point = center_point[np.newaxis, np.newaxis, :]
    distance = np.sum(np.power((points - center_point), 2), axis=2)
    #print("distance : ", distance)
    ri, ci = distance.argmin()//distance.shape[1], distance.argmin()%distance.shape[1]
    return (ri, ci)

# %%
def score_test(grid_coord, score, parameters, images, grid_shape=(16,16)):
    image_A, image_B = images
    score = score[grid_coord[0], grid_coord[1]]
    H, W, C = image_A.shape
    grid_size = H/grid_shape[0], W/grid_shape[1]

    start_pix_h = int(grid_size[0]*grid_coord[0])
    end_pix_h = int(grid_size[0]*(1+grid_coord[0]))
    start_pix_w = int(grid_size[1]*grid_coord[1])
    end_pix_w = int(grid_size[1]*(1+grid_coord[1]))
    
    drawn_grid_image_A = image_A.copy()
    drawn_grid_image_A[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)   
    
    expected_drawn_grid_image_B = image_B.copy()
    grid_center_A = (int(start_pix_h+grid_size[0]/2), int(start_pix_w+grid_size[1]/2))
    grid_center_B = get_matching_grid_from_B(parameters, grid_center_A)
    start_pix_h = int(grid_center_B[0] - grid_size[0]/2)
    start_pix_w = int(grid_center_B[1] - grid_size[1]/2)
    end_pix_h = int(grid_center_B[0] + grid_size[0]/2)
    end_pix_w = int(grid_center_B[1] + grid_size[1]/2)
    expected_drawn_grid_image_B[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)
    
    drawn_grid_image_B = image_B.copy()
    max_correlation_grid_index = score.argmax()//score.shape[1], score.argmax()%score.shape[1]
    start_pix_h = int(grid_size[0]*max_correlation_grid_index[0])
    end_pix_h = int(grid_size[0]*(1+max_correlation_grid_index[0]))
    start_pix_w = int(grid_size[1]*max_correlation_grid_index[1])
    end_pix_w = int(grid_size[1]*(1+max_correlation_grid_index[1]))

    drawn_grid_image_B[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)
    
    print("top 10 correlation values in descending : ", np.sort(score.flatten())[::-1][:10])
    print("standard deviation : {}".format(np.std(score)))
    return drawn_grid_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, score

# %%
drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, patch_score= score_test(grid_coord=(5,10), 
                                                                            score=score, 
                                                                            parameters=np.zeros([9,2]), 
                                                                            images=(image_A, image_A))
# Out:
# top 10 correlation values in descending :  [0.1112 0.1033 0.1014 0.0991 0.0969 0.0956 0.0942 0.0937 0.0930 0.0893]
# standard deviation : 0.01695752516388893

# %%
# n, bins, patches = plt.hist(patch_score, bins=10, density=False, facecolor='blue', alpha=0.5)
# plt.xlabel('X bins')
# plt.ylabel('Frequency')
# plt.title('Histogram of correlations')


fig = plt.figure()

ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)
ax1.imshow(drawn_image_A)
ax2.imshow(expected_drawn_grid_image_B)
ax3.imshow(drawn_grid_image_B)
plt.show()
n, bins, patches = plt.hist(patch_score, bins=5, density=False, facecolor='blue', alpha=0.5)
plt.show()

# %%
drawn_image_A.shape
expected_drawn_grid_image_B.shape
drawn_grid_image_B.shape
# Out:
# (64, 64, 3)

# %% [markdown]
# ### b.1 ) 동일한 사진의 경우

# %%
for i in range(16):
    drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, patch_score= score_test(grid_coord=(i,i), 
                                                                                score=score, 
                                                                                parameters=np.zeros([9,2]), 
                                                                                images=(image_A, image_A))   
    fig = plt.figure()
    
    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)

    ax1.imshow(drawn_image_A)
    ax2.imshow(expected_drawn_grid_image_B)
    ax3.imshow(drawn_grid_image_B)

    plt.show()
    n, bins, patches = plt.hist(patch_score, bins=5, density=False, facecolor='blue', alpha=0.5)
    plt.axis([0.0, 0.070, 0, 20])
    plt.show()
# Out:
# top 10 correlation values in descending :  [0.1160 0.1014 0.1008 0.0995 0.0993 0.0974 0.0960 0.0955 0.0953 0.0947]
# standard deviation : 0.022102115675807
# top 10 correlation values in descending :  [0.0920 0.0897 0.0894 0.0892 0.0890 0.0882 0.0879 0.0877 0.0876 0.0873]
# standard deviation : 0.02439359948039055
# top 10 correlation values in descending :  [0.0919 0.0901 0.0899 0.0898 0.0894 0.0893 0.0875 0.0870 0.0861 0.0861]
# standard deviation : 0.021598340943455696
# top 10 correlation values in descending :  [0.1065 0.1053 0.1043 0.1032 0.1031 0.1030 0.1016 0.0975 0.0956 0.0956]
# standard deviation : 0.019337322562932968
# top 10 correlation values in descending :  [0.1279 0.1253 0.1237 0.1231 0.1226 0.1219 0.1181 0.1171 0.1143 0.1140]
# standard deviation : 0.027998676523566246
# top 10 correlation values in descending :  [0.1340 0.1284 0.1260 0.1257 0.1239 0.1233 0.1231 0.1215 0.1192 0.1191]
# standard deviation : 0.0312972329556942
# top 10 correlation values in descending :  [0.1496 0.1334 0.1250 0.1223 0.1215 0.1118 0.1097 0.1092 0.1070 0.1047]
# standard deviation : 0.02605181559920311
# top 10 correlation values in descending :  [0.3142 0.2604 0.2490 0.2098 0.1840 0.1830 0.1797 0.1790 0.1617 0.1587]
# standard deviation : 0.04605048522353172
# top 10 correlation values in descending :  [0.2573 0.2289 0.1956 0.1955 0.1914 0.1907 0.1813 0.1560 0.1557 0.1552]
# standard deviation : 0.03802593797445297
# top 10 correlation values in descending :  [0.1529 0.1440 0.1356 0.1351 0.1318 0.1275 0.1250 0.1232 0.1214 0.1191]
# standard deviation : 0.027990078553557396
# top 10 correlation values in descending :  [0.1203 0.1160 0.1154 0.1147 0.1133 0.1122 0.1115 0.1113 0.1107 0.1083]
# standard deviation : 0.026475971564650536
# top 10 correlation values in descending :  [0.1160 0.1138 0.1123 0.1123 0.1122 0.1119 0.1108 0.1096 0.1092 0.1090]
# standard deviation : 0.026758352294564247
# top 10 correlation values in descending :  [0.1156 0.1134 0.1133 0.1129 0.1123 0.1122 0.1115 0.1090 0.1084 0.1078]
# standard deviation : 0.027036134153604507
# top 10 correlation values in descending :  [0.1128 0.1105 0.1102 0.1091 0.1090 0.1083 0.1070 0.1064 0.1061 0.1057]
# standard deviation : 0.02640659362077713
# top 10 correlation values in descending :  [0.1090 0.1052 0.1041 0.1028 0.1010 0.0983 0.0980 0.0977 0.0972 0.0964]
# standard deviation : 0.025021910667419434
# top 10 correlation values in descending :  [0.1405 0.1254 0.1195 0.1139 0.1132 0.1039 0.1031 0.1013 0.1005 0.0998]
# standard deviation : 0.023511292412877083

# %% [markdown]
# ### b.2 ) 다른 사진의 경우

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_A)

score = score.numpy()[0]
parameters = parameters[0]
image_A = image_A[0]
image_B = image_B[0]

print(score.shape, parameters.shape, image_A.shape)
# Out:
# (16, 16, 16, 16) (9, 2) (64, 64, 3)

# %%
for i in range(16):
    drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, patch_score = score_test(grid_coord=(i,i), 
                                                                                score=score, 
                                                                                parameters=parameters, 
                                                                                images=(image_A, image_B))   
    fig = plt.figure()

    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)

    ax1.imshow(drawn_image_A)
    ax2.imshow(expected_drawn_grid_image_B)
    ax3.imshow(drawn_grid_image_B)

    plt.show()
    n, bins, patches = plt.hist(patch_score, bins=5, density=False, facecolor='blue', alpha=0.5)
    plt.axis([0.055, 0.070, 0, 30])
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.1134 0.0995 0.0986 0.0974 0.0970 0.0957 0.0949 0.0948 0.0944 0.0942]
# standard deviation : 0.021509556099772453
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0890 0.0863 0.0860 0.0860 0.0859 0.0855 0.0850 0.0848 0.0845 0.0845]
# standard deviation : 0.02402397058904171
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0910 0.0892 0.0887 0.0883 0.0877 0.0874 0.0857 0.0844 0.0829 0.0827]
# standard deviation : 0.020982423797249794
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.1118 0.1106 0.1090 0.1078 0.1073 0.1071 0.1067 0.1062 0.1053 0.1050]
# standard deviation : 0.020127762109041214
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.1265 0.1240 0.1239 0.1227 0.1226 0.1225 0.1225 0.1186 0.1184 0.1174]
# standard deviation : 0.028996707871556282
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.1299 0.1266 0.1264 0.1239 0.1239 0.1233 0.1216 0.1209 0.1192 0.1174]
# standard deviation : 0.02893618308007717
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.1200 0.1161 0.1157 0.1137 0.1134 0.1134 0.1116 0.1096 0.1083 0.1077]
# standard deviation : 0.02459721267223358
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.1214 0.1141 0.1063 0.1060 0.1051 0.1048 0.0977 0.0933 0.0918 0.0911]
# standard deviation : 0.019478196278214455
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.1047 0.0969 0.0944 0.0912 0.0902 0.0891 0.0891 0.0891 0.0882 0.0864]
# standard deviation : 0.020244471728801727
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0930 0.0909 0.0899 0.0886 0.0886 0.0882 0.0878 0.0874 0.0871 0.0871]
# standard deviation : 0.024956634268164635
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0915 0.0907 0.0899 0.0895 0.0895 0.0894 0.0892 0.0885 0.0880 0.0872]
# standard deviation : 0.025696992874145508
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0915 0.0912 0.0908 0.0893 0.0892 0.0891 0.0885 0.0880 0.0872 0.0869]
# standard deviation : 0.02608472667634487
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0914 0.0910 0.0898 0.0895 0.0892 0.0885 0.0883 0.0875 0.0872 0.0865]
# standard deviation : 0.025896698236465454
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0900 0.0882 0.0881 0.0877 0.0874 0.0870 0.0864 0.0857 0.0856 0.0853]
# standard deviation : 0.024753734469413757
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0920 0.0879 0.0870 0.0865 0.0851 0.0841 0.0840 0.0840 0.0839 0.0839]
# standard deviation : 0.024063263088464737
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.1179 0.1055 0.1024 0.1011 0.1004 0.0996 0.0984 0.0971 0.0965 0.0934]
# standard deviation : 0.021510113030672073
