# %%
import os, sys
root_path = os.path.abspath('.').split('jupyters')[0]
sys.path.append(root_path)

# %%
import json
import argparse
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

from data_loader import load_data
from models.cnn_geo import CNN_geo

from debug_tools import data, train, visualize
from utils import image
import geo_transform as tps
import CNNgeo_debug

# %% [markdown]
# # 1. Read configuration file

# %%
with open('../overfit.json') as fp:
    config = json.load(fp)
split = 'val'

# %%
print(config)
# Out:
# {'exp_desc': '200507_regressor_filter_size_up', 'dataset_name': 'mini_imagenet', 'data_dir': '/home/files/datasets/mini_imagenet', 'image_shape': [64, 64, 3], 'model_name': 'CNNgeo', 'backbone': 'prototypical_network', 'data': {'method': 'synthesized_pair', 'tps_random_rate': 0.2, 'pad_ratio': 0.2}, 'ckpt': {'save_type': 'latest', 'max_to_keep': 10}, 'train': {'n_examples': 1, 'learning_rate': 0.0001, 'batch_size': 1, 'epochs': 200, 'print_step': 10}, 'val': {'n_examples': 1, 'batch_size': 1}, 'test': {'n_examples': -1, 'batch_size': 128}}

# %%
print(config['train'])
# Out:
# {'n_examples': 1, 'learning_rate': 0.0001, 'batch_size': 1, 'epochs': 200, 'print_step': 10}

# %%
print("backbone : ", config['backbone'])
print("n_examples : ", config['train']['n_examples'])
print("learning_rate : ", config['train']['learning_rate'])
print("batch_size : ", config['train']['batch_size'])
print("epoch num : ", config['train']['epochs'])
# Out:
# backbone :  prototypical_network
# n_examples :  1
# learning_rate :  0.0001
# batch_size :  1
# epoch num :  200

# %% [markdown]
# # 2. Train model on the config parameters

# %%
model = CNNgeo_debug.train(config)
# Out:
# train dataset amount : 1
# val dataset amount : 1
# start of epoch 1
# Training loss (for one batch) at step 0: 0.54694664478302
# Epoch 1, Loss: 0.54694664478302, Val Loss: 0.5199554562568665
# end of epoch.
# start of epoch 2
# Training loss (for one batch) at step 0: 0.6056487560272217
# Epoch 2, Loss: 0.6056487560272217, Val Loss: 0.5380284190177917
# end of epoch.
# start of epoch 3
# Training loss (for one batch) at step 0: 0.6157944798469543
# Epoch 3, Loss: 0.6157944798469543, Val Loss: 0.4795549213886261
# end of epoch.
# start of epoch 4
# Training loss (for one batch) at step 0: 0.5787988305091858
# Epoch 4, Loss: 0.5787988305091858, Val Loss: 0.5746862292289734
# end of epoch.
# start of epoch 5
# Training loss (for one batch) at step 0: 0.6526102423667908
# Epoch 5, Loss: 0.6526102423667908, Val Loss: 0.4679897427558899
# end of epoch.
# start of epoch 6
# Training loss (for one batch) at step 0: 0.5307285189628601
# Epoch 6, Loss: 0.5307285189628601, Val Loss: 0.3776545226573944
# end of epoch.
# start of epoch 7
# Training loss (for one batch) at step 0: 0.48292630910873413
# Epoch 7, Loss: 0.48292630910873413, Val Loss: 0.5068355202674866
# end of epoch.
# start of epoch 8
# Training loss (for one batch) at step 0: 0.5486197471618652
# Epoch 8, Loss: 0.5486197471618652, Val Loss: 0.5820777416229248
# end of epoch.
# start of epoch 9
# Training loss (for one batch) at step 0: 0.5778759121894836
# Epoch 9, Loss: 0.5778759121894836, Val Loss: 0.43911227583885193
# end of epoch.
# start of epoch 10
# Training loss (for one batch) at step 0: 0.5791380405426025
# Epoch 10, Loss: 0.5791380405426025, Val Loss: 0.47065719962120056
# end of epoch.
# start of epoch 11
# Training loss (for one batch) at step 0: 0.5432131886482239
# Epoch 11, Loss: 0.5432131886482239, Val Loss: 0.5524713397026062
# end of epoch.
# start of epoch 12
# Training loss (for one batch) at step 0: 0.47519615292549133
# Epoch 12, Loss: 0.47519615292549133, Val Loss: 0.5496025085449219
# end of epoch.
# start of epoch 13
# Training loss (for one batch) at step 0: 0.49348318576812744
# Epoch 13, Loss: 0.49348318576812744, Val Loss: 0.6336485147476196
# end of epoch.
# start of epoch 14
# Training loss (for one batch) at step 0: 0.5835795402526855
# Epoch 14, Loss: 0.5835795402526855, Val Loss: 0.5740704536437988
# end of epoch.
# start of epoch 15
# Training loss (for one batch) at step 0: 0.5796908736228943
# Epoch 15, Loss: 0.5796908736228943, Val Loss: 0.48067617416381836
# end of epoch.
# start of epoch 16
# Training loss (for one batch) at step 0: 0.3996149003505707
# Epoch 16, Loss: 0.3996149003505707, Val Loss: 0.5195478796958923
# end of epoch.
# start of epoch 17
# Training loss (for one batch) at step 0: 0.45345717668533325
# Epoch 17, Loss: 0.45345717668533325, Val Loss: 0.4805622398853302
# end of epoch.
# start of epoch 18
# Training loss (for one batch) at step 0: 0.6053553819656372
# Epoch 18, Loss: 0.6053553819656372, Val Loss: 0.478145033121109
# end of epoch.
# start of epoch 19
# Training loss (for one batch) at step 0: 0.5214177370071411
# Epoch 19, Loss: 0.5214177370071411, Val Loss: 0.43074101209640503
# end of epoch.
# start of epoch 20
# Training loss (for one batch) at step 0: 0.43029138445854187
# Epoch 20, Loss: 0.43029138445854187, Val Loss: 0.5943552851676941
# end of epoch.
# start of epoch 21
# Training loss (for one batch) at step 0: 0.5270421504974365
# Epoch 21, Loss: 0.5270421504974365, Val Loss: 0.5387476682662964
# end of epoch.
# start of epoch 22
# Training loss (for one batch) at step 0: 0.48553523421287537
# Epoch 22, Loss: 0.48553523421287537, Val Loss: 0.5331254601478577
# end of epoch.
# start of epoch 23
# Training loss (for one batch) at step 0: 0.5243309140205383
# Epoch 23, Loss: 0.5243309140205383, Val Loss: 0.42694172263145447
# end of epoch.
# start of epoch 24
# Training loss (for one batch) at step 0: 0.45474109053611755
# Epoch 24, Loss: 0.45474109053611755, Val Loss: 0.5160195827484131
# end of epoch.
# start of epoch 25
# Training loss (for one batch) at step 0: 0.5202633142471313
# Epoch 25, Loss: 0.5202633142471313, Val Loss: 0.43300092220306396
# end of epoch.
# start of epoch 26
# Training loss (for one batch) at step 0: 0.5385153293609619
# Epoch 26, Loss: 0.5385153293609619, Val Loss: 0.5556387305259705
# end of epoch.
# start of epoch 27
# Training loss (for one batch) at step 0: 0.49151402711868286
# Epoch 27, Loss: 0.49151402711868286, Val Loss: 0.4704383313655853
# end of epoch.
# start of epoch 28
# Training loss (for one batch) at step 0: 0.4285728335380554
# Epoch 28, Loss: 0.4285728335380554, Val Loss: 0.4041898548603058
# end of epoch.
# start of epoch 29
# Training loss (for one batch) at step 0: 0.5692600011825562
# Epoch 29, Loss: 0.5692600011825562, Val Loss: 0.5320484042167664
# end of epoch.
# start of epoch 30
# Training loss (for one batch) at step 0: 0.49162957072257996
# Epoch 30, Loss: 0.49162957072257996, Val Loss: 0.5564960241317749
# end of epoch.
# start of epoch 31
# Training loss (for one batch) at step 0: 0.50534987449646
# Epoch 31, Loss: 0.50534987449646, Val Loss: 0.5328788161277771
# end of epoch.
# start of epoch 32
# Training loss (for one batch) at step 0: 0.4133797883987427
# Epoch 32, Loss: 0.4133797883987427, Val Loss: 0.5069152116775513
# end of epoch.
# start of epoch 33
# Training loss (for one batch) at step 0: 0.521783173084259
# Epoch 33, Loss: 0.521783173084259, Val Loss: 0.43055102229118347
# end of epoch.
# start of epoch 34
# Training loss (for one batch) at step 0: 0.5753503441810608
# Epoch 34, Loss: 0.5753503441810608, Val Loss: 0.43291300535202026
# end of epoch.
# start of epoch 35
# Training loss (for one batch) at step 0: 0.4319201409816742
# Epoch 35, Loss: 0.4319201409816742, Val Loss: 0.47372299432754517
# end of epoch.
# start of epoch 36
# Training loss (for one batch) at step 0: 0.4571658670902252
# Epoch 36, Loss: 0.4571658670902252, Val Loss: 0.48706549406051636
# end of epoch.
# start of epoch 37
# Training loss (for one batch) at step 0: 0.5017988681793213
# Epoch 37, Loss: 0.5017988681793213, Val Loss: 0.49963369965553284
# end of epoch.
# start of epoch 38
# Training loss (for one batch) at step 0: 0.5997821688652039
# Epoch 38, Loss: 0.5997821688652039, Val Loss: 0.48503029346466064
# end of epoch.
# start of epoch 39
# Training loss (for one batch) at step 0: 0.4800339639186859
# Epoch 39, Loss: 0.4800339639186859, Val Loss: 0.4370415508747101
# end of epoch.
# start of epoch 40
# Training loss (for one batch) at step 0: 0.4519731104373932
# Epoch 40, Loss: 0.4519731104373932, Val Loss: 0.4197005331516266
# end of epoch.
# start of epoch 41
# Training loss (for one batch) at step 0: 0.5557140707969666
# Epoch 41, Loss: 0.5557140707969666, Val Loss: 0.3715524673461914
# end of epoch.
# start of epoch 42
# Training loss (for one batch) at step 0: 0.5472802519798279
# Epoch 42, Loss: 0.5472802519798279, Val Loss: 0.3694339692592621
# end of epoch.
# start of epoch 43
# Training loss (for one batch) at step 0: 0.497678279876709
# Epoch 43, Loss: 0.497678279876709, Val Loss: 0.5384107828140259
# end of epoch.
# start of epoch 44
# Training loss (for one batch) at step 0: 0.56866854429245
# Epoch 44, Loss: 0.56866854429245, Val Loss: 0.41543543338775635
# end of epoch.
# start of epoch 45
# Training loss (for one batch) at step 0: 0.4384993612766266
# Epoch 45, Loss: 0.4384993612766266, Val Loss: 0.5703572630882263
# end of epoch.
# start of epoch 46
# Training loss (for one batch) at step 0: 0.5596413612365723
# Epoch 46, Loss: 0.5596413612365723, Val Loss: 0.4739091694355011
# end of epoch.
# start of epoch 47
# Training loss (for one batch) at step 0: 0.3893618881702423
# Epoch 47, Loss: 0.3893618881702423, Val Loss: 0.524012565612793
# end of epoch.
# start of epoch 48
# Training loss (for one batch) at step 0: 0.46400853991508484
# Epoch 48, Loss: 0.46400853991508484, Val Loss: 0.5322402119636536
# end of epoch.
# start of epoch 49
# Training loss (for one batch) at step 0: 0.5169229507446289
# Epoch 49, Loss: 0.5169229507446289, Val Loss: 0.4751342833042145
# end of epoch.
# start of epoch 50
# Training loss (for one batch) at step 0: 0.43172895908355713
# Epoch 50, Loss: 0.43172895908355713, Val Loss: 0.5402786731719971
# end of epoch.
# start of epoch 51
# Training loss (for one batch) at step 0: 0.5251944065093994
# Epoch 51, Loss: 0.5251944065093994, Val Loss: 0.5693680047988892
# end of epoch.
# start of epoch 52
# Training loss (for one batch) at step 0: 0.4728544056415558
# Epoch 52, Loss: 0.4728544056415558, Val Loss: 0.49147483706474304
# end of epoch.
# start of epoch 53
# Training loss (for one batch) at step 0: 0.5162457227706909
# Epoch 53, Loss: 0.5162457227706909, Val Loss: 0.4566076695919037
# end of epoch.
# start of epoch 54
# Training loss (for one batch) at step 0: 0.6287229657173157
# Epoch 54, Loss: 0.6287229657173157, Val Loss: 0.46575719118118286
# end of epoch.
# start of epoch 55
# Training loss (for one batch) at step 0: 0.46284061670303345
# Epoch 55, Loss: 0.46284061670303345, Val Loss: 0.5037506222724915
# end of epoch.
# start of epoch 56
# Training loss (for one batch) at step 0: 0.4717921018600464
# Epoch 56, Loss: 0.4717921018600464, Val Loss: 0.4608892500400543
# end of epoch.
# start of epoch 57
# Training loss (for one batch) at step 0: 0.4684344530105591
# Epoch 57, Loss: 0.4684344530105591, Val Loss: 0.457498162984848
# end of epoch.
# start of epoch 58
# Training loss (for one batch) at step 0: 0.47092798352241516
# Epoch 58, Loss: 0.47092798352241516, Val Loss: 0.5814359784126282
# end of epoch.
# start of epoch 59
# Training loss (for one batch) at step 0: 0.527619481086731
# Epoch 59, Loss: 0.527619481086731, Val Loss: 0.49166232347488403
# end of epoch.
# start of epoch 60
# Training loss (for one batch) at step 0: 0.5446205735206604
# Epoch 60, Loss: 0.5446205735206604, Val Loss: 0.49870964884757996
# end of epoch.
# start of epoch 61
# Training loss (for one batch) at step 0: 0.48517337441444397
# Epoch 61, Loss: 0.48517337441444397, Val Loss: 0.5126546025276184
# end of epoch.
# start of epoch 62
# Training loss (for one batch) at step 0: 0.36621931195259094
# Epoch 62, Loss: 0.36621931195259094, Val Loss: 0.49958181381225586
# end of epoch.
# start of epoch 63
# Training loss (for one batch) at step 0: 0.4841087758541107
# Epoch 63, Loss: 0.4841087758541107, Val Loss: 0.44420483708381653
# end of epoch.
# start of epoch 64
# Training loss (for one batch) at step 0: 0.42358553409576416
# Epoch 64, Loss: 0.42358553409576416, Val Loss: 0.41800007224082947
# end of epoch.
# start of epoch 65
# Training loss (for one batch) at step 0: 0.4793989062309265
# Epoch 65, Loss: 0.4793989062309265, Val Loss: 0.4671911299228668
# end of epoch.
# start of epoch 66
# Training loss (for one batch) at step 0: 0.5416224002838135
# Epoch 66, Loss: 0.5416224002838135, Val Loss: 0.461920827627182
# end of epoch.
# start of epoch 67
# Training loss (for one batch) at step 0: 0.5064189434051514
# Epoch 67, Loss: 0.5064189434051514, Val Loss: 0.5758153796195984
# end of epoch.
# start of epoch 68
# Training loss (for one batch) at step 0: 0.40634140372276306
# Epoch 68, Loss: 0.40634140372276306, Val Loss: 0.5806067585945129
# end of epoch.
# start of epoch 69
# Training loss (for one batch) at step 0: 0.4477216899394989
# Epoch 69, Loss: 0.4477216899394989, Val Loss: 0.4417031407356262
# end of epoch.
# start of epoch 70
# Training loss (for one batch) at step 0: 0.4996583163738251
# Epoch 70, Loss: 0.4996583163738251, Val Loss: 0.47702401876449585
# end of epoch.
# start of epoch 71
# Training loss (for one batch) at step 0: 0.4766620695590973
# Epoch 71, Loss: 0.4766620695590973, Val Loss: 0.4441777467727661
# end of epoch.
# start of epoch 72
# Training loss (for one batch) at step 0: 0.5197756886482239
# Epoch 72, Loss: 0.5197756886482239, Val Loss: 0.5248984694480896
# end of epoch.
# start of epoch 73
# Training loss (for one batch) at step 0: 0.5360475778579712
# Epoch 73, Loss: 0.5360475778579712, Val Loss: 0.5190481543540955
# end of epoch.
# start of epoch 74
# Training loss (for one batch) at step 0: 0.4389345943927765
# Epoch 74, Loss: 0.4389345943927765, Val Loss: 0.5063801407814026
# end of epoch.
# start of epoch 75
# Training loss (for one batch) at step 0: 0.4754057824611664
# Epoch 75, Loss: 0.4754057824611664, Val Loss: 0.589374840259552
# end of epoch.
# start of epoch 76
# Training loss (for one batch) at step 0: 0.5318872928619385
# Epoch 76, Loss: 0.5318872928619385, Val Loss: 0.518430769443512
# end of epoch.
# start of epoch 77
# Training loss (for one batch) at step 0: 0.5688440203666687
# Epoch 77, Loss: 0.5688440203666687, Val Loss: 0.5018121004104614
# end of epoch.
# start of epoch 78
# Training loss (for one batch) at step 0: 0.43604713678359985
# Epoch 78, Loss: 0.43604713678359985, Val Loss: 0.47676682472229004
# end of epoch.
# start of epoch 79
# Training loss (for one batch) at step 0: 0.4804719090461731
# Epoch 79, Loss: 0.4804719090461731, Val Loss: 0.37183916568756104
# end of epoch.
# start of epoch 80
# Training loss (for one batch) at step 0: 0.4263445734977722
# Epoch 80, Loss: 0.4263445734977722, Val Loss: 0.44893473386764526
# end of epoch.
# start of epoch 81
# Training loss (for one batch) at step 0: 0.47036758065223694
# Epoch 81, Loss: 0.47036758065223694, Val Loss: 0.47493061423301697
# end of epoch.
# start of epoch 82
# Training loss (for one batch) at step 0: 0.534442126750946
# Epoch 82, Loss: 0.534442126750946, Val Loss: 0.5228666067123413
# end of epoch.
# start of epoch 83
# Training loss (for one batch) at step 0: 0.4237419664859772
# Epoch 83, Loss: 0.4237419664859772, Val Loss: 0.5666265487670898
# end of epoch.
# start of epoch 84
# Training loss (for one batch) at step 0: 0.5401995778083801
# Epoch 84, Loss: 0.5401995778083801, Val Loss: 0.46474868059158325
# end of epoch.
# start of epoch 85
# Training loss (for one batch) at step 0: 0.4327765703201294
# Epoch 85, Loss: 0.4327765703201294, Val Loss: 0.46598362922668457
# end of epoch.
# start of epoch 86
# Training loss (for one batch) at step 0: 0.5478379726409912
# Epoch 86, Loss: 0.5478379726409912, Val Loss: 0.5422770380973816
# end of epoch.
# start of epoch 87
# Training loss (for one batch) at step 0: 0.4229736626148224
# Epoch 87, Loss: 0.4229736626148224, Val Loss: 0.45245984196662903
# end of epoch.
# start of epoch 88
# Training loss (for one batch) at step 0: 0.5056045651435852
# Epoch 88, Loss: 0.5056045651435852, Val Loss: 0.4961977005004883
# end of epoch.
# start of epoch 89
# Training loss (for one batch) at step 0: 0.48690199851989746
# Epoch 89, Loss: 0.48690199851989746, Val Loss: 0.5614334940910339
# end of epoch.
# start of epoch 90
# Training loss (for one batch) at step 0: 0.5112452507019043
# Epoch 90, Loss: 0.5112452507019043, Val Loss: 0.5394271612167358
# end of epoch.
# start of epoch 91
# Training loss (for one batch) at step 0: 0.5089008808135986
# Epoch 91, Loss: 0.5089008808135986, Val Loss: 0.5065916180610657
# end of epoch.
# start of epoch 92
# Training loss (for one batch) at step 0: 0.4941548705101013
# Epoch 92, Loss: 0.4941548705101013, Val Loss: 0.5117560625076294
# end of epoch.
# start of epoch 93
# Training loss (for one batch) at step 0: 0.5114707350730896
# Epoch 93, Loss: 0.5114707350730896, Val Loss: 0.4736265540122986
# end of epoch.
# start of epoch 94
# Training loss (for one batch) at step 0: 0.3982216417789459
# Epoch 94, Loss: 0.3982216417789459, Val Loss: 0.39882269501686096
# end of epoch.
# start of epoch 95
# Training loss (for one batch) at step 0: 0.45777425169944763
# Epoch 95, Loss: 0.45777425169944763, Val Loss: 0.5366623997688293
# end of epoch.
# start of epoch 96
# Training loss (for one batch) at step 0: 0.4677354395389557
# Epoch 96, Loss: 0.4677354395389557, Val Loss: 0.4787352681159973
# end of epoch.
# start of epoch 97
# Training loss (for one batch) at step 0: 0.48498764634132385
# Epoch 97, Loss: 0.48498764634132385, Val Loss: 0.5463255047798157
# end of epoch.
# start of epoch 98
# Training loss (for one batch) at step 0: 0.5284290313720703
# Epoch 98, Loss: 0.5284290313720703, Val Loss: 0.4558711647987366
# end of epoch.
# start of epoch 99
# Training loss (for one batch) at step 0: 0.5098173022270203
# Epoch 99, Loss: 0.5098173022270203, Val Loss: 0.45976221561431885
# end of epoch.
# start of epoch 100
# Training loss (for one batch) at step 0: 0.4280788004398346
# Epoch 100, Loss: 0.4280788004398346, Val Loss: 0.48144713044166565
# end of epoch.
# start of epoch 101
# Training loss (for one batch) at step 0: 0.43213075399398804
# Epoch 101, Loss: 0.43213075399398804, Val Loss: 0.5363522171974182
# end of epoch.
# start of epoch 102
# Training loss (for one batch) at step 0: 0.5248621106147766
# Epoch 102, Loss: 0.5248621106147766, Val Loss: 0.5591844916343689
# end of epoch.
# start of epoch 103
# Training loss (for one batch) at step 0: 0.5305953621864319
# Epoch 103, Loss: 0.5305953621864319, Val Loss: 0.5454709529876709
# end of epoch.
# start of epoch 104
# Training loss (for one batch) at step 0: 0.43060317635536194
# Epoch 104, Loss: 0.43060317635536194, Val Loss: 0.5618702173233032
# end of epoch.
# start of epoch 105
# Training loss (for one batch) at step 0: 0.4237445592880249
# Epoch 105, Loss: 0.4237445592880249, Val Loss: 0.5468326807022095
# end of epoch.
# start of epoch 106
# Training loss (for one batch) at step 0: 0.5187745690345764
# Epoch 106, Loss: 0.5187745690345764, Val Loss: 0.6045650243759155
# end of epoch.
# start of epoch 107
# Training loss (for one batch) at step 0: 0.4232129752635956
# Epoch 107, Loss: 0.4232129752635956, Val Loss: 0.44147956371307373
# end of epoch.
# start of epoch 108
# Training loss (for one batch) at step 0: 0.5028395056724548
# Epoch 108, Loss: 0.5028395056724548, Val Loss: 0.44468483328819275
# end of epoch.
# start of epoch 109
# Training loss (for one batch) at step 0: 0.4668995440006256
# Epoch 109, Loss: 0.4668995440006256, Val Loss: 0.48586946725845337
# end of epoch.
# start of epoch 110
# Training loss (for one batch) at step 0: 0.5401276350021362
# Epoch 110, Loss: 0.5401276350021362, Val Loss: 0.4266722500324249
# end of epoch.
# start of epoch 111
# Training loss (for one batch) at step 0: 0.5078317523002625
# Epoch 111, Loss: 0.5078317523002625, Val Loss: 0.35838818550109863
# end of epoch.
# start of epoch 112
# Training loss (for one batch) at step 0: 0.45362263917922974
# Epoch 112, Loss: 0.45362263917922974, Val Loss: 0.44916561245918274
# end of epoch.
# start of epoch 113
# Training loss (for one batch) at step 0: 0.5745120048522949
# Epoch 113, Loss: 0.5745120048522949, Val Loss: 0.5608663558959961
# end of epoch.
# start of epoch 114
# Training loss (for one batch) at step 0: 0.45422595739364624
# Epoch 114, Loss: 0.45422595739364624, Val Loss: 0.44254669547080994
# end of epoch.
# start of epoch 115
# Training loss (for one batch) at step 0: 0.5767689943313599
# Epoch 115, Loss: 0.5767689943313599, Val Loss: 0.5090638995170593
# end of epoch.
# start of epoch 116
# Training loss (for one batch) at step 0: 0.49224504828453064
# Epoch 116, Loss: 0.49224504828453064, Val Loss: 0.5971888303756714
# end of epoch.
# start of epoch 117
# Training loss (for one batch) at step 0: 0.5480503439903259
# Epoch 117, Loss: 0.5480503439903259, Val Loss: 0.49786585569381714
# end of epoch.
# start of epoch 118
# Training loss (for one batch) at step 0: 0.49582964181900024
# Epoch 118, Loss: 0.49582964181900024, Val Loss: 0.49541810154914856
# end of epoch.
# start of epoch 119
# Training loss (for one batch) at step 0: 0.5179821848869324
# Epoch 119, Loss: 0.5179821848869324, Val Loss: 0.4877381920814514
# end of epoch.
# start of epoch 120
# Training loss (for one batch) at step 0: 0.538314938545227
# Epoch 120, Loss: 0.538314938545227, Val Loss: 0.4744925796985626
# end of epoch.
# start of epoch 121
# Training loss (for one batch) at step 0: 0.5019136667251587
# Epoch 121, Loss: 0.5019136667251587, Val Loss: 0.5012034177780151
# end of epoch.
# start of epoch 122
# Training loss (for one batch) at step 0: 0.4832601845264435
# Epoch 122, Loss: 0.4832601845264435, Val Loss: 0.5615828633308411
# end of epoch.
# start of epoch 123
# Training loss (for one batch) at step 0: 0.41187694668769836
# Epoch 123, Loss: 0.41187694668769836, Val Loss: 0.4527522027492523
# end of epoch.
# start of epoch 124
# Training loss (for one batch) at step 0: 0.5557810068130493
# Epoch 124, Loss: 0.5557810068130493, Val Loss: 0.4801837205886841
# end of epoch.
# start of epoch 125
# Training loss (for one batch) at step 0: 0.5050844550132751
# Epoch 125, Loss: 0.5050844550132751, Val Loss: 0.5032296776771545
# end of epoch.
# start of epoch 126
# Training loss (for one batch) at step 0: 0.5119388699531555
# Epoch 126, Loss: 0.5119388699531555, Val Loss: 0.5201016664505005
# end of epoch.
# start of epoch 127
# Training loss (for one batch) at step 0: 0.5381128787994385
# Epoch 127, Loss: 0.5381128787994385, Val Loss: 0.4727376103401184
# end of epoch.
# start of epoch 128
# Training loss (for one batch) at step 0: 0.5146986842155457
# Epoch 128, Loss: 0.5146986842155457, Val Loss: 0.5149853825569153
# end of epoch.
# start of epoch 129
# Training loss (for one batch) at step 0: 0.4562544524669647
# Epoch 129, Loss: 0.4562544524669647, Val Loss: 0.5454192161560059
# end of epoch.
# start of epoch 130
# Training loss (for one batch) at step 0: 0.5772790908813477
# Epoch 130, Loss: 0.5772790908813477, Val Loss: 0.3858416676521301
# end of epoch.
# start of epoch 131
# Training loss (for one batch) at step 0: 0.4472416639328003
# Epoch 131, Loss: 0.4472416639328003, Val Loss: 0.5269171595573425
# end of epoch.
# start of epoch 132
# Training loss (for one batch) at step 0: 0.5258317589759827
# Epoch 132, Loss: 0.5258317589759827, Val Loss: 0.46261557936668396
# end of epoch.
# start of epoch 133
# Training loss (for one batch) at step 0: 0.5712345242500305
# Epoch 133, Loss: 0.5712345242500305, Val Loss: 0.4453871548175812
# end of epoch.
# start of epoch 134
# Training loss (for one batch) at step 0: 0.50001060962677
# Epoch 134, Loss: 0.50001060962677, Val Loss: 0.5694080591201782
# end of epoch.
# start of epoch 135
# Training loss (for one batch) at step 0: 0.4967411160469055
# Epoch 135, Loss: 0.4967411160469055, Val Loss: 0.3988904356956482
# end of epoch.
# start of epoch 136
# Training loss (for one batch) at step 0: 0.46534889936447144
# Epoch 136, Loss: 0.46534889936447144, Val Loss: 0.4902123808860779
# end of epoch.
# start of epoch 137
# Training loss (for one batch) at step 0: 0.5263005495071411
# Epoch 137, Loss: 0.5263005495071411, Val Loss: 0.42578229308128357
# end of epoch.
# start of epoch 138
# Training loss (for one batch) at step 0: 0.496845006942749
# Epoch 138, Loss: 0.496845006942749, Val Loss: 0.45147576928138733
# end of epoch.
# start of epoch 139
# Training loss (for one batch) at step 0: 0.4371749758720398
# Epoch 139, Loss: 0.4371749758720398, Val Loss: 0.4470071792602539
# end of epoch.
# start of epoch 140
# Training loss (for one batch) at step 0: 0.5028517246246338
# Epoch 140, Loss: 0.5028517246246338, Val Loss: 0.42489492893218994
# end of epoch.
# start of epoch 141
# Training loss (for one batch) at step 0: 0.46547600626945496
# Epoch 141, Loss: 0.46547600626945496, Val Loss: 0.4911673963069916
# end of epoch.
# start of epoch 142
# Training loss (for one batch) at step 0: 0.5159972310066223
# Epoch 142, Loss: 0.5159972310066223, Val Loss: 0.5089504718780518
# end of epoch.
# start of epoch 143
# Training loss (for one batch) at step 0: 0.4253833293914795
# Epoch 143, Loss: 0.4253833293914795, Val Loss: 0.5582759380340576
# end of epoch.
# start of epoch 144
# Training loss (for one batch) at step 0: 0.4469379186630249
# Epoch 144, Loss: 0.4469379186630249, Val Loss: 0.4513384997844696
# end of epoch.
# start of epoch 145
# Training loss (for one batch) at step 0: 0.4533665180206299
# Epoch 145, Loss: 0.4533665180206299, Val Loss: 0.4635206460952759
# end of epoch.
# start of epoch 146
# Training loss (for one batch) at step 0: 0.570041835308075
# Epoch 146, Loss: 0.570041835308075, Val Loss: 0.45835715532302856
# end of epoch.
# start of epoch 147
# Training loss (for one batch) at step 0: 0.5961726903915405
# Epoch 147, Loss: 0.5961726903915405, Val Loss: 0.5058210492134094
# end of epoch.
# start of epoch 148
# Training loss (for one batch) at step 0: 0.44165152311325073
# Epoch 148, Loss: 0.44165152311325073, Val Loss: 0.4632568061351776
# end of epoch.
# start of epoch 149
# Training loss (for one batch) at step 0: 0.4897932708263397
# Epoch 149, Loss: 0.4897932708263397, Val Loss: 0.47498130798339844
# end of epoch.
# start of epoch 150
# Training loss (for one batch) at step 0: 0.5861766338348389
# Epoch 150, Loss: 0.5861766338348389, Val Loss: 0.4987991750240326
# end of epoch.
# start of epoch 151
# Training loss (for one batch) at step 0: 0.5834481716156006
# Epoch 151, Loss: 0.5834481716156006, Val Loss: 0.5067287087440491
# end of epoch.
# start of epoch 152
# Training loss (for one batch) at step 0: 0.44938600063323975
# Epoch 152, Loss: 0.44938600063323975, Val Loss: 0.3937537670135498
# end of epoch.
# start of epoch 153
# Training loss (for one batch) at step 0: 0.5788265466690063
# Epoch 153, Loss: 0.5788265466690063, Val Loss: 0.5579371452331543
# end of epoch.
# start of epoch 154
# Training loss (for one batch) at step 0: 0.567603588104248
# Epoch 154, Loss: 0.567603588104248, Val Loss: 0.5101967453956604
# end of epoch.
# start of epoch 155
# Training loss (for one batch) at step 0: 0.551896870136261
# Epoch 155, Loss: 0.551896870136261, Val Loss: 0.40800637006759644
# end of epoch.
# start of epoch 156
# Training loss (for one batch) at step 0: 0.4516685903072357
# Epoch 156, Loss: 0.4516685903072357, Val Loss: 0.47986480593681335
# end of epoch.
# start of epoch 157
# Training loss (for one batch) at step 0: 0.5952096581459045
# Epoch 157, Loss: 0.5952096581459045, Val Loss: 0.487508088350296
# end of epoch.
# start of epoch 158
# Training loss (for one batch) at step 0: 0.36277344822883606
# Epoch 158, Loss: 0.36277344822883606, Val Loss: 0.39805325865745544
# end of epoch.
# start of epoch 159
# Training loss (for one batch) at step 0: 0.5705267190933228
# Epoch 159, Loss: 0.5705267190933228, Val Loss: 0.47000840306282043
# end of epoch.
# start of epoch 160
# Training loss (for one batch) at step 0: 0.4413488507270813
# Epoch 160, Loss: 0.4413488507270813, Val Loss: 0.47524338960647583
# end of epoch.
# start of epoch 161
# Training loss (for one batch) at step 0: 0.48256799578666687
# Epoch 161, Loss: 0.48256799578666687, Val Loss: 0.437059223651886
# end of epoch.
# start of epoch 162
# Training loss (for one batch) at step 0: 0.5758069157600403
# Epoch 162, Loss: 0.5758069157600403, Val Loss: 0.43186402320861816
# end of epoch.
# start of epoch 163
# Training loss (for one batch) at step 0: 0.5107272863388062
# Epoch 163, Loss: 0.5107272863388062, Val Loss: 0.44178417325019836
# end of epoch.
# start of epoch 164
# Training loss (for one batch) at step 0: 0.5193161964416504
# Epoch 164, Loss: 0.5193161964416504, Val Loss: 0.4511953592300415
# end of epoch.
# start of epoch 165
# Training loss (for one batch) at step 0: 0.46108072996139526
# Epoch 165, Loss: 0.46108072996139526, Val Loss: 0.47481366991996765
# end of epoch.
# start of epoch 166
# Training loss (for one batch) at step 0: 0.5195452570915222
# Epoch 166, Loss: 0.5195452570915222, Val Loss: 0.49946102499961853
# end of epoch.
# start of epoch 167
# Training loss (for one batch) at step 0: 0.5175470113754272
# Epoch 167, Loss: 0.5175470113754272, Val Loss: 0.4522019922733307
# end of epoch.
# start of epoch 168
# Training loss (for one batch) at step 0: 0.4933135211467743
# Epoch 168, Loss: 0.4933135211467743, Val Loss: 0.47195765376091003
# end of epoch.
# start of epoch 169
# Training loss (for one batch) at step 0: 0.40200212597846985
# Epoch 169, Loss: 0.40200212597846985, Val Loss: 0.4650856852531433
# end of epoch.
# start of epoch 170
# Training loss (for one batch) at step 0: 0.4617919623851776
# Epoch 170, Loss: 0.4617919623851776, Val Loss: 0.5175835490226746
# end of epoch.
# start of epoch 171
# Training loss (for one batch) at step 0: 0.3657139241695404
# Epoch 171, Loss: 0.3657139241695404, Val Loss: 0.46320387721061707
# end of epoch.
# start of epoch 172
# Training loss (for one batch) at step 0: 0.48936349153518677
# Epoch 172, Loss: 0.48936349153518677, Val Loss: 0.5312162637710571
# end of epoch.
# start of epoch 173
# Training loss (for one batch) at step 0: 0.5072193145751953
# Epoch 173, Loss: 0.5072193145751953, Val Loss: 0.458088219165802
# end of epoch.
# start of epoch 174
# Training loss (for one batch) at step 0: 0.5300772786140442
# Epoch 174, Loss: 0.5300772786140442, Val Loss: 0.5337572693824768
# end of epoch.
# start of epoch 175
# Training loss (for one batch) at step 0: 0.5266353487968445
# Epoch 175, Loss: 0.5266353487968445, Val Loss: 0.473455011844635
# end of epoch.
# start of epoch 176
# Training loss (for one batch) at step 0: 0.4349958896636963
# Epoch 176, Loss: 0.4349958896636963, Val Loss: 0.4142063558101654
# end of epoch.
# start of epoch 177
# Training loss (for one batch) at step 0: 0.44284000992774963
# Epoch 177, Loss: 0.44284000992774963, Val Loss: 0.4955272078514099
# end of epoch.
# start of epoch 178
# Training loss (for one batch) at step 0: 0.5036137104034424
# Epoch 178, Loss: 0.5036137104034424, Val Loss: 0.5164483189582825
# end of epoch.
# start of epoch 179
# Training loss (for one batch) at step 0: 0.4565497636795044
# Epoch 179, Loss: 0.4565497636795044, Val Loss: 0.5342406034469604
# end of epoch.
# start of epoch 180
# Training loss (for one batch) at step 0: 0.480951726436615
# Epoch 180, Loss: 0.480951726436615, Val Loss: 0.5078092813491821
# end of epoch.
# start of epoch 181
# Training loss (for one batch) at step 0: 0.5227863788604736
# Epoch 181, Loss: 0.5227863788604736, Val Loss: 0.3919403553009033
# end of epoch.
# start of epoch 182
# Training loss (for one batch) at step 0: 0.4413570761680603
# Epoch 182, Loss: 0.4413570761680603, Val Loss: 0.45950838923454285
# end of epoch.
# start of epoch 183
# Training loss (for one batch) at step 0: 0.46333855390548706
# Epoch 183, Loss: 0.46333855390548706, Val Loss: 0.5177693367004395
# end of epoch.
# start of epoch 184
# Training loss (for one batch) at step 0: 0.5480315685272217
# Epoch 184, Loss: 0.5480315685272217, Val Loss: 0.4733123183250427
# end of epoch.
# start of epoch 185
# Training loss (for one batch) at step 0: 0.5199049711227417
# Epoch 185, Loss: 0.5199049711227417, Val Loss: 0.514775276184082
# end of epoch.
# start of epoch 186
# Training loss (for one batch) at step 0: 0.4513079524040222
# Epoch 186, Loss: 0.4513079524040222, Val Loss: 0.46715518832206726
# end of epoch.
# start of epoch 187
# Training loss (for one batch) at step 0: 0.3954662084579468
# Epoch 187, Loss: 0.3954662084579468, Val Loss: 0.5008852481842041
# end of epoch.
# start of epoch 188
# Training loss (for one batch) at step 0: 0.5865530371665955
# Epoch 188, Loss: 0.5865530371665955, Val Loss: 0.5556296706199646
# end of epoch.
# start of epoch 189
# Training loss (for one batch) at step 0: 0.4218042492866516
# Epoch 189, Loss: 0.4218042492866516, Val Loss: 0.4380863904953003
# end of epoch.
# start of epoch 190
# Training loss (for one batch) at step 0: 0.48008137941360474
# Epoch 190, Loss: 0.48008137941360474, Val Loss: 0.44851067662239075
# end of epoch.
# start of epoch 191
# Training loss (for one batch) at step 0: 0.5077405571937561
# Epoch 191, Loss: 0.5077405571937561, Val Loss: 0.48447754979133606
# end of epoch.
# start of epoch 192
# Training loss (for one batch) at step 0: 0.43205127120018005
# Epoch 192, Loss: 0.43205127120018005, Val Loss: 0.41065889596939087
# end of epoch.
# start of epoch 193
# Training loss (for one batch) at step 0: 0.47259509563446045
# Epoch 193, Loss: 0.47259509563446045, Val Loss: 0.40772104263305664
# end of epoch.
# start of epoch 194
# Training loss (for one batch) at step 0: 0.4952300190925598
# Epoch 194, Loss: 0.4952300190925598, Val Loss: 0.517570972442627
# end of epoch.
# start of epoch 195
# Training loss (for one batch) at step 0: 0.47493574023246765
# Epoch 195, Loss: 0.47493574023246765, Val Loss: 0.4824063181877136
# end of epoch.
# start of epoch 196
# Training loss (for one batch) at step 0: 0.5163307785987854
# Epoch 196, Loss: 0.5163307785987854, Val Loss: 0.5238887071609497
# end of epoch.
# start of epoch 197
# Training loss (for one batch) at step 0: 0.46842122077941895
# Epoch 197, Loss: 0.46842122077941895, Val Loss: 0.4962780475616455
# end of epoch.
# start of epoch 198
# Training loss (for one batch) at step 0: 0.43714454770088196
# Epoch 198, Loss: 0.43714454770088196, Val Loss: 0.5452091097831726
# end of epoch.
# start of epoch 199
# Training loss (for one batch) at step 0: 0.4121841490268707
# Epoch 199, Loss: 0.4121841490268707, Val Loss: 0.5169394016265869
# end of epoch.
# start of epoch 200
# Training loss (for one batch) at step 0: 0.5495585799217224
# Epoch 200, Loss: 0.5495585799217224, Val Loss: 0.5353859663009644
# end of epoch.
# Checkpoint directory :  checkpoints/CNNgeo/200507_regressor_filter_size_up
# Tensorboard log directory :  logs/CNNgeo/200507_regressor_filter_size_up

# %%
model.summary()
# Out:
# Model: "cnn_geo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature__extractor (Feature_ multiple                  113600
# _________________________________________________________________
# correlation_network (Correla multiple                  0
# _________________________________________________________________
# spatial_transformer_regresso multiple                  875250
# =================================================================
# Total params: 988,850
# Trainable params: 988,146
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# # 3. Debug

# %%
datasets = load_data(['train'], config)
ds = datasets['train'].batch(1)
# Out:
# train dataset amount : 1

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
#image_B_hat = np.ones([1, 64, 64, 3])
pred, score = model(image_A, image_B)

# %%
print("parameter shape", pred.shape)
print("score shape", score.shape)
print(image_A.shape)
# Out:
# parameter shape (1, 9, 2)
# score shape (1, 16, 16, 16, 16)
# (1, 64, 64, 3)

# %% [markdown]
# ## 3.1. 입력 영상에 따른 모델 추정 확인

# %% [markdown]
# ### case 1) 임의의 기하관계를 갖는 영상 쌍 (image A, image B)

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred1 = pred.copy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.00675101 -0.10057826]
#   [-0.02715597  0.03614287]
#   [ 0.05108271  0.1285973 ]
#   [ 0.0308547   0.00939541]
#   [-0.06910592  0.07528596]
#   [ 0.02282548  0.15209074]
#   [-0.11201473  0.19377461]
#   [ 0.12146964  0.03804803]
#   [-0.19517432  0.19438887]]] and
#  pred : [[[ 0.00381521 -0.00378535]
#   [-0.00517986 -0.00182904]
#   [ 0.01294973  0.0023025 ]
#   [-0.00533697 -0.0004811 ]
#   [ 0.00426779  0.0001971 ]
#   [-0.00133303  0.00305858]
#   [ 0.00579428 -0.00259195]
#   [ 0.00217069 -0.00781883]
#   [-0.00127887 -0.0044709 ]]]
# loss : [0.10497446]

# %% [markdown]
# ### case 2) 임의의 다른 기하관계를 갖는 영상 쌍 (image A, image B)

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred2 = pred.copy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.05626178 -0.12879959]
#   [ 0.07746921 -0.0625784 ]
#   [-0.17583919  0.03164211]
#   [-0.06517635  0.06468143]
#   [-0.06833448  0.0311913 ]
#   [-0.0817854  -0.06089459]
#   [ 0.01266017  0.1148098 ]
#   [ 0.17548576 -0.18527494]
#   [-0.06582909 -0.11445685]]] and
#  pred : [[[ 0.00381521 -0.00378535]
#   [-0.00517986 -0.00182904]
#   [ 0.01294973  0.0023025 ]
#   [-0.00533697 -0.0004811 ]
#   [ 0.00426779  0.0001971 ]
#   [-0.00133303  0.00305858]
#   [ 0.00579428 -0.00259195]
#   [ 0.00217069 -0.00781883]
#   [-0.00127887 -0.0044709 ]]]
# loss : [0.09125259]

# %% [markdown]
# ### case 3) Image A와 연관 없는 image B(백색 사진)의 영상 쌍

# %%
image_B = np.ones([1, 64, 64, 3])
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred3 = pred.copy()
# Out:
# WARNING:tensorflow:Layer feature__extractor is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.05626178 -0.12879959]
#   [ 0.07746921 -0.0625784 ]
#   [-0.17583919  0.03164211]
#   [-0.06517635  0.06468143]
#   [-0.06833448  0.0311913 ]
#   [-0.0817854  -0.06089459]
#   [ 0.01266017  0.1148098 ]
#   [ 0.17548576 -0.18527494]
#   [-0.06582909 -0.11445685]]] and
#  pred : [[[ 0.00381521 -0.00378535]
#   [-0.00517986 -0.00182904]
#   [ 0.01294973  0.0023025 ]
#   [-0.00533697 -0.0004811 ]
#   [ 0.00426779  0.0001971 ]
#   [-0.00133303  0.00305858]
#   [ 0.00579428 -0.00259195]
#   [ 0.00217069 -0.00781883]
#   [-0.00127887 -0.0044709 ]]]
# loss : [0.09125259]

# %%
print(pred1, "\n", pred2, "\n", pred3)
# Out:
# [[[ 0.00381521 -0.00378535]
#   [-0.00517986 -0.00182904]
#   [ 0.01294973  0.0023025 ]
#   [-0.00533697 -0.0004811 ]
#   [ 0.00426779  0.0001971 ]
#   [-0.00133303  0.00305858]
#   [ 0.00579428 -0.00259195]
#   [ 0.00217069 -0.00781883]
#   [-0.00127887 -0.0044709 ]]]
#  [[[ 0.00381521 -0.00378535]
#   [-0.00517986 -0.00182904]
#   [ 0.01294973  0.0023025 ]
#   [-0.00533697 -0.0004811 ]
#   [ 0.00426779  0.0001971 ]
#   [-0.00133303  0.00305858]
#   [ 0.00579428 -0.00259195]
#   [ 0.00217069 -0.00781883]
#   [-0.00127887 -0.0044709 ]]]
#  [[[ 0.00381521 -0.00378535]
#   [-0.00517986 -0.00182904]
#   [ 0.01294973  0.0023025 ]
#   [-0.00533697 -0.0004811 ]
#   [ 0.00426779  0.0001971 ]
#   [-0.00133303  0.00305858]
#   [ 0.00579428 -0.00259195]
#   [ 0.00217069 -0.00781883]
#   [-0.00127887 -0.0044709 ]]]

# %% [markdown]
# case 1)와 case 2)는 동일한 영상을 다른 기하관계를 사용하여 두 개의 영상쌍(image pair)을 만든 경우를 말한다. 모델이 정상적이라면 각 영상쌍의 기하관계를 추정할 수 있을 것이다. 그러나 두 영상쌍이 다른 기하관계를 갖음에도 동일한 모션파라미터를 추정하였다. case 3)에서는 전혀 연관 없는 영상을 image B로 사용하였다. image B는 어떤 특징 정보도 없는 백색 사진임에도 불구하고 모델은 case 1)과 case 2)에서와 같은 모션파라미터를 추정하였다.

# %%
model.summary()
# Out:
# Model: "cnn_geo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature__extractor (Feature_ multiple                  113600
# _________________________________________________________________
# correlation_network (Correla multiple                  0
# _________________________________________________________________
# spatial_transformer_regresso multiple                  875250
# =================================================================
# Total params: 988,850
# Trainable params: 988,146
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# ## 3.2 Correlation 분포에 따른 Regressor 예측

# %% [markdown]
# 3.1의 case 1, 2, 3에서 Regressor은 같은 모션파라미터를 예측했다. 명확한 이유를 파악하기 위해 입력 correlation(matching scores)를 제어하며 spatial parameter regressor의 출력을 분석했다.

# %%
x = np.zeros([1, 16, 16, 16, 16]) # all correlations are zero
y = model.layers[2](x)
print(y)
# Out:
# WARNING:tensorflow:Layer spatial_transformer_regressor is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# tf.Tensor(
# [[ 0.00381521 -0.00378535 -0.00517986 -0.00182904  0.01294973  0.0023025
#   -0.00533697 -0.0004811   0.00426779  0.0001971  -0.00133303  0.00305858
#    0.00579428 -0.00259195  0.00217069 -0.00781883 -0.00127887 -0.0044709 ]], shape=(1, 18), dtype=float32)

# %%
x = np.ones([1, 16, 16, 16, 16]) # all correlations are one
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[ 0.00381521 -0.00378535 -0.00517986 -0.00182904  0.01294973  0.0023025
#   -0.00533697 -0.0004811   0.00426779  0.0001971  -0.00133303  0.00305858
#    0.00579428 -0.00259195  0.00217069 -0.00781883 -0.00127887 -0.0044709 ]], shape=(1, 18), dtype=float32)

# %%
x = np.random.normal(loc=0.5, scale=0.0, size=[1, 16, 16, 16, 16])
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[ 0.00381521 -0.00378535 -0.00517986 -0.00182904  0.01294973  0.0023025
#   -0.00533697 -0.0004811   0.00426779  0.0001971  -0.00133303  0.00305858
#    0.00579428 -0.00259195  0.00217069 -0.00781883 -0.00127887 -0.0044709 ]], shape=(1, 18), dtype=float32)

# %%
x = np.random.normal(loc=0.5, scale=0.3, size=[1, 16, 16, 16, 16])
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[ 0.01630943 -0.38072103 -0.08925564  0.04464093  0.09060439  0.02696136
#   -0.1841177  -0.13782504 -0.03273034  0.07060761  0.06905543  0.06890927
#   -0.03148824  0.06865966 -0.05029478  0.08867814 -0.01655756 -0.14948685]], shape=(1, 18), dtype=float32)

# %% [markdown]
# 위 실험의 결과를 토대로 확인할 수 있는 것은 regressor의 출력은 입력 correlation의 크기가 아닌 편차에 따라 달라진다는 것이다. correlation의 분포의 표준편차를 변화시키며 출력의 변화 정도를 추정해주었다.

# %%
_range = np.linspace(0, 1.0, 50)
print(_range)
# Out:
# [0.         0.02040816 0.04081633 0.06122449 0.08163265 0.10204082
#  0.12244898 0.14285714 0.16326531 0.18367347 0.20408163 0.2244898
#  0.24489796 0.26530612 0.28571429 0.30612245 0.32653061 0.34693878
#  0.36734694 0.3877551  0.40816327 0.42857143 0.44897959 0.46938776
#  0.48979592 0.51020408 0.53061224 0.55102041 0.57142857 0.59183673
#  0.6122449  0.63265306 0.65306122 0.67346939 0.69387755 0.71428571
#  0.73469388 0.75510204 0.7755102  0.79591837 0.81632653 0.83673469
#  0.85714286 0.87755102 0.89795918 0.91836735 0.93877551 0.95918367
#  0.97959184 1.        ]

# %%
variations_via_std = []
variations_via_mean = []
for std in _range:
    variations = []
    for i in range(1000):
        x = np.random.normal(loc=0.5, scale=std, size=[1, 16, 16, 16, 16])
        _y = model.layers[2](x)
        variations.append(_y)
    variations_via_std.append(np.sum(np.std(np.array(variations), axis = 0)))
    
for mean in _range:
    variations = []
    for i in range(1000):
        x = np.random.normal(loc=mean, scale=0.1, size=[1, 16, 16, 16, 16])
        _y = model.layers[2](x)
        variations.append(_y)
    variations_via_mean.append(np.sum(np.std(np.array(variations), axis = 0)))

# %%
variations
# Out:
# [<tf.Tensor: id=2188107, shape=(1, 18), dtype=float32, numpy=
#  array([[ 0.01045   , -0.00699841, -0.00930982, -0.01701221,  0.03348215,
#          -0.02102187, -0.01369438, -0.02694789,  0.00061128,  0.00068287,
#           0.02000355,  0.01909635,  0.01503688, -0.02387713,  0.04400306,
#           0.01600954, -0.02850125, -0.02340665]], dtype=float32)>]

# %%
plt.ylabel("variations of motion parameters")
plt.xlabel("via sigma, mean. \n correlations are sampled from N(0.5, sigma), N(mean, 0.1)")
plt.plot(_range, variations_via_std, label='via sigma')
plt.plot(_range, variations_via_mean, label='via mean')
plt.legend()
plt.show()

# %% [markdown]
# 1. VGG16을 통한 correlations
# 2. 시각화 방식 개선
# 3. tentative penalty

# %% [markdown]
# ## b. 특징추출기의 정상 동작 검증

# %% [markdown]
# ### 동일 영상에 대한 correlation

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_A)

score = score.numpy()[0]
parameters = parameters[0]
image_A = image_A[0]
image_B = image_B[0]

print(score.shape, parameters.shape, image_A.shape)
# Out:
# (16, 16, 16, 16) (9, 2) (64, 64, 3)

# %%
def get_matching_grid_from_B(parameters, center_point):
    src_points = np.array([[0.0, 0.0], [0.5, 0.0], [1.0, 0.0],
                                   [0.0, 0.5], [0.5, 0.5], [1.0, 0.5],
                                   [0.0, 1.0], [0.5, 1.0], [1.0, 1.0]])

    dst_points = src_points +parameters

    theta = tps.tps_theta_from_points(src_points, dst_points, reduced=True)
    dshape = (64, 64)
    grid = tps.tps_grid(theta, dst_points, dshape)
    mapx, mapy = tps.tps_grid_to_remap(grid, (64, 64))
    points = np.concatenate([mapy[:,:,np.newaxis], mapx[:,:,np.newaxis]], axis=2)
    #print("points :", points)
    center_point = np.array(center_point)
    #print("grid center : ", center_point)
    center_point = center_point[np.newaxis, np.newaxis, :]
    distance = np.sum(np.power((points - center_point), 2), axis=2)
    #print("distance : ", distance)
    ri, ci = distance.argmin()//distance.shape[1], distance.argmin()%distance.shape[1]
    return (ri, ci)

# %%
def score_test(grid_coord, score, parameters, images, grid_shape=(16,16)):
    image_A, image_B = images
    score = score[grid_coord[0], grid_coord[1]]
    H, W, C = image_A.shape
    grid_size = H/grid_shape[0], W/grid_shape[1]

    start_pix_h = int(grid_size[0]*grid_coord[0])
    end_pix_h = int(grid_size[0]*(1+grid_coord[0]))
    start_pix_w = int(grid_size[1]*grid_coord[1])
    end_pix_w = int(grid_size[1]*(1+grid_coord[1]))
    
    drawn_grid_image_A = image_A.copy()
    drawn_grid_image_A[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)   
    
    expected_drawn_grid_image_B = image_B.copy()
    grid_center_A = (int(start_pix_h+grid_size[0]/2), int(start_pix_w+grid_size[1]/2))
    grid_center_B = get_matching_grid_from_B(parameters, grid_center_A)
    start_pix_h = int(grid_center_B[0] - grid_size[0]/2)
    start_pix_w = int(grid_center_B[1] - grid_size[1]/2)
    end_pix_h = int(grid_center_B[0] + grid_size[0]/2)
    end_pix_w = int(grid_center_B[1] + grid_size[1]/2)
    expected_drawn_grid_image_B[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)
    
    drawn_grid_image_B = image_B.copy()
    max_correlation_grid_index = score.argmax()//score.shape[1], score.argmax()%score.shape[1]
    start_pix_h = int(grid_size[0]*max_correlation_grid_index[0])
    end_pix_h = int(grid_size[0]*(1+max_correlation_grid_index[0]))
    start_pix_w = int(grid_size[1]*max_correlation_grid_index[1])
    end_pix_w = int(grid_size[1]*(1+max_correlation_grid_index[1]))

    drawn_grid_image_B[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)
    
    print("top 10 correlation values in descending : ", np.sort(score.flatten())[::-1][:10])
    
    return drawn_grid_image_A, expected_drawn_grid_image_B, drawn_grid_image_B

# %%
drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B = score_test(grid_coord=(5,10), 
                                                                            score=score, 
                                                                            parameters=np.zeros([9,2]), 
                                                                            images=(image_A, image_A))
# Out:
# top 10 correlation values in descending :  [0.06371453 0.06362    0.06360997 0.0635888  0.06355985 0.06354817
#  0.06353967 0.0635275  0.06351044 0.06349815]

# %%
fig = plt.figure()

ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

ax1.imshow(drawn_image_A)
ax2.imshow(expected_drawn_grid_image_B)
ax3.imshow(drawn_grid_image_B)

plt.show()

# %%
drawn_image_A.shape
expected_drawn_grid_image_B.shape
drawn_grid_image_B.shape
# Out:
# (64, 64, 3)

# %% [markdown]
# ### b.1 ) 동일한 사진의 경우

# %%
for i in range(16):
    drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B = score_test(grid_coord=(i,i), 
                                                                                score=score, 
                                                                                parameters=np.zeros([9,2]), 
                                                                                images=(image_A, image_A))   
    fig = plt.figure()

    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)

    ax1.imshow(drawn_image_A)
    ax2.imshow(expected_drawn_grid_image_B)
    ax3.imshow(drawn_grid_image_B)

    plt.show()
# Out:
# top 10 correlation values in descending :  [0.06601112 0.0654678  0.06532574 0.06522945 0.06513942 0.06512149
#  0.06511775 0.0651135  0.06511321 0.06511208]
# top 10 correlation values in descending :  [0.06328703 0.06327283 0.06327252 0.06327248 0.0632718  0.06327173
#  0.06326655 0.06326547 0.06326303 0.06326253]
# top 10 correlation values in descending :  [0.0633186  0.06331843 0.06331842 0.0633184  0.06331834 0.0633183
#  0.0633183  0.06331827 0.06331827 0.06331823]
# top 10 correlation values in descending :  [0.06331862 0.0633185  0.0633185  0.06331849 0.06331849 0.06331848
#  0.06331845 0.0633184  0.06331837 0.06331836]
# top 10 correlation values in descending :  [0.0633136  0.06331319 0.0633131  0.0633131  0.06331308 0.06331302
#  0.06331299 0.06331296 0.06331295 0.06331293]
# top 10 correlation values in descending :  [0.06332421 0.06328749 0.0632733  0.06326561 0.06325534 0.06324352
#  0.0632417  0.06324063 0.06323943 0.06323886]
# top 10 correlation values in descending :  [0.06392016 0.0637717  0.06369827 0.0636384  0.06363187 0.06363071
#  0.06347775 0.06344233 0.06344169 0.06343055]
# top 10 correlation values in descending :  [0.06344255 0.06324761 0.06323809 0.06320921 0.06313681 0.06313576
#  0.06313214 0.06312937 0.06312709 0.06312269]
# top 10 correlation values in descending :  [0.06350461 0.06336074 0.06334674 0.06334168 0.06333425 0.06333055
#  0.06331557 0.06329577 0.06328908 0.06327767]
# top 10 correlation values in descending :  [0.06367137 0.06351732 0.06345944 0.06341426 0.06340881 0.06339829
#  0.06339288 0.06339122 0.06337429 0.0633464 ]
# top 10 correlation values in descending :  [0.06340957 0.06326876 0.06325114 0.06324987 0.06323751 0.06323213
#  0.06322982 0.06322824 0.06322774 0.06321952]
# top 10 correlation values in descending :  [0.06342576 0.06328072 0.0632409  0.06323977 0.06321821 0.06320666
#  0.0632066  0.06320366 0.06319799 0.06319395]
# top 10 correlation values in descending :  [0.06334971 0.06327417 0.06325442 0.06323955 0.06322685 0.06322243
#  0.06322147 0.06322087 0.06321013 0.06320994]
# top 10 correlation values in descending :  [0.06347664 0.06338121 0.06331798 0.06329799 0.06329171 0.06328653
#  0.06327885 0.06324331 0.06322861 0.06322379]
# top 10 correlation values in descending :  [0.06339458 0.06331904 0.06327329 0.06324675 0.06323612 0.06323025
#  0.06323022 0.06322221 0.06322001 0.06321343]
# top 10 correlation values in descending :  [0.06811817 0.06575753 0.06567222 0.06566292 0.06553306 0.06551122
#  0.0654984  0.06549384 0.06549326 0.06549204]

# %% [markdown]
# ### b.2 ) 다른 사진의 경우

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_A)

score = score.numpy()[0]
parameters = parameters[0]
image_A = image_A[0]
image_B = image_B[0]

print(score.shape, parameters.shape, image_A.shape)
# Out:
# (16, 16, 16, 16) (9, 2) (64, 64, 3)

# %%
for i in range(16):
    drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B = score_test(grid_coord=(i,i), 
                                                                                score=score, 
                                                                                parameters=parameters, 
                                                                                images=(image_A, image_B))   
    fig = plt.figure()

    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)

    ax1.imshow(drawn_image_A)
    ax2.imshow(expected_drawn_grid_image_B)
    ax3.imshow(drawn_grid_image_B)

    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06599283 0.06537625 0.06535853 0.06515469 0.06511968 0.06509265
#  0.06508546 0.06508378 0.06508362 0.06508081]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06327919 0.06326389 0.06326378 0.06326375 0.06326319 0.06326114
#  0.06325591 0.06325475 0.06325369 0.06325275]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06331789 0.06331775 0.06331774 0.06331764 0.06331763 0.0633176
#  0.06331727 0.06331708 0.06331705 0.06331689]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06331035 0.06330972 0.06330969 0.06330965 0.06330964 0.06330951
#  0.06330939 0.06330938 0.06330927 0.06330892]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0633015  0.06329952 0.06329878 0.06329732 0.06329658 0.06329568
#  0.06329456 0.06329139 0.06329031 0.06329024]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06333213 0.06328505 0.06328127 0.06324825 0.06322856 0.06322521
#  0.06320276 0.06320184 0.06320092 0.06320068]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06375875 0.06361061 0.06353519 0.06340345 0.06338228 0.06335971
#  0.06333459 0.06331814 0.06330378 0.06330223]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06366211 0.06335492 0.06335115 0.0633469  0.06328762 0.06328344
#  0.06327482 0.06327225 0.06326656 0.06325686]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06366249 0.06341781 0.06333644 0.06332042 0.06331784 0.06331149
#  0.06330901 0.06327244 0.06325261 0.06323735]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0640405  0.06339812 0.06329463 0.06327818 0.06326357 0.06324413
#  0.0632377  0.06323677 0.06323504 0.06322651]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06382584 0.06343699 0.06328978 0.06327933 0.06325682 0.06322402
#  0.06318895 0.06318879 0.06318417 0.0631633 ]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0637965  0.06364466 0.06357964 0.0635128  0.06350003 0.06339957
#  0.06337941 0.0632543  0.06325176 0.06321765]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06374889 0.06359816 0.06359712 0.06355646 0.06351079 0.06334303
#  0.06332548 0.0632945  0.06327403 0.06325499]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0635993  0.06345756 0.06344891 0.06338486 0.06331643 0.06330606
#  0.06323641 0.06315669 0.06315594 0.06314486]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06365698 0.06351513 0.06341923 0.06330144 0.06325582 0.06324311
#  0.06324077 0.06318807 0.0631757  0.06316218]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06894623 0.06552692 0.06522664 0.06511083 0.06507547 0.06506551
#  0.06505787 0.06505785 0.06504798 0.06504478]
