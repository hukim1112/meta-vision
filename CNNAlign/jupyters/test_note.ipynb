# %%
import os, sys
root_path = os.path.abspath('.').split('jupyters')[0]
sys.path.append(root_path)

# %%
import json
import argparse
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

from data_loader import load_data
from models.cnn_geo import CNN_geo

from debug_tools import data, train, visualize
from utils import image
import geo_transform as tps
import CNNgeo_debug

# %% [markdown]
# # 1. Read configuration file

# %%
with open('../overfit.json') as fp:
    config = json.load(fp)
split = 'val'

# %%
print(config)
# Out:
# {'exp_desc': '200507_regressor_filter_size_up', 'dataset_name': 'mini_imagenet', 'data_dir': '/home/files/datasets/mini_imagenet', 'image_shape': [64, 64, 3], 'model_name': 'CNNgeo', 'backbone': 'prototypical_network', 'data': {'method': 'synthesized_pair', 'tps_random_rate': 0.2, 'pad_ratio': 0.2}, 'ckpt': {'save_type': 'latest', 'max_to_keep': 10}, 'train': {'n_examples': 1, 'learning_rate': 0.0001, 'batch_size': 1, 'epochs': 200, 'print_step': 10}, 'val': {'n_examples': 1, 'batch_size': 1}, 'test': {'n_examples': -1, 'batch_size': 128}}

# %%
print(config['train'])
# Out:
# {'n_examples': 1, 'learning_rate': 0.0001, 'batch_size': 1, 'epochs': 200, 'print_step': 10}

# %%
print("backbone : ", config['backbone'])
print("n_examples : ", config['train']['n_examples'])
print("learning_rate : ", config['train']['learning_rate'])
print("batch_size : ", config['train']['batch_size'])
print("epoch num : ", config['train']['epochs'])
# Out:
# backbone :  prototypical_network
# n_examples :  1
# learning_rate :  0.0001
# batch_size :  1
# epoch num :  200

# %% [markdown]
# # 2. Train model on the config parameters

# %%
model = CNNgeo_debug.train(config)
# Out:
# train dataset amount : 1
# val dataset amount : 1
# start of epoch 1
# Training loss (for one batch) at step 0: 0.44786950945854187
# Epoch 1, Loss: 0.44786950945854187, Val Loss: 0.7034504413604736
# end of epoch.
# start of epoch 2
# Training loss (for one batch) at step 0: 0.6835514903068542
# Epoch 2, Loss: 0.6835514903068542, Val Loss: 0.6186314225196838
# end of epoch.
# start of epoch 3
# Training loss (for one batch) at step 0: 0.6849080920219421
# Epoch 3, Loss: 0.6849080920219421, Val Loss: 0.48742616176605225
# end of epoch.
# start of epoch 4
# Training loss (for one batch) at step 0: 0.6527343392372131
# Epoch 4, Loss: 0.6527343392372131, Val Loss: 0.5538454651832581
# end of epoch.
# start of epoch 5
# Training loss (for one batch) at step 0: 0.6142864227294922
# Epoch 5, Loss: 0.6142864227294922, Val Loss: 0.6145812273025513
# end of epoch.
# start of epoch 6
# Training loss (for one batch) at step 0: 0.5639229416847229
# Epoch 6, Loss: 0.5639229416847229, Val Loss: 0.4813130497932434
# end of epoch.
# start of epoch 7
# Training loss (for one batch) at step 0: 0.5384957790374756
# Epoch 7, Loss: 0.5384957790374756, Val Loss: 0.48325327038764954
# end of epoch.
# start of epoch 8
# Training loss (for one batch) at step 0: 0.5023382306098938
# Epoch 8, Loss: 0.5023382306098938, Val Loss: 0.5678495764732361
# end of epoch.
# start of epoch 9
# Training loss (for one batch) at step 0: 0.5154645442962646
# Epoch 9, Loss: 0.5154645442962646, Val Loss: 0.5443628430366516
# end of epoch.
# start of epoch 10
# Training loss (for one batch) at step 0: 0.523666501045227
# Epoch 10, Loss: 0.523666501045227, Val Loss: 0.5146512389183044
# end of epoch.
# start of epoch 11
# Training loss (for one batch) at step 0: 0.5620467662811279
# Epoch 11, Loss: 0.5620467662811279, Val Loss: 0.503157913684845
# end of epoch.
# start of epoch 12
# Training loss (for one batch) at step 0: 0.4349314570426941
# Epoch 12, Loss: 0.4349314570426941, Val Loss: 0.4545777142047882
# end of epoch.
# start of epoch 13
# Training loss (for one batch) at step 0: 0.48640668392181396
# Epoch 13, Loss: 0.48640668392181396, Val Loss: 0.4932059049606323
# end of epoch.
# start of epoch 14
# Training loss (for one batch) at step 0: 0.5979380011558533
# Epoch 14, Loss: 0.5979380011558533, Val Loss: 0.5616407990455627
# end of epoch.
# start of epoch 15
# Training loss (for one batch) at step 0: 0.4756113886833191
# Epoch 15, Loss: 0.4756113886833191, Val Loss: 0.47989991307258606
# end of epoch.
# start of epoch 16
# Training loss (for one batch) at step 0: 0.33546656370162964
# Epoch 16, Loss: 0.33546656370162964, Val Loss: 0.47418665885925293
# end of epoch.
# start of epoch 17
# Training loss (for one batch) at step 0: 0.4888516664505005
# Epoch 17, Loss: 0.4888516664505005, Val Loss: 0.5205814838409424
# end of epoch.
# start of epoch 18
# Training loss (for one batch) at step 0: 0.4651477634906769
# Epoch 18, Loss: 0.4651477634906769, Val Loss: 0.48701703548431396
# end of epoch.
# start of epoch 19
# Training loss (for one batch) at step 0: 0.436383455991745
# Epoch 19, Loss: 0.436383455991745, Val Loss: 0.5198742151260376
# end of epoch.
# start of epoch 20
# Training loss (for one batch) at step 0: 0.5760212540626526
# Epoch 20, Loss: 0.5760212540626526, Val Loss: 0.44763654470443726
# end of epoch.
# start of epoch 21
# Training loss (for one batch) at step 0: 0.4440297484397888
# Epoch 21, Loss: 0.4440297484397888, Val Loss: 0.531254231929779
# end of epoch.
# start of epoch 22
# Training loss (for one batch) at step 0: 0.5683196783065796
# Epoch 22, Loss: 0.5683196783065796, Val Loss: 0.48054105043411255
# end of epoch.
# start of epoch 23
# Training loss (for one batch) at step 0: 0.4937025308609009
# Epoch 23, Loss: 0.4937025308609009, Val Loss: 0.46829548478126526
# end of epoch.
# start of epoch 24
# Training loss (for one batch) at step 0: 0.5589279532432556
# Epoch 24, Loss: 0.5589279532432556, Val Loss: 0.5275559425354004
# end of epoch.
# start of epoch 25
# Training loss (for one batch) at step 0: 0.5206498503684998
# Epoch 25, Loss: 0.5206498503684998, Val Loss: 0.4935802221298218
# end of epoch.
# start of epoch 26
# Training loss (for one batch) at step 0: 0.5050920844078064
# Epoch 26, Loss: 0.5050920844078064, Val Loss: 0.44191908836364746
# end of epoch.
# start of epoch 27
# Training loss (for one batch) at step 0: 0.463470995426178
# Epoch 27, Loss: 0.463470995426178, Val Loss: 0.44589632749557495
# end of epoch.
# start of epoch 28
# Training loss (for one batch) at step 0: 0.6037217378616333
# Epoch 28, Loss: 0.6037217378616333, Val Loss: 0.3905184268951416
# end of epoch.
# start of epoch 29
# Training loss (for one batch) at step 0: 0.5172477960586548
# Epoch 29, Loss: 0.5172477960586548, Val Loss: 0.42363590002059937
# end of epoch.
# start of epoch 30
# Training loss (for one batch) at step 0: 0.44544294476509094
# Epoch 30, Loss: 0.44544294476509094, Val Loss: 0.41999781131744385
# end of epoch.
# start of epoch 31
# Training loss (for one batch) at step 0: 0.5615904927253723
# Epoch 31, Loss: 0.5615904927253723, Val Loss: 0.4127749502658844
# end of epoch.
# start of epoch 32
# Training loss (for one batch) at step 0: 0.4953244626522064
# Epoch 32, Loss: 0.4953244626522064, Val Loss: 0.4940985441207886
# end of epoch.
# start of epoch 33
# Training loss (for one batch) at step 0: 0.6039695143699646
# Epoch 33, Loss: 0.6039695143699646, Val Loss: 0.5112569332122803
# end of epoch.
# start of epoch 34
# Training loss (for one batch) at step 0: 0.4658009707927704
# Epoch 34, Loss: 0.4658009707927704, Val Loss: 0.4733119308948517
# end of epoch.
# start of epoch 35
# Training loss (for one batch) at step 0: 0.44011861085891724
# Epoch 35, Loss: 0.44011861085891724, Val Loss: 0.4660324454307556
# end of epoch.
# start of epoch 36
# Training loss (for one batch) at step 0: 0.512261152267456
# Epoch 36, Loss: 0.512261152267456, Val Loss: 0.5108099579811096
# end of epoch.
# start of epoch 37
# Training loss (for one batch) at step 0: 0.5106873512268066
# Epoch 37, Loss: 0.5106873512268066, Val Loss: 0.5535329580307007
# end of epoch.
# start of epoch 38
# Training loss (for one batch) at step 0: 0.4918075501918793
# Epoch 38, Loss: 0.4918075501918793, Val Loss: 0.538049578666687
# end of epoch.
# start of epoch 39
# Training loss (for one batch) at step 0: 0.4812690317630768
# Epoch 39, Loss: 0.4812690317630768, Val Loss: 0.506639301776886
# end of epoch.
# start of epoch 40
# Training loss (for one batch) at step 0: 0.518593430519104
# Epoch 40, Loss: 0.518593430519104, Val Loss: 0.4594365358352661
# end of epoch.
# start of epoch 41
# Training loss (for one batch) at step 0: 0.5203948020935059
# Epoch 41, Loss: 0.5203948020935059, Val Loss: 0.49117836356163025
# end of epoch.
# start of epoch 42
# Training loss (for one batch) at step 0: 0.4206269383430481
# Epoch 42, Loss: 0.4206269383430481, Val Loss: 0.5176917314529419
# end of epoch.
# start of epoch 43
# Training loss (for one batch) at step 0: 0.5033637881278992
# Epoch 43, Loss: 0.5033637881278992, Val Loss: 0.4982451796531677
# end of epoch.
# start of epoch 44
# Training loss (for one batch) at step 0: 0.4563314914703369
# Epoch 44, Loss: 0.4563314914703369, Val Loss: 0.5696738958358765
# end of epoch.
# start of epoch 45
# Training loss (for one batch) at step 0: 0.5374769568443298
# Epoch 45, Loss: 0.5374769568443298, Val Loss: 0.5221592783927917
# end of epoch.
# start of epoch 46
# Training loss (for one batch) at step 0: 0.5409786105155945
# Epoch 46, Loss: 0.5409786105155945, Val Loss: 0.5066879391670227
# end of epoch.
# start of epoch 47
# Training loss (for one batch) at step 0: 0.5139039754867554
# Epoch 47, Loss: 0.5139039754867554, Val Loss: 0.45769044756889343
# end of epoch.
# start of epoch 48
# Training loss (for one batch) at step 0: 0.5813197493553162
# Epoch 48, Loss: 0.5813197493553162, Val Loss: 0.4457736909389496
# end of epoch.
# start of epoch 49
# Training loss (for one batch) at step 0: 0.5257031917572021
# Epoch 49, Loss: 0.5257031917572021, Val Loss: 0.39281973242759705
# end of epoch.
# start of epoch 50
# Training loss (for one batch) at step 0: 0.5213693976402283
# Epoch 50, Loss: 0.5213693976402283, Val Loss: 0.5495991706848145
# end of epoch.
# start of epoch 51
# Training loss (for one batch) at step 0: 0.5323788523674011
# Epoch 51, Loss: 0.5323788523674011, Val Loss: 0.49840617179870605
# end of epoch.
# start of epoch 52
# Training loss (for one batch) at step 0: 0.5295822620391846
# Epoch 52, Loss: 0.5295822620391846, Val Loss: 0.45883908867836
# end of epoch.
# start of epoch 53
# Training loss (for one batch) at step 0: 0.3490840196609497
# Epoch 53, Loss: 0.3490840196609497, Val Loss: 0.5556533932685852
# end of epoch.
# start of epoch 54
# Training loss (for one batch) at step 0: 0.505532443523407
# Epoch 54, Loss: 0.505532443523407, Val Loss: 0.5665066242218018
# end of epoch.
# start of epoch 55
# Training loss (for one batch) at step 0: 0.5074228644371033
# Epoch 55, Loss: 0.5074228644371033, Val Loss: 0.5259538292884827
# end of epoch.
# start of epoch 56
# Training loss (for one batch) at step 0: 0.47638535499572754
# Epoch 56, Loss: 0.47638535499572754, Val Loss: 0.5769562125205994
# end of epoch.
# start of epoch 57
# Training loss (for one batch) at step 0: 0.482738196849823
# Epoch 57, Loss: 0.482738196849823, Val Loss: 0.5295934081077576
# end of epoch.
# start of epoch 58
# Training loss (for one batch) at step 0: 0.4623218774795532
# Epoch 58, Loss: 0.4623218774795532, Val Loss: 0.4977138340473175
# end of epoch.
# start of epoch 59
# Training loss (for one batch) at step 0: 0.48170340061187744
# Epoch 59, Loss: 0.48170340061187744, Val Loss: 0.3885011672973633
# end of epoch.
# start of epoch 60
# Training loss (for one batch) at step 0: 0.4955378770828247
# Epoch 60, Loss: 0.4955378770828247, Val Loss: 0.5188688635826111
# end of epoch.
# start of epoch 61
# Training loss (for one batch) at step 0: 0.4900152385234833
# Epoch 61, Loss: 0.4900152385234833, Val Loss: 0.5712443590164185
# end of epoch.
# start of epoch 62
# Training loss (for one batch) at step 0: 0.5553090572357178
# Epoch 62, Loss: 0.5553090572357178, Val Loss: 0.45947787165641785
# end of epoch.
# start of epoch 63
# Training loss (for one batch) at step 0: 0.466839462518692
# Epoch 63, Loss: 0.466839462518692, Val Loss: 0.4761607348918915
# end of epoch.
# start of epoch 64
# Training loss (for one batch) at step 0: 0.5008081793785095
# Epoch 64, Loss: 0.5008081793785095, Val Loss: 0.6495875716209412
# end of epoch.
# start of epoch 65
# Training loss (for one batch) at step 0: 0.4761750400066376
# Epoch 65, Loss: 0.4761750400066376, Val Loss: 0.4373033940792084
# end of epoch.
# start of epoch 66
# Training loss (for one batch) at step 0: 0.5344802737236023
# Epoch 66, Loss: 0.5344802737236023, Val Loss: 0.5090218186378479
# end of epoch.
# start of epoch 67
# Training loss (for one batch) at step 0: 0.4012971520423889
# Epoch 67, Loss: 0.4012971520423889, Val Loss: 0.4524284899234772
# end of epoch.
# start of epoch 68
# Training loss (for one batch) at step 0: 0.4419783651828766
# Epoch 68, Loss: 0.4419783651828766, Val Loss: 0.4687995910644531
# end of epoch.
# start of epoch 69
# Training loss (for one batch) at step 0: 0.5816426277160645
# Epoch 69, Loss: 0.5816426277160645, Val Loss: 0.5167897939682007
# end of epoch.
# start of epoch 70
# Training loss (for one batch) at step 0: 0.5418368577957153
# Epoch 70, Loss: 0.5418368577957153, Val Loss: 0.41020330786705017
# end of epoch.
# start of epoch 71
# Training loss (for one batch) at step 0: 0.5599846243858337
# Epoch 71, Loss: 0.5599846243858337, Val Loss: 0.47264987230300903
# end of epoch.
# start of epoch 72
# Training loss (for one batch) at step 0: 0.5335127115249634
# Epoch 72, Loss: 0.5335127115249634, Val Loss: 0.4076017439365387
# end of epoch.
# start of epoch 73
# Training loss (for one batch) at step 0: 0.47625216841697693
# Epoch 73, Loss: 0.47625216841697693, Val Loss: 0.5004957914352417
# end of epoch.
# start of epoch 74
# Training loss (for one batch) at step 0: 0.5181024074554443
# Epoch 74, Loss: 0.5181024074554443, Val Loss: 0.48107150197029114
# end of epoch.
# start of epoch 75
# Training loss (for one batch) at step 0: 0.4426933526992798
# Epoch 75, Loss: 0.4426933526992798, Val Loss: 0.5672447681427002
# end of epoch.
# start of epoch 76
# Training loss (for one batch) at step 0: 0.547050416469574
# Epoch 76, Loss: 0.547050416469574, Val Loss: 0.4976162314414978
# end of epoch.
# start of epoch 77
# Training loss (for one batch) at step 0: 0.5383424162864685
# Epoch 77, Loss: 0.5383424162864685, Val Loss: 0.532675564289093
# end of epoch.
# start of epoch 78
# Training loss (for one batch) at step 0: 0.48245975375175476
# Epoch 78, Loss: 0.48245975375175476, Val Loss: 0.5429524779319763
# end of epoch.
# start of epoch 79
# Training loss (for one batch) at step 0: 0.514201283454895
# Epoch 79, Loss: 0.514201283454895, Val Loss: 0.4287508428096771
# end of epoch.
# start of epoch 80
# Training loss (for one batch) at step 0: 0.4734349846839905
# Epoch 80, Loss: 0.4734349846839905, Val Loss: 0.5073368549346924
# end of epoch.
# start of epoch 81
# Training loss (for one batch) at step 0: 0.5134397745132446
# Epoch 81, Loss: 0.5134397745132446, Val Loss: 0.3673194944858551
# end of epoch.
# start of epoch 82
# Training loss (for one batch) at step 0: 0.49755603075027466
# Epoch 82, Loss: 0.49755603075027466, Val Loss: 0.4573388695716858
# end of epoch.
# start of epoch 83
# Training loss (for one batch) at step 0: 0.4356705844402313
# Epoch 83, Loss: 0.4356705844402313, Val Loss: 0.47744321823120117
# end of epoch.
# start of epoch 84
# Training loss (for one batch) at step 0: 0.5360152125358582
# Epoch 84, Loss: 0.5360152125358582, Val Loss: 0.5089743733406067
# end of epoch.
# start of epoch 85
# Training loss (for one batch) at step 0: 0.5011578798294067
# Epoch 85, Loss: 0.5011578798294067, Val Loss: 0.49406230449676514
# end of epoch.
# start of epoch 86
# Training loss (for one batch) at step 0: 0.5255739092826843
# Epoch 86, Loss: 0.5255739092826843, Val Loss: 0.5290042161941528
# end of epoch.
# start of epoch 87
# Training loss (for one batch) at step 0: 0.512649416923523
# Epoch 87, Loss: 0.512649416923523, Val Loss: 0.5076760649681091
# end of epoch.
# start of epoch 88
# Training loss (for one batch) at step 0: 0.553731381893158
# Epoch 88, Loss: 0.553731381893158, Val Loss: 0.37877514958381653
# end of epoch.
# start of epoch 89
# Training loss (for one batch) at step 0: 0.45935362577438354
# Epoch 89, Loss: 0.45935362577438354, Val Loss: 0.4962810277938843
# end of epoch.
# start of epoch 90
# Training loss (for one batch) at step 0: 0.5409315824508667
# Epoch 90, Loss: 0.5409315824508667, Val Loss: 0.4336021840572357
# end of epoch.
# start of epoch 91
# Training loss (for one batch) at step 0: 0.4874776601791382
# Epoch 91, Loss: 0.4874776601791382, Val Loss: 0.5571755766868591
# end of epoch.
# start of epoch 92
# Training loss (for one batch) at step 0: 0.4933597445487976
# Epoch 92, Loss: 0.4933597445487976, Val Loss: 0.44406232237815857
# end of epoch.
# start of epoch 93
# Training loss (for one batch) at step 0: 0.439203143119812
# Epoch 93, Loss: 0.439203143119812, Val Loss: 0.4305366575717926
# end of epoch.
# start of epoch 94
# Training loss (for one batch) at step 0: 0.47440192103385925
# Epoch 94, Loss: 0.47440192103385925, Val Loss: 0.4903813898563385
# end of epoch.
# start of epoch 95
# Training loss (for one batch) at step 0: 0.44867369532585144
# Epoch 95, Loss: 0.44867369532585144, Val Loss: 0.503558337688446
# end of epoch.
# start of epoch 96
# Training loss (for one batch) at step 0: 0.5398872494697571
# Epoch 96, Loss: 0.5398872494697571, Val Loss: 0.48633748292922974
# end of epoch.
# start of epoch 97
# Training loss (for one batch) at step 0: 0.42546454071998596
# Epoch 97, Loss: 0.42546454071998596, Val Loss: 0.4410530924797058
# end of epoch.
# start of epoch 98
# Training loss (for one batch) at step 0: 0.5631614923477173
# Epoch 98, Loss: 0.5631614923477173, Val Loss: 0.4492708146572113
# end of epoch.
# start of epoch 99
# Training loss (for one batch) at step 0: 0.45785629749298096
# Epoch 99, Loss: 0.45785629749298096, Val Loss: 0.4878038465976715
# end of epoch.
# start of epoch 100
# Training loss (for one batch) at step 0: 0.4644070565700531
# Epoch 100, Loss: 0.4644070565700531, Val Loss: 0.49199360609054565
# end of epoch.
# start of epoch 101
# Training loss (for one batch) at step 0: 0.47729822993278503
# Epoch 101, Loss: 0.47729822993278503, Val Loss: 0.45811164379119873
# end of epoch.
# start of epoch 102
# Training loss (for one batch) at step 0: 0.49028730392456055
# Epoch 102, Loss: 0.49028730392456055, Val Loss: 0.4951218068599701
# end of epoch.
# start of epoch 103
# Training loss (for one batch) at step 0: 0.5734382271766663
# Epoch 103, Loss: 0.5734382271766663, Val Loss: 0.4337274134159088
# end of epoch.
# start of epoch 104
# Training loss (for one batch) at step 0: 0.48084092140197754
# Epoch 104, Loss: 0.48084092140197754, Val Loss: 0.5568633675575256
# end of epoch.
# start of epoch 105
# Training loss (for one batch) at step 0: 0.42918336391448975
# Epoch 105, Loss: 0.42918336391448975, Val Loss: 0.45565783977508545
# end of epoch.
# start of epoch 106
# Training loss (for one batch) at step 0: 0.47016653418540955
# Epoch 106, Loss: 0.47016653418540955, Val Loss: 0.3892067074775696
# end of epoch.
# start of epoch 107
# Training loss (for one batch) at step 0: 0.4905271828174591
# Epoch 107, Loss: 0.4905271828174591, Val Loss: 0.4385889768600464
# end of epoch.
# start of epoch 108
# Training loss (for one batch) at step 0: 0.38017553091049194
# Epoch 108, Loss: 0.38017553091049194, Val Loss: 0.49004101753234863
# end of epoch.
# start of epoch 109
# Training loss (for one batch) at step 0: 0.46285468339920044
# Epoch 109, Loss: 0.46285468339920044, Val Loss: 0.4652467966079712
# end of epoch.
# start of epoch 110
# Training loss (for one batch) at step 0: 0.47326135635375977
# Epoch 110, Loss: 0.47326135635375977, Val Loss: 0.4688059091567993
# end of epoch.
# start of epoch 111
# Training loss (for one batch) at step 0: 0.4236316680908203
# Epoch 111, Loss: 0.4236316680908203, Val Loss: 0.5890540480613708
# end of epoch.
# start of epoch 112
# Training loss (for one batch) at step 0: 0.5009804964065552
# Epoch 112, Loss: 0.5009804964065552, Val Loss: 0.5225657820701599
# end of epoch.
# start of epoch 113
# Training loss (for one batch) at step 0: 0.5900781750679016
# Epoch 113, Loss: 0.5900781750679016, Val Loss: 0.35249608755111694
# end of epoch.
# start of epoch 114
# Training loss (for one batch) at step 0: 0.5214461088180542
# Epoch 114, Loss: 0.5214461088180542, Val Loss: 0.45055392384529114
# end of epoch.
# start of epoch 115
# Training loss (for one batch) at step 0: 0.5801333785057068
# Epoch 115, Loss: 0.5801333785057068, Val Loss: 0.46941882371902466
# end of epoch.
# start of epoch 116
# Training loss (for one batch) at step 0: 0.5135616064071655
# Epoch 116, Loss: 0.5135616064071655, Val Loss: 0.5355784296989441
# end of epoch.
# start of epoch 117
# Training loss (for one batch) at step 0: 0.5508996248245239
# Epoch 117, Loss: 0.5508996248245239, Val Loss: 0.4180145859718323
# end of epoch.
# start of epoch 118
# Training loss (for one batch) at step 0: 0.5476433038711548
# Epoch 118, Loss: 0.5476433038711548, Val Loss: 0.4927767813205719
# end of epoch.
# start of epoch 119
# Training loss (for one batch) at step 0: 0.5014583468437195
# Epoch 119, Loss: 0.5014583468437195, Val Loss: 0.5178496241569519
# end of epoch.
# start of epoch 120
# Training loss (for one batch) at step 0: 0.5722208619117737
# Epoch 120, Loss: 0.5722208619117737, Val Loss: 0.4493750333786011
# end of epoch.
# start of epoch 121
# Training loss (for one batch) at step 0: 0.4825131893157959
# Epoch 121, Loss: 0.4825131893157959, Val Loss: 0.6256555914878845
# end of epoch.
# start of epoch 122
# Training loss (for one batch) at step 0: 0.49489349126815796
# Epoch 122, Loss: 0.49489349126815796, Val Loss: 0.5269814729690552
# end of epoch.
# start of epoch 123
# Training loss (for one batch) at step 0: 0.3973127007484436
# Epoch 123, Loss: 0.3973127007484436, Val Loss: 0.44091519713401794
# end of epoch.
# start of epoch 124
# Training loss (for one batch) at step 0: 0.4703579843044281
# Epoch 124, Loss: 0.4703579843044281, Val Loss: 0.46348050236701965
# end of epoch.
# start of epoch 125
# Training loss (for one batch) at step 0: 0.46650299429893494
# Epoch 125, Loss: 0.46650299429893494, Val Loss: 0.4677882194519043
# end of epoch.
# start of epoch 126
# Training loss (for one batch) at step 0: 0.5080901384353638
# Epoch 126, Loss: 0.5080901384353638, Val Loss: 0.49518200755119324
# end of epoch.
# start of epoch 127
# Training loss (for one batch) at step 0: 0.4716675281524658
# Epoch 127, Loss: 0.4716675281524658, Val Loss: 0.5062830448150635
# end of epoch.
# start of epoch 128
# Training loss (for one batch) at step 0: 0.36073723435401917
# Epoch 128, Loss: 0.36073723435401917, Val Loss: 0.429879754781723
# end of epoch.
# start of epoch 129
# Training loss (for one batch) at step 0: 0.45478561520576477
# Epoch 129, Loss: 0.45478561520576477, Val Loss: 0.4758724868297577
# end of epoch.
# start of epoch 130
# Training loss (for one batch) at step 0: 0.5329574346542358
# Epoch 130, Loss: 0.5329574346542358, Val Loss: 0.569451630115509
# end of epoch.
# start of epoch 131
# Training loss (for one batch) at step 0: 0.4234234690666199
# Epoch 131, Loss: 0.4234234690666199, Val Loss: 0.5774126648902893
# end of epoch.
# start of epoch 132
# Training loss (for one batch) at step 0: 0.4545672535896301
# Epoch 132, Loss: 0.4545672535896301, Val Loss: 0.5765988230705261
# end of epoch.
# start of epoch 133
# Training loss (for one batch) at step 0: 0.5543113946914673
# Epoch 133, Loss: 0.5543113946914673, Val Loss: 0.4944911599159241
# end of epoch.
# start of epoch 134
# Training loss (for one batch) at step 0: 0.4808056056499481
# Epoch 134, Loss: 0.4808056056499481, Val Loss: 0.32800331711769104
# end of epoch.
# start of epoch 135
# Training loss (for one batch) at step 0: 0.5722440481185913
# Epoch 135, Loss: 0.5722440481185913, Val Loss: 0.439096063375473
# end of epoch.
# start of epoch 136
# Training loss (for one batch) at step 0: 0.503701388835907
# Epoch 136, Loss: 0.503701388835907, Val Loss: 0.533785879611969
# end of epoch.
# start of epoch 137
# Training loss (for one batch) at step 0: 0.5094422698020935
# Epoch 137, Loss: 0.5094422698020935, Val Loss: 0.5452486276626587
# end of epoch.
# start of epoch 138
# Training loss (for one batch) at step 0: 0.42190685868263245
# Epoch 138, Loss: 0.42190685868263245, Val Loss: 0.5208943486213684
# end of epoch.
# start of epoch 139
# Training loss (for one batch) at step 0: 0.5965040922164917
# Epoch 139, Loss: 0.5965040922164917, Val Loss: 0.5726855397224426
# end of epoch.
# start of epoch 140
# Training loss (for one batch) at step 0: 0.4610845446586609
# Epoch 140, Loss: 0.4610845446586609, Val Loss: 0.45715489983558655
# end of epoch.
# start of epoch 141
# Training loss (for one batch) at step 0: 0.5606251358985901
# Epoch 141, Loss: 0.5606251358985901, Val Loss: 0.514621913433075
# end of epoch.
# start of epoch 142
# Training loss (for one batch) at step 0: 0.49081867933273315
# Epoch 142, Loss: 0.49081867933273315, Val Loss: 0.5036506056785583
# end of epoch.
# start of epoch 143
# Training loss (for one batch) at step 0: 0.5336839556694031
# Epoch 143, Loss: 0.5336839556694031, Val Loss: 0.5414583086967468
# end of epoch.
# start of epoch 144
# Training loss (for one batch) at step 0: 0.4355360269546509
# Epoch 144, Loss: 0.4355360269546509, Val Loss: 0.4968690872192383
# end of epoch.
# start of epoch 145
# Training loss (for one batch) at step 0: 0.5348408222198486
# Epoch 145, Loss: 0.5348408222198486, Val Loss: 0.4834991693496704
# end of epoch.
# start of epoch 146
# Training loss (for one batch) at step 0: 0.5154876112937927
# Epoch 146, Loss: 0.5154876112937927, Val Loss: 0.4837447702884674
# end of epoch.
# start of epoch 147
# Training loss (for one batch) at step 0: 0.5100864171981812
# Epoch 147, Loss: 0.5100864171981812, Val Loss: 0.5765308141708374
# end of epoch.
# start of epoch 148
# Training loss (for one batch) at step 0: 0.5208722352981567
# Epoch 148, Loss: 0.5208722352981567, Val Loss: 0.4934218227863312
# end of epoch.
# start of epoch 149
# Training loss (for one batch) at step 0: 0.48179125785827637
# Epoch 149, Loss: 0.48179125785827637, Val Loss: 0.5123639106750488
# end of epoch.
# start of epoch 150
# Training loss (for one batch) at step 0: 0.4140183925628662
# Epoch 150, Loss: 0.4140183925628662, Val Loss: 0.5381132364273071
# end of epoch.
# start of epoch 151
# Training loss (for one batch) at step 0: 0.4883240759372711
# Epoch 151, Loss: 0.4883240759372711, Val Loss: 0.4960615634918213
# end of epoch.
# start of epoch 152
# Training loss (for one batch) at step 0: 0.42794543504714966
# Epoch 152, Loss: 0.42794543504714966, Val Loss: 0.5833501815795898
# end of epoch.
# start of epoch 153
# Training loss (for one batch) at step 0: 0.44928178191185
# Epoch 153, Loss: 0.44928178191185, Val Loss: 0.5534402132034302
# end of epoch.
# start of epoch 154
# Training loss (for one batch) at step 0: 0.435962438583374
# Epoch 154, Loss: 0.435962438583374, Val Loss: 0.44570109248161316
# end of epoch.
# start of epoch 155
# Training loss (for one batch) at step 0: 0.41886261105537415
# Epoch 155, Loss: 0.41886261105537415, Val Loss: 0.5924562811851501
# end of epoch.
# start of epoch 156
# Training loss (for one batch) at step 0: 0.47372037172317505
# Epoch 156, Loss: 0.47372037172317505, Val Loss: 0.46572980284690857
# end of epoch.
# start of epoch 157
# Training loss (for one batch) at step 0: 0.5258721113204956
# Epoch 157, Loss: 0.5258721113204956, Val Loss: 0.5091937780380249
# end of epoch.
# start of epoch 158
# Training loss (for one batch) at step 0: 0.46347784996032715
# Epoch 158, Loss: 0.46347784996032715, Val Loss: 0.4765949547290802
# end of epoch.
# start of epoch 159
# Training loss (for one batch) at step 0: 0.48504161834716797
# Epoch 159, Loss: 0.48504161834716797, Val Loss: 0.4267828166484833
# end of epoch.
# start of epoch 160
# Training loss (for one batch) at step 0: 0.47419866919517517
# Epoch 160, Loss: 0.47419866919517517, Val Loss: 0.5641480088233948
# end of epoch.
# start of epoch 161
# Training loss (for one batch) at step 0: 0.5404940247535706
# Epoch 161, Loss: 0.5404940247535706, Val Loss: 0.47069811820983887
# end of epoch.
# start of epoch 162
# Training loss (for one batch) at step 0: 0.5258541703224182
# Epoch 162, Loss: 0.5258541703224182, Val Loss: 0.44942042231559753
# end of epoch.
# start of epoch 163
# Training loss (for one batch) at step 0: 0.4573836922645569
# Epoch 163, Loss: 0.4573836922645569, Val Loss: 0.5936691761016846
# end of epoch.
# start of epoch 164
# Training loss (for one batch) at step 0: 0.5204290151596069
# Epoch 164, Loss: 0.5204290151596069, Val Loss: 0.4886597692966461
# end of epoch.
# start of epoch 165
# Training loss (for one batch) at step 0: 0.4769394099712372
# Epoch 165, Loss: 0.4769394099712372, Val Loss: 0.5233604311943054
# end of epoch.
# start of epoch 166
# Training loss (for one batch) at step 0: 0.5587181448936462
# Epoch 166, Loss: 0.5587181448936462, Val Loss: 0.3663862347602844
# end of epoch.
# start of epoch 167
# Training loss (for one batch) at step 0: 0.4927899241447449
# Epoch 167, Loss: 0.4927899241447449, Val Loss: 0.5035279989242554
# end of epoch.
# start of epoch 168
# Training loss (for one batch) at step 0: 0.4470467269420624
# Epoch 168, Loss: 0.4470467269420624, Val Loss: 0.3827817142009735
# end of epoch.
# start of epoch 169
# Training loss (for one batch) at step 0: 0.44914868474006653
# Epoch 169, Loss: 0.44914868474006653, Val Loss: 0.5354340672492981
# end of epoch.
# start of epoch 170
# Training loss (for one batch) at step 0: 0.5609357357025146
# Epoch 170, Loss: 0.5609357357025146, Val Loss: 0.43052443861961365
# end of epoch.
# start of epoch 171
# Training loss (for one batch) at step 0: 0.5265286564826965
# Epoch 171, Loss: 0.5265286564826965, Val Loss: 0.5585227608680725
# end of epoch.
# start of epoch 172
# Training loss (for one batch) at step 0: 0.4761432707309723
# Epoch 172, Loss: 0.4761432707309723, Val Loss: 0.4847193956375122
# end of epoch.
# start of epoch 173
# Training loss (for one batch) at step 0: 0.4799768924713135
# Epoch 173, Loss: 0.4799768924713135, Val Loss: 0.5364682674407959
# end of epoch.
# start of epoch 174
# Training loss (for one batch) at step 0: 0.5259674787521362
# Epoch 174, Loss: 0.5259674787521362, Val Loss: 0.5185568928718567
# end of epoch.
# start of epoch 175
# Training loss (for one batch) at step 0: 0.46877723932266235
# Epoch 175, Loss: 0.46877723932266235, Val Loss: 0.503054678440094
# end of epoch.
# start of epoch 176
# Training loss (for one batch) at step 0: 0.5927184820175171
# Epoch 176, Loss: 0.5927184820175171, Val Loss: 0.5532684922218323
# end of epoch.
# start of epoch 177
# Training loss (for one batch) at step 0: 0.4453311264514923
# Epoch 177, Loss: 0.4453311264514923, Val Loss: 0.41355040669441223
# end of epoch.
# start of epoch 178
# Training loss (for one batch) at step 0: 0.5100809931755066
# Epoch 178, Loss: 0.5100809931755066, Val Loss: 0.4110405743122101
# end of epoch.
# start of epoch 179
# Training loss (for one batch) at step 0: 0.518634557723999
# Epoch 179, Loss: 0.518634557723999, Val Loss: 0.4504840075969696
# end of epoch.
# start of epoch 180
# Training loss (for one batch) at step 0: 0.5344801545143127
# Epoch 180, Loss: 0.5344801545143127, Val Loss: 0.4839812219142914
# end of epoch.
# start of epoch 181
# Training loss (for one batch) at step 0: 0.403825044631958
# Epoch 181, Loss: 0.403825044631958, Val Loss: 0.4978026747703552
# end of epoch.
# start of epoch 182
# Training loss (for one batch) at step 0: 0.4965170621871948
# Epoch 182, Loss: 0.4965170621871948, Val Loss: 0.38206741213798523
# end of epoch.
# start of epoch 183
# Training loss (for one batch) at step 0: 0.5551437139511108
# Epoch 183, Loss: 0.5551437139511108, Val Loss: 0.4844924509525299
# end of epoch.
# start of epoch 184
# Training loss (for one batch) at step 0: 0.5578048229217529
# Epoch 184, Loss: 0.5578048229217529, Val Loss: 0.457489550113678
# end of epoch.
# start of epoch 185
# Training loss (for one batch) at step 0: 0.5241541266441345
# Epoch 185, Loss: 0.5241541266441345, Val Loss: 0.4799257516860962
# end of epoch.
# start of epoch 186
# Training loss (for one batch) at step 0: 0.4747460186481476
# Epoch 186, Loss: 0.4747460186481476, Val Loss: 0.5123950242996216
# end of epoch.
# start of epoch 187
# Training loss (for one batch) at step 0: 0.4535512924194336
# Epoch 187, Loss: 0.4535512924194336, Val Loss: 0.582203209400177
# end of epoch.
# start of epoch 188
# Training loss (for one batch) at step 0: 0.5261052250862122
# Epoch 188, Loss: 0.5261052250862122, Val Loss: 0.545877993106842
# end of epoch.
# start of epoch 189
# Training loss (for one batch) at step 0: 0.43471306562423706
# Epoch 189, Loss: 0.43471306562423706, Val Loss: 0.42309901118278503
# end of epoch.
# start of epoch 190
# Training loss (for one batch) at step 0: 0.5274806618690491
# Epoch 190, Loss: 0.5274806618690491, Val Loss: 0.5721940398216248
# end of epoch.
# start of epoch 191
# Training loss (for one batch) at step 0: 0.527476966381073
# Epoch 191, Loss: 0.527476966381073, Val Loss: 0.4735819697380066
# end of epoch.
# start of epoch 192
# Training loss (for one batch) at step 0: 0.4177553951740265
# Epoch 192, Loss: 0.4177553951740265, Val Loss: 0.44583582878112793
# end of epoch.
# start of epoch 193
# Training loss (for one batch) at step 0: 0.5656916499137878
# Epoch 193, Loss: 0.5656916499137878, Val Loss: 0.4961961507797241
# end of epoch.
# start of epoch 194
# Training loss (for one batch) at step 0: 0.49172306060791016
# Epoch 194, Loss: 0.49172306060791016, Val Loss: 0.5099368095397949
# end of epoch.
# start of epoch 195
# Training loss (for one batch) at step 0: 0.4685249626636505
# Epoch 195, Loss: 0.4685249626636505, Val Loss: 0.4523499310016632
# end of epoch.
# start of epoch 196
# Training loss (for one batch) at step 0: 0.532948911190033
# Epoch 196, Loss: 0.532948911190033, Val Loss: 0.5387112498283386
# end of epoch.
# start of epoch 197
# Training loss (for one batch) at step 0: 0.5120590925216675
# Epoch 197, Loss: 0.5120590925216675, Val Loss: 0.5303472876548767
# end of epoch.
# start of epoch 198
# Training loss (for one batch) at step 0: 0.442805677652359
# Epoch 198, Loss: 0.442805677652359, Val Loss: 0.4247771203517914
# end of epoch.
# start of epoch 199
# Training loss (for one batch) at step 0: 0.4677448272705078
# Epoch 199, Loss: 0.4677448272705078, Val Loss: 0.46088793873786926
# end of epoch.
# start of epoch 200
# Training loss (for one batch) at step 0: 0.47969308495521545
# Epoch 200, Loss: 0.47969308495521545, Val Loss: 0.4349216818809509
# end of epoch.
# Checkpoint directory :  checkpoints/CNNgeo/200507_regressor_filter_size_up
# Tensorboard log directory :  logs/CNNgeo/200507_regressor_filter_size_up

# %%
model.summary()
# Out:
# Model: "cnn_geo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature__extractor (Feature_ multiple                  113600
# _________________________________________________________________
# correlation_network (Correla multiple                  0
# _________________________________________________________________
# spatial_transformer_regresso multiple                  875250
# =================================================================
# Total params: 988,850
# Trainable params: 988,146
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# # 3. Debug

# %%
datasets = load_data(['train'], config)
ds = datasets['train'].batch(1)
# Out:
# train dataset amount : 1

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
#image_B_hat = np.ones([1, 64, 64, 3])
pred, score = model(image_A, image_B)

# %%
print("parameter shape", pred.shape)
print("score shape", score.shape)
print(image_A.shape)
# Out:
# parameter shape (1, 9, 2)
# score shape (1, 16, 16, 16, 16)
# (1, 64, 64, 3)

# %% [markdown]
# ## 3.1. 입력 영상에 따른 모델 추정 확인

# %% [markdown]
# ### case 1) 임의의 기하관계를 갖는 영상 쌍 (image A, image B)

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred1 = pred.copy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.1697545   0.10623898]
#   [ 0.04899674 -0.17275314]
#   [ 0.15941344 -0.18629943]
#   [-0.16934071  0.03920197]
#   [-0.19635125  0.11792412]
#   [ 0.16363125 -0.14913164]
#   [-0.18460135 -0.15040469]
#   [ 0.11132684 -0.05433364]
#   [-0.07537756  0.06651749]]] and
#  pred : [[[ 2.6768646e-03 -2.2224975e-03]
#   [-2.2731363e-03 -4.6701790e-03]
#   [-1.0111692e-02  1.7620879e-03]
#   [ 3.3739703e-03  1.3939134e-05]
#   [-7.4683409e-03 -2.6148066e-03]
#   [ 2.1639722e-03 -1.2682738e-03]
#   [ 2.7663275e-03  3.2521104e-03]
#   [-7.3485577e-04  1.2735294e-02]
#   [ 1.4922377e-03 -1.7934504e-03]]]
# loss : [0.17616951]

# %% [markdown]
# ### case 2) 임의의 다른 기하관계를 갖는 영상 쌍 (image A, image B)

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred2 = pred.copy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.00571246 -0.15646143]
#   [-0.01987796  0.05698042]
#   [-0.04982848 -0.09091353]
#   [-0.10522737  0.16444182]
#   [ 0.11237164  0.0356225 ]
#   [-0.0553462  -0.16916052]
#   [-0.16677995  0.00028534]
#   [ 0.16417642  0.19048   ]
#   [ 0.00328512 -0.02653084]]] and
#  pred : [[[ 2.6768646e-03 -2.2224975e-03]
#   [-2.2731363e-03 -4.6701790e-03]
#   [-1.0111692e-02  1.7620879e-03]
#   [ 3.3739703e-03  1.3939134e-05]
#   [-7.4683409e-03 -2.6148066e-03]
#   [ 2.1639722e-03 -1.2682738e-03]
#   [ 2.7663275e-03  3.2521104e-03]
#   [-7.3485577e-04  1.2735294e-02]
#   [ 1.4922377e-03 -1.7934504e-03]]]
# loss : [0.10622273]

# %% [markdown]
# ### case 3) Image A와 연관 없는 image B(백색 사진)의 영상 쌍

# %%
image_B = np.ones([1, 64, 64, 3])
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred3 = pred.copy()
# Out:
# WARNING:tensorflow:Layer feature__extractor is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.00571246 -0.15646143]
#   [-0.01987796  0.05698042]
#   [-0.04982848 -0.09091353]
#   [-0.10522737  0.16444182]
#   [ 0.11237164  0.0356225 ]
#   [-0.0553462  -0.16916052]
#   [-0.16677995  0.00028534]
#   [ 0.16417642  0.19048   ]
#   [ 0.00328512 -0.02653084]]] and
#  pred : [[[ 2.6768646e-03 -2.2224975e-03]
#   [-2.2731363e-03 -4.6701790e-03]
#   [-1.0111692e-02  1.7620879e-03]
#   [ 3.3739703e-03  1.3939134e-05]
#   [-7.4683409e-03 -2.6148066e-03]
#   [ 2.1639722e-03 -1.2682738e-03]
#   [ 2.7663275e-03  3.2521104e-03]
#   [-7.3485577e-04  1.2735294e-02]
#   [ 1.4922377e-03 -1.7934504e-03]]]
# loss : [0.10622273]

# %%
print(pred1, "\n", pred2, "\n", pred3)
# Out:
# [[[ 2.6768646e-03 -2.2224975e-03]
#   [-2.2731363e-03 -4.6701790e-03]
#   [-1.0111692e-02  1.7620879e-03]
#   [ 3.3739703e-03  1.3939134e-05]
#   [-7.4683409e-03 -2.6148066e-03]
#   [ 2.1639722e-03 -1.2682738e-03]
#   [ 2.7663275e-03  3.2521104e-03]
#   [-7.3485577e-04  1.2735294e-02]
#   [ 1.4922377e-03 -1.7934504e-03]]]
#  [[[ 2.6768646e-03 -2.2224975e-03]
#   [-2.2731363e-03 -4.6701790e-03]
#   [-1.0111692e-02  1.7620879e-03]
#   [ 3.3739703e-03  1.3939134e-05]
#   [-7.4683409e-03 -2.6148066e-03]
#   [ 2.1639722e-03 -1.2682738e-03]
#   [ 2.7663275e-03  3.2521104e-03]
#   [-7.3485577e-04  1.2735294e-02]
#   [ 1.4922377e-03 -1.7934504e-03]]]
#  [[[ 2.6768646e-03 -2.2224975e-03]
#   [-2.2731363e-03 -4.6701790e-03]
#   [-1.0111692e-02  1.7620879e-03]
#   [ 3.3739703e-03  1.3939134e-05]
#   [-7.4683409e-03 -2.6148066e-03]
#   [ 2.1639722e-03 -1.2682738e-03]
#   [ 2.7663275e-03  3.2521104e-03]
#   [-7.3485577e-04  1.2735294e-02]
#   [ 1.4922377e-03 -1.7934504e-03]]]

# %% [markdown]
# case 1)와 case 2)는 동일한 영상을 다른 기하관계를 사용하여 두 개의 영상쌍(image pair)을 만든 경우를 말한다. 모델이 정상적이라면 각 영상쌍의 기하관계를 추정할 수 있을 것이다. 그러나 두 영상쌍이 다른 기하관계를 갖음에도 동일한 모션파라미터를 추정하였다. case 3)에서는 전혀 연관 없는 영상을 image B로 사용하였다. image B는 어떤 특징 정보도 없는 백색 사진임에도 불구하고 모델은 case 1)과 case 2)에서와 같은 모션파라미터를 추정하였다.

# %%
model.summary()
# Out:
# Model: "cnn_geo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature__extractor (Feature_ multiple                  113600
# _________________________________________________________________
# correlation_network (Correla multiple                  0
# _________________________________________________________________
# spatial_transformer_regresso multiple                  875250
# =================================================================
# Total params: 988,850
# Trainable params: 988,146
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# ## 3.2 Correlation 분포에 따른 Regressor 예측

# %% [markdown]
# 3.1의 case 1, 2, 3에서 Regressor은 같은 모션파라미터를 예측했다. 명확한 이유를 파악하기 위해 입력 correlation(matching scores)를 제어하며 spatial parameter regressor의 출력을 분석했다.

# %%
x = np.zeros([1, 16, 16, 16, 16]) # all correlations are zero
y = model.layers[2](x)
print(y)
# Out:
# WARNING:tensorflow:Layer spatial_transformer_regressor is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# tf.Tensor(
# [[ 2.6768646e-03 -2.2224975e-03 -2.2731363e-03 -4.6701790e-03
#   -1.0111692e-02  1.7620879e-03  3.3739703e-03  1.3939134e-05
#   -7.4683409e-03 -2.6148066e-03  2.1639722e-03 -1.2682738e-03
#    2.7663275e-03  3.2521104e-03 -7.3485577e-04  1.2735294e-02
#    1.4922377e-03 -1.7934504e-03]], shape=(1, 18), dtype=float32)

# %%
x = np.ones([1, 16, 16, 16, 16]) # all correlations are one
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[ 2.6768646e-03 -2.2224975e-03 -2.2731363e-03 -4.6701790e-03
#   -1.0111692e-02  1.7620879e-03  3.3739703e-03  1.3939134e-05
#   -7.4683409e-03 -2.6148066e-03  2.1639722e-03 -1.2682738e-03
#    2.7663275e-03  3.2521104e-03 -7.3485577e-04  1.2735294e-02
#    1.4922377e-03 -1.7934504e-03]], shape=(1, 18), dtype=float32)

# %%
x = np.random.normal(loc=0.5, scale=0.0, size=[1, 16, 16, 16, 16])
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[ 2.6768646e-03 -2.2224975e-03 -2.2731363e-03 -4.6701790e-03
#   -1.0111692e-02  1.7620879e-03  3.3739703e-03  1.3939134e-05
#   -7.4683409e-03 -2.6148066e-03  2.1639722e-03 -1.2682738e-03
#    2.7663275e-03  3.2521104e-03 -7.3485577e-04  1.2735294e-02
#    1.4922377e-03 -1.7934504e-03]], shape=(1, 18), dtype=float32)

# %%
x = np.random.normal(loc=0.5, scale=0.3, size=[1, 16, 16, 16, 16])
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[ 0.07593004 -0.02898131 -0.02001374  0.03746543  0.02245526  0.01882404
#   -0.09522279 -0.00917984  0.03248481  0.00913522 -0.01607769  0.0383249
#   -0.04246456 -0.00034787 -0.07218534 -0.00345779 -0.08408961  0.02285212]], shape=(1, 18), dtype=float32)

# %% [markdown]
# 위 실험의 결과를 토대로 확인할 수 있는 것은 regressor의 출력은 입력 correlation의 크기가 아닌 편차에 따라 달라진다는 것이다. correlation의 분포의 표준편차를 변화시키며 출력의 변화 정도를 추정해주었다.

# %%
_range = np.linspace(0, 1.0, 50)
print(_range)
# Out:
# [0.         0.02040816 0.04081633 0.06122449 0.08163265 0.10204082
#  0.12244898 0.14285714 0.16326531 0.18367347 0.20408163 0.2244898
#  0.24489796 0.26530612 0.28571429 0.30612245 0.32653061 0.34693878
#  0.36734694 0.3877551  0.40816327 0.42857143 0.44897959 0.46938776
#  0.48979592 0.51020408 0.53061224 0.55102041 0.57142857 0.59183673
#  0.6122449  0.63265306 0.65306122 0.67346939 0.69387755 0.71428571
#  0.73469388 0.75510204 0.7755102  0.79591837 0.81632653 0.83673469
#  0.85714286 0.87755102 0.89795918 0.91836735 0.93877551 0.95918367
#  0.97959184 1.        ]

# %%
variations_via_std = []
variations_via_mean = []
for std in _range:
    x = np.random.normal(loc=0.5, scale=std, size=[1, 16, 16, 16, 16])
    _y = model.layers[2](x)
    variation = np.square(np.sum(np.power((y - _y), 2)))
    variations_via_std.append(variation)
for mean in _range:
    x = np.random.normal(loc=mean, scale=0.1, size=[1, 16, 16, 16, 16])
    _y = model.layers[2](x)
    variation = np.square(np.sum(np.power((y - _y), 2)))
    variations_via_mean.append(variation)

# %%
plt.ylabel("variation of motion parameters")
plt.xlabel("std-dev or mean")
plt.plot(_range, variations_via_std, label='variation_via_std')
plt.plot(_range, variations_via_mean, label='variation_via_mean')
plt.legend()
plt.show()

# %% [markdown]
# 1. VGG16을 통한 correlations
# 2. 시각화 방식 개선
# 3. tentative penalty

# %% [markdown]
# ## b. 특징추출기의 정상 동작 검증

# %% [markdown]
# ### 동일 영상에 대한 correlation

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_A)

score = score.numpy()[0]
parameters = parameters[0]
image_A = image_A[0]
image_B = image_B[0]

print(score.shape, parameters.shape, image_A.shape)
# Out:
# (16, 16, 16, 16) (9, 2) (64, 64, 3)

# %%
def get_matching_grid_from_B(parameters, center_point):
    src_points = np.array([[0.0, 0.0], [0.5, 0.0], [1.0, 0.0],
                                   [0.0, 0.5], [0.5, 0.5], [1.0, 0.5],
                                   [0.0, 1.0], [0.5, 1.0], [1.0, 1.0]])

    dst_points = src_points +parameters

    theta = tps.tps_theta_from_points(src_points, dst_points, reduced=True)
    dshape = (64, 64)
    grid = tps.tps_grid(theta, dst_points, dshape)
    mapx, mapy = tps.tps_grid_to_remap(grid, (64, 64))
    points = np.concatenate([mapy[:,:,np.newaxis], mapx[:,:,np.newaxis]], axis=2)
    #print("points :", points)
    center_point = np.array(center_point)
    #print("grid center : ", center_point)
    center_point = center_point[np.newaxis, np.newaxis, :]
    distance = np.sum(np.power((points - center_point), 2), axis=2)
    #print("distance : ", distance)
    ri, ci = distance.argmin()//distance.shape[1], distance.argmin()%distance.shape[1]
    return (ri, ci)

# %%
def score_test(grid_coord, score, parameters, images, grid_shape=(16,16)):
    image_A, image_B = images
    score = score[grid_coord[0], grid_coord[1]]
    H, W, C = image_A.shape
    grid_size = H/grid_shape[0], W/grid_shape[1]

    start_pix_h = int(grid_size[0]*grid_coord[0])
    end_pix_h = int(grid_size[0]*(1+grid_coord[0]))
    start_pix_w = int(grid_size[1]*grid_coord[1])
    end_pix_w = int(grid_size[1]*(1+grid_coord[1]))
    
    drawn_grid_image_A = image_A.copy()
    drawn_grid_image_A[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)   
    
    expected_drawn_grid_image_B = image_B.copy()
    grid_center_A = (int(start_pix_h+grid_size[0]/2), int(start_pix_w+grid_size[1]/2))
    grid_center_B = get_matching_grid_from_B(parameters, grid_center_A)
    start_pix_h = int(grid_center_B[0] - grid_size[0]/2)
    start_pix_w = int(grid_center_B[1] - grid_size[1]/2)
    end_pix_h = int(grid_center_B[0] + grid_size[0]/2)
    end_pix_w = int(grid_center_B[1] + grid_size[1]/2)
    expected_drawn_grid_image_B[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)
    
    drawn_grid_image_B = image_B.copy()
    max_correlation_grid_index = score.argmax()//score.shape[1], score.argmax()%score.shape[1]
    start_pix_h = int(grid_size[0]*max_correlation_grid_index[0])
    end_pix_h = int(grid_size[0]*(1+max_correlation_grid_index[0]))
    start_pix_w = int(grid_size[1]*max_correlation_grid_index[1])
    end_pix_w = int(grid_size[1]*(1+max_correlation_grid_index[1]))

    drawn_grid_image_B[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)
    
    print("top 10 correlation values in descending : ", np.sort(score.flatten())[::-1][:10])
    
    return drawn_grid_image_A, expected_drawn_grid_image_B, drawn_grid_image_B

# %%
drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B = score_test(grid_coord=(5,10), 
                                                                            score=score, 
                                                                            parameters=np.zeros([9,2]), 
                                                                            images=(image_A, image_A))
# Out:
# top 10 correlation values in descending :  [0.07240419 0.07184959 0.07181428 0.07159597 0.07155896 0.0711441
#  0.07113773 0.07108656 0.07107585 0.07101363]

# %%
fig = plt.figure()

ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

ax1.imshow(drawn_image_A)
ax2.imshow(expected_drawn_grid_image_B)
ax3.imshow(drawn_grid_image_B)

plt.show()

# %%
drawn_image_A.shape
expected_drawn_grid_image_B.shape
drawn_grid_image_B.shape
# Out:
# (64, 64, 3)

# %% [markdown]
# ### b.1 ) 동일한 사진의 경우

# %%
for i in range(16):
    drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B = score_test(grid_coord=(i,i), 
                                                                                score=score, 
                                                                                parameters=np.zeros([9,2]), 
                                                                                images=(image_A, image_A))   
    fig = plt.figure()

    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)

    ax1.imshow(drawn_image_A)
    ax2.imshow(expected_drawn_grid_image_B)
    ax3.imshow(drawn_grid_image_B)

    plt.show()
# Out:
# top 10 correlation values in descending :  [0.0747098  0.06983026 0.0698179  0.06961145 0.06951884 0.06941254
#  0.06935969 0.06921736 0.06920499 0.0691859 ]
# top 10 correlation values in descending :  [0.06859732 0.0684334  0.06842981 0.06842771 0.06842524 0.06842392
#  0.06842369 0.0684185  0.06837586 0.06827578]
# top 10 correlation values in descending :  [0.0689264  0.06892554 0.06892544 0.06892518 0.06892515 0.06892513
#  0.06892496 0.06892489 0.06892487 0.06892478]
# top 10 correlation values in descending :  [0.06892286 0.06892192 0.06892184 0.06892174 0.06892124 0.06892112
#  0.06892101 0.06892096 0.06892094 0.06892075]
# top 10 correlation values in descending :  [0.06893444 0.06893331 0.06893319 0.06893314 0.06893305 0.06893302
#  0.06893296 0.06893289 0.06893282 0.06893275]
# top 10 correlation values in descending :  [0.06894398 0.0689434  0.06894315 0.0689427  0.0689427  0.06894261
#  0.06894257 0.06894252 0.06894248 0.06894225]
# top 10 correlation values in descending :  [0.06858185 0.06855878 0.06854922 0.06854063 0.06853747 0.06853413
#  0.06853364 0.06853161 0.06853047 0.06853037]
# top 10 correlation values in descending :  [0.07010069 0.06894711 0.06853707 0.06847886 0.06816306 0.06814617
#  0.06811655 0.06800066 0.06772111 0.06762103]
# top 10 correlation values in descending :  [0.06985711 0.06820045 0.06814878 0.06811095 0.06789268 0.06786913
#  0.06782369 0.06777425 0.06776386 0.06776074]
# top 10 correlation values in descending :  [0.07010992 0.06951467 0.0693212  0.06915079 0.06911734 0.06908947
#  0.06908349 0.06901135 0.06894691 0.06890939]
# top 10 correlation values in descending :  [0.07079648 0.06997489 0.06982892 0.06966456 0.06964803 0.06955956
#  0.06950114 0.06945457 0.06941735 0.06931108]
# top 10 correlation values in descending :  [0.06834174 0.06773073 0.06752449 0.06705853 0.066992   0.06697053
#  0.0669122  0.06690719 0.06689479 0.06687313]
# top 10 correlation values in descending :  [0.06822973 0.06790625 0.06787238 0.06786861 0.06783551 0.06782851
#  0.06782835 0.06781907 0.06781445 0.06781412]
# top 10 correlation values in descending :  [0.06826223 0.06809814 0.06804616 0.06804319 0.06803985 0.06803876
#  0.06803156 0.06802665 0.06801645 0.06800587]
# top 10 correlation values in descending :  [0.06815495 0.06797126 0.06796075 0.06795949 0.0679576  0.06795236
#  0.06795129 0.06794659 0.06793769 0.06793436]
# top 10 correlation values in descending :  [0.08980771 0.0765859  0.07655641 0.07625484 0.07602645 0.0759494
#  0.07571924 0.0754393  0.07480326 0.07437141]

# %% [markdown]
# ### b.2 ) 다른 사진의 경우

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_A)

score = score.numpy()[0]
parameters = parameters[0]
image_A = image_A[0]
image_B = image_B[0]

print(score.shape, parameters.shape, image_A.shape)
# Out:
# (16, 16, 16, 16) (9, 2) (64, 64, 3)

# %%
for i in range(16):
    drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B = score_test(grid_coord=(i,i), 
                                                                                score=score, 
                                                                                parameters=parameters, 
                                                                                images=(image_A, image_B))   
    fig = plt.figure()

    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)

    ax1.imshow(drawn_image_A)
    ax2.imshow(expected_drawn_grid_image_B)
    ax3.imshow(drawn_grid_image_B)

    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.07446965 0.07039398 0.07015154 0.06935411 0.06926589 0.06913771
#  0.06906357 0.06903198 0.06897779 0.06892854]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06915541 0.06900038 0.06899972 0.06899617 0.06899412 0.06899357
#  0.06889131 0.06887296 0.06884268 0.06880086]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06956401 0.06956264 0.0695625  0.06956227 0.06956212 0.06956185
#  0.06956179 0.06956176 0.06956159 0.06956148]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06964491 0.06964355 0.06964353 0.0696432  0.06964269 0.06964253
#  0.06964181 0.06964169 0.06964169 0.06964123]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0695712  0.06956916 0.06956906 0.06956892 0.06956868 0.06956865
#  0.06956865 0.06956847 0.06956835 0.06956784]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06929039 0.06925555 0.06925127 0.0692504  0.06924942 0.06924906
#  0.06924867 0.06924814 0.06924722 0.06924651]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06934401 0.06796235 0.06783894 0.06775299 0.06734207 0.067269
#  0.06707124 0.06705223 0.06702328 0.06696572]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.07039946 0.06904063 0.06886106 0.06871095 0.06869642 0.06862059
#  0.06855436 0.06852528 0.06849419 0.06835216]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.07049415 0.06969273 0.0696631  0.0694418  0.06935886 0.06903274
#  0.06896643 0.06894318 0.06891114 0.06889457]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.07024502 0.06972486 0.069381   0.06927969 0.06920353 0.0691821
#  0.06904648 0.06880537 0.06870115 0.06868559]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0688726  0.06788033 0.06779534 0.06754328 0.06747915 0.06743237
#  0.06709646 0.06700374 0.067003   0.06699195]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06838668 0.06735797 0.06701689 0.06683316 0.06670808 0.06666486
#  0.06663677 0.06662811 0.06641217 0.06639435]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06784724 0.06696454 0.066893   0.06682648 0.06669655 0.0663638
#  0.06623547 0.06610855 0.06609716 0.06608035]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06810527 0.06742741 0.06731287 0.06724896 0.0671477  0.06689674
#  0.06677081 0.06663715 0.06662524 0.066621  ]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.06835005 0.06766991 0.06746127 0.06682723 0.0667983  0.06677891
#  0.06663246 0.06637689 0.06636689 0.06634586]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.08968583 0.07881486 0.07646012 0.07554738 0.07550391 0.07531726
#  0.07528225 0.07464709 0.07427635 0.07427324]
