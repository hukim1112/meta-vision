# %%
import os, sys
root_path = os.path.abspath('.').split('jupyters')[0]
sys.path.append(root_path)

# %%
import json
import argparse
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

from data_loader import load_data
from models.cnn_geo import CNN_geo

from debug_tools import data, train, visualize
from utils import image
import geo_transform as tps
import CNNgeo_debug

# %% [markdown]
# # 1. Read configuration file

# %%
with open('../overfit.json') as fp:
    config = json.load(fp)
split = 'val'

# %%
print(config)
# Out:
# {'exp_desc': '200507_regressor_filter_size_up', 'dataset_name': 'mini_imagenet', 'data_dir': '/home/files/datasets/mini_imagenet', 'image_shape': [64, 64, 3], 'model_name': 'CNNgeo', 'backbone': 'prototypical_network', 'data': {'method': 'synthesized_pair', 'tps_random_rate': 0.2, 'pad_ratio': 0.2}, 'ckpt': {'save_type': 'latest', 'max_to_keep': 10}, 'train': {'n_examples': 1, 'learning_rate': 0.0001, 'batch_size': 1, 'epochs': 200, 'print_step': 10}, 'val': {'n_examples': 1, 'batch_size': 1}, 'test': {'n_examples': -1, 'batch_size': 128}}

# %%
print(config['train'])
# Out:
# {'n_examples': 1, 'learning_rate': 0.0001, 'batch_size': 1, 'epochs': 200, 'print_step': 10}

# %%
print("backbone : ", config['backbone'])
print("n_examples : ", config['train']['n_examples'])
print("learning_rate : ", config['train']['learning_rate'])
print("batch_size : ", config['train']['batch_size'])
print("epoch num : ", config['train']['epochs'])
# Out:
# backbone :  prototypical_network
# n_examples :  1
# learning_rate :  0.0001
# batch_size :  1
# epoch num :  200

# %% [markdown]
# # 2. Train model on the config parameters

# %%
model = CNNgeo_debug.train(config)
# Out:
# train dataset amount : 1
# val dataset amount : 1
# start of epoch 1
# Training loss (for one batch) at step 0: 0.4769645035266876
# Epoch 1, Loss: 0.4769645035266876, Val Loss: 0.5614500641822815
# end of epoch.
# start of epoch 2
# Training loss (for one batch) at step 0: 0.6016846299171448
# Epoch 2, Loss: 0.6016846299171448, Val Loss: 0.572044849395752
# end of epoch.
# start of epoch 3
# Training loss (for one batch) at step 0: 0.6449494361877441
# Epoch 3, Loss: 0.6449494361877441, Val Loss: 0.6445736885070801
# end of epoch.
# start of epoch 4
# Training loss (for one batch) at step 0: 0.5707190036773682
# Epoch 4, Loss: 0.5707190036773682, Val Loss: 0.5922034978866577
# end of epoch.
# start of epoch 5
# Training loss (for one batch) at step 0: 0.4884611964225769
# Epoch 5, Loss: 0.4884611964225769, Val Loss: 0.6153637170791626
# end of epoch.
# start of epoch 6
# Training loss (for one batch) at step 0: 0.52915358543396
# Epoch 6, Loss: 0.52915358543396, Val Loss: 0.6033773422241211
# end of epoch.
# start of epoch 7
# Training loss (for one batch) at step 0: 0.4065549969673157
# Epoch 7, Loss: 0.4065549969673157, Val Loss: 0.5716155767440796
# end of epoch.
# start of epoch 8
# Training loss (for one batch) at step 0: 0.546191394329071
# Epoch 8, Loss: 0.546191394329071, Val Loss: 0.5141870379447937
# end of epoch.
# start of epoch 9
# Training loss (for one batch) at step 0: 0.5025476217269897
# Epoch 9, Loss: 0.5025476217269897, Val Loss: 0.5268982648849487
# end of epoch.
# start of epoch 10
# Training loss (for one batch) at step 0: 0.5520973801612854
# Epoch 10, Loss: 0.5520973801612854, Val Loss: 0.6295629739761353
# end of epoch.
# start of epoch 11
# Training loss (for one batch) at step 0: 0.5212616920471191
# Epoch 11, Loss: 0.5212616920471191, Val Loss: 0.4258195459842682
# end of epoch.
# start of epoch 12
# Training loss (for one batch) at step 0: 0.4081652760505676
# Epoch 12, Loss: 0.4081652760505676, Val Loss: 0.507757842540741
# end of epoch.
# start of epoch 13
# Training loss (for one batch) at step 0: 0.5383145213127136
# Epoch 13, Loss: 0.5383145213127136, Val Loss: 0.5550889372825623
# end of epoch.
# start of epoch 14
# Training loss (for one batch) at step 0: 0.5879290699958801
# Epoch 14, Loss: 0.5879290699958801, Val Loss: 0.5582249164581299
# end of epoch.
# start of epoch 15
# Training loss (for one batch) at step 0: 0.5873311758041382
# Epoch 15, Loss: 0.5873311758041382, Val Loss: 0.5333138108253479
# end of epoch.
# start of epoch 16
# Training loss (for one batch) at step 0: 0.441144198179245
# Epoch 16, Loss: 0.441144198179245, Val Loss: 0.5751022696495056
# end of epoch.
# start of epoch 17
# Training loss (for one batch) at step 0: 0.5451817512512207
# Epoch 17, Loss: 0.5451817512512207, Val Loss: 0.4665859043598175
# end of epoch.
# start of epoch 18
# Training loss (for one batch) at step 0: 0.4374566078186035
# Epoch 18, Loss: 0.4374566078186035, Val Loss: 0.4939751625061035
# end of epoch.
# start of epoch 19
# Training loss (for one batch) at step 0: 0.5472937226295471
# Epoch 19, Loss: 0.5472937226295471, Val Loss: 0.44390401244163513
# end of epoch.
# start of epoch 20
# Training loss (for one batch) at step 0: 0.5295515656471252
# Epoch 20, Loss: 0.5295515656471252, Val Loss: 0.557538628578186
# end of epoch.
# start of epoch 21
# Training loss (for one batch) at step 0: 0.4906753599643707
# Epoch 21, Loss: 0.4906753599643707, Val Loss: 0.450699120759964
# end of epoch.
# start of epoch 22
# Training loss (for one batch) at step 0: 0.4535748362541199
# Epoch 22, Loss: 0.4535748362541199, Val Loss: 0.5023050904273987
# end of epoch.
# start of epoch 23
# Training loss (for one batch) at step 0: 0.560968279838562
# Epoch 23, Loss: 0.560968279838562, Val Loss: 0.49050089716911316
# end of epoch.
# start of epoch 24
# Training loss (for one batch) at step 0: 0.5423553586006165
# Epoch 24, Loss: 0.5423553586006165, Val Loss: 0.49793723225593567
# end of epoch.
# start of epoch 25
# Training loss (for one batch) at step 0: 0.44070425629615784
# Epoch 25, Loss: 0.44070425629615784, Val Loss: 0.4577329456806183
# end of epoch.
# start of epoch 26
# Training loss (for one batch) at step 0: 0.49512314796447754
# Epoch 26, Loss: 0.49512314796447754, Val Loss: 0.4707590639591217
# end of epoch.
# start of epoch 27
# Training loss (for one batch) at step 0: 0.4881896376609802
# Epoch 27, Loss: 0.4881896376609802, Val Loss: 0.460293710231781
# end of epoch.
# start of epoch 28
# Training loss (for one batch) at step 0: 0.49385809898376465
# Epoch 28, Loss: 0.49385809898376465, Val Loss: 0.46002817153930664
# end of epoch.
# start of epoch 29
# Training loss (for one batch) at step 0: 0.3826446235179901
# Epoch 29, Loss: 0.3826446235179901, Val Loss: 0.43696466088294983
# end of epoch.
# start of epoch 30
# Training loss (for one batch) at step 0: 0.48529288172721863
# Epoch 30, Loss: 0.48529288172721863, Val Loss: 0.5289134383201599
# end of epoch.
# start of epoch 31
# Training loss (for one batch) at step 0: 0.4169333875179291
# Epoch 31, Loss: 0.4169333875179291, Val Loss: 0.5529080629348755
# end of epoch.
# start of epoch 32
# Training loss (for one batch) at step 0: 0.4803657531738281
# Epoch 32, Loss: 0.4803657531738281, Val Loss: 0.5283344984054565
# end of epoch.
# start of epoch 33
# Training loss (for one batch) at step 0: 0.44143110513687134
# Epoch 33, Loss: 0.44143110513687134, Val Loss: 0.411172091960907
# end of epoch.
# start of epoch 34
# Training loss (for one batch) at step 0: 0.5219213962554932
# Epoch 34, Loss: 0.5219213962554932, Val Loss: 0.4098697006702423
# end of epoch.
# start of epoch 35
# Training loss (for one batch) at step 0: 0.48999011516571045
# Epoch 35, Loss: 0.48999011516571045, Val Loss: 0.45687079429626465
# end of epoch.
# start of epoch 36
# Training loss (for one batch) at step 0: 0.49664512276649475
# Epoch 36, Loss: 0.49664512276649475, Val Loss: 0.5312374234199524
# end of epoch.
# start of epoch 37
# Training loss (for one batch) at step 0: 0.47849196195602417
# Epoch 37, Loss: 0.47849196195602417, Val Loss: 0.47747179865837097
# end of epoch.
# start of epoch 38
# Training loss (for one batch) at step 0: 0.5841050744056702
# Epoch 38, Loss: 0.5841050744056702, Val Loss: 0.3344590365886688
# end of epoch.
# start of epoch 39
# Training loss (for one batch) at step 0: 0.49987369775772095
# Epoch 39, Loss: 0.49987369775772095, Val Loss: 0.4784308671951294
# end of epoch.
# start of epoch 40
# Training loss (for one batch) at step 0: 0.46947112679481506
# Epoch 40, Loss: 0.46947112679481506, Val Loss: 0.46248334646224976
# end of epoch.
# start of epoch 41
# Training loss (for one batch) at step 0: 0.5261147618293762
# Epoch 41, Loss: 0.5261147618293762, Val Loss: 0.6029466986656189
# end of epoch.
# start of epoch 42
# Training loss (for one batch) at step 0: 0.5539258122444153
# Epoch 42, Loss: 0.5539258122444153, Val Loss: 0.47088125348091125
# end of epoch.
# start of epoch 43
# Training loss (for one batch) at step 0: 0.5660234689712524
# Epoch 43, Loss: 0.5660234689712524, Val Loss: 0.5226455330848694
# end of epoch.
# start of epoch 44
# Training loss (for one batch) at step 0: 0.5316691994667053
# Epoch 44, Loss: 0.5316691994667053, Val Loss: 0.4621054232120514
# end of epoch.
# start of epoch 45
# Training loss (for one batch) at step 0: 0.49700748920440674
# Epoch 45, Loss: 0.49700748920440674, Val Loss: 0.48964211344718933
# end of epoch.
# start of epoch 46
# Training loss (for one batch) at step 0: 0.43354931473731995
# Epoch 46, Loss: 0.43354931473731995, Val Loss: 0.4917454421520233
# end of epoch.
# start of epoch 47
# Training loss (for one batch) at step 0: 0.40063872933387756
# Epoch 47, Loss: 0.40063872933387756, Val Loss: 0.4818725883960724
# end of epoch.
# start of epoch 48
# Training loss (for one batch) at step 0: 0.5099498629570007
# Epoch 48, Loss: 0.5099498629570007, Val Loss: 0.4938596785068512
# end of epoch.
# start of epoch 49
# Training loss (for one batch) at step 0: 0.5277716517448425
# Epoch 49, Loss: 0.5277716517448425, Val Loss: 0.49250707030296326
# end of epoch.
# start of epoch 50
# Training loss (for one batch) at step 0: 0.4960983991622925
# Epoch 50, Loss: 0.4960983991622925, Val Loss: 0.5676299333572388
# end of epoch.
# start of epoch 51
# Training loss (for one batch) at step 0: 0.5087409019470215
# Epoch 51, Loss: 0.5087409019470215, Val Loss: 0.5287980437278748
# end of epoch.
# start of epoch 52
# Training loss (for one batch) at step 0: 0.5116506218910217
# Epoch 52, Loss: 0.5116506218910217, Val Loss: 0.4776915907859802
# end of epoch.
# start of epoch 53
# Training loss (for one batch) at step 0: 0.5146713852882385
# Epoch 53, Loss: 0.5146713852882385, Val Loss: 0.46455416083335876
# end of epoch.
# start of epoch 54
# Training loss (for one batch) at step 0: 0.3920183777809143
# Epoch 54, Loss: 0.3920183777809143, Val Loss: 0.4801587164402008
# end of epoch.
# start of epoch 55
# Training loss (for one batch) at step 0: 0.5420045852661133
# Epoch 55, Loss: 0.5420045852661133, Val Loss: 0.4066928029060364
# end of epoch.
# start of epoch 56
# Training loss (for one batch) at step 0: 0.46619850397109985
# Epoch 56, Loss: 0.46619850397109985, Val Loss: 0.46259891986846924
# end of epoch.
# start of epoch 57
# Training loss (for one batch) at step 0: 0.6038587093353271
# Epoch 57, Loss: 0.6038587093353271, Val Loss: 0.4660927355289459
# end of epoch.
# start of epoch 58
# Training loss (for one batch) at step 0: 0.40508776903152466
# Epoch 58, Loss: 0.40508776903152466, Val Loss: 0.527143120765686
# end of epoch.
# start of epoch 59
# Training loss (for one batch) at step 0: 0.4837087094783783
# Epoch 59, Loss: 0.4837087094783783, Val Loss: 0.4618312418460846
# end of epoch.
# start of epoch 60
# Training loss (for one batch) at step 0: 0.48713037371635437
# Epoch 60, Loss: 0.48713037371635437, Val Loss: 0.47734689712524414
# end of epoch.
# start of epoch 61
# Training loss (for one batch) at step 0: 0.45913389325141907
# Epoch 61, Loss: 0.45913389325141907, Val Loss: 0.563755989074707
# end of epoch.
# start of epoch 62
# Training loss (for one batch) at step 0: 0.497251033782959
# Epoch 62, Loss: 0.497251033782959, Val Loss: 0.5128109455108643
# end of epoch.
# start of epoch 63
# Training loss (for one batch) at step 0: 0.5128761529922485
# Epoch 63, Loss: 0.5128761529922485, Val Loss: 0.4605740010738373
# end of epoch.
# start of epoch 64
# Training loss (for one batch) at step 0: 0.5413201451301575
# Epoch 64, Loss: 0.5413201451301575, Val Loss: 0.5010260939598083
# end of epoch.
# start of epoch 65
# Training loss (for one batch) at step 0: 0.4518139064311981
# Epoch 65, Loss: 0.4518139064311981, Val Loss: 0.4681703448295593
# end of epoch.
# start of epoch 66
# Training loss (for one batch) at step 0: 0.4807344079017639
# Epoch 66, Loss: 0.4807344079017639, Val Loss: 0.46720898151397705
# end of epoch.
# start of epoch 67
# Training loss (for one batch) at step 0: 0.5666211843490601
# Epoch 67, Loss: 0.5666211843490601, Val Loss: 0.5669373869895935
# end of epoch.
# start of epoch 68
# Training loss (for one batch) at step 0: 0.44432753324508667
# Epoch 68, Loss: 0.44432753324508667, Val Loss: 0.5594619512557983
# end of epoch.
# start of epoch 69
# Training loss (for one batch) at step 0: 0.611711859703064
# Epoch 69, Loss: 0.611711859703064, Val Loss: 0.5575234889984131
# end of epoch.
# start of epoch 70
# Training loss (for one batch) at step 0: 0.44371676445007324
# Epoch 70, Loss: 0.44371676445007324, Val Loss: 0.42729344964027405
# end of epoch.
# start of epoch 71
# Training loss (for one batch) at step 0: 0.4283194839954376
# Epoch 71, Loss: 0.4283194839954376, Val Loss: 0.5169020891189575
# end of epoch.
# start of epoch 72
# Training loss (for one batch) at step 0: 0.4381386935710907
# Epoch 72, Loss: 0.4381386935710907, Val Loss: 0.4737420380115509
# end of epoch.
# start of epoch 73
# Training loss (for one batch) at step 0: 0.36087679862976074
# Epoch 73, Loss: 0.36087679862976074, Val Loss: 0.49317315220832825
# end of epoch.
# start of epoch 74
# Training loss (for one batch) at step 0: 0.45113804936408997
# Epoch 74, Loss: 0.45113804936408997, Val Loss: 0.4524344801902771
# end of epoch.
# start of epoch 75
# Training loss (for one batch) at step 0: 0.5203180313110352
# Epoch 75, Loss: 0.5203180313110352, Val Loss: 0.5403796434402466
# end of epoch.
# start of epoch 76
# Training loss (for one batch) at step 0: 0.5595749616622925
# Epoch 76, Loss: 0.5595749616622925, Val Loss: 0.38644665479660034
# end of epoch.
# start of epoch 77
# Training loss (for one batch) at step 0: 0.5497481822967529
# Epoch 77, Loss: 0.5497481822967529, Val Loss: 0.4906853139400482
# end of epoch.
# start of epoch 78
# Training loss (for one batch) at step 0: 0.4594267010688782
# Epoch 78, Loss: 0.4594267010688782, Val Loss: 0.5291683673858643
# end of epoch.
# start of epoch 79
# Training loss (for one batch) at step 0: 0.4760247766971588
# Epoch 79, Loss: 0.4760247766971588, Val Loss: 0.42351460456848145
# end of epoch.
# start of epoch 80
# Training loss (for one batch) at step 0: 0.4999379813671112
# Epoch 80, Loss: 0.4999379813671112, Val Loss: 0.5149278044700623
# end of epoch.
# start of epoch 81
# Training loss (for one batch) at step 0: 0.4670644998550415
# Epoch 81, Loss: 0.4670644998550415, Val Loss: 0.4823036789894104
# end of epoch.
# start of epoch 82
# Training loss (for one batch) at step 0: 0.5301690697669983
# Epoch 82, Loss: 0.5301690697669983, Val Loss: 0.5123497843742371
# end of epoch.
# start of epoch 83
# Training loss (for one batch) at step 0: 0.4760034382343292
# Epoch 83, Loss: 0.4760034382343292, Val Loss: 0.4876890480518341
# end of epoch.
# start of epoch 84
# Training loss (for one batch) at step 0: 0.5149257183074951
# Epoch 84, Loss: 0.5149257183074951, Val Loss: 0.5502554178237915
# end of epoch.
# start of epoch 85
# Training loss (for one batch) at step 0: 0.43482932448387146
# Epoch 85, Loss: 0.43482932448387146, Val Loss: 0.49093130230903625
# end of epoch.
# start of epoch 86
# Training loss (for one batch) at step 0: 0.5164636373519897
# Epoch 86, Loss: 0.5164636373519897, Val Loss: 0.39067941904067993
# end of epoch.
# start of epoch 87
# Training loss (for one batch) at step 0: 0.4691510796546936
# Epoch 87, Loss: 0.4691510796546936, Val Loss: 0.3706769049167633
# end of epoch.
# start of epoch 88
# Training loss (for one batch) at step 0: 0.540803074836731
# Epoch 88, Loss: 0.540803074836731, Val Loss: 0.5172218680381775
# end of epoch.
# start of epoch 89
# Training loss (for one batch) at step 0: 0.5692958831787109
# Epoch 89, Loss: 0.5692958831787109, Val Loss: 0.4751114547252655
# end of epoch.
# start of epoch 90
# Training loss (for one batch) at step 0: 0.5106954574584961
# Epoch 90, Loss: 0.5106954574584961, Val Loss: 0.4238629639148712
# end of epoch.
# start of epoch 91
# Training loss (for one batch) at step 0: 0.5134104490280151
# Epoch 91, Loss: 0.5134104490280151, Val Loss: 0.4359106123447418
# end of epoch.
# start of epoch 92
# Training loss (for one batch) at step 0: 0.4923410415649414
# Epoch 92, Loss: 0.4923410415649414, Val Loss: 0.5335588455200195
# end of epoch.
# start of epoch 93
# Training loss (for one batch) at step 0: 0.42374691367149353
# Epoch 93, Loss: 0.42374691367149353, Val Loss: 0.540556788444519
# end of epoch.
# start of epoch 94
# Training loss (for one batch) at step 0: 0.45255130529403687
# Epoch 94, Loss: 0.45255130529403687, Val Loss: 0.5608229637145996
# end of epoch.
# start of epoch 95
# Training loss (for one batch) at step 0: 0.43406274914741516
# Epoch 95, Loss: 0.43406274914741516, Val Loss: 0.5208854079246521
# end of epoch.
# start of epoch 96
# Training loss (for one batch) at step 0: 0.47645673155784607
# Epoch 96, Loss: 0.47645673155784607, Val Loss: 0.4122998118400574
# end of epoch.
# start of epoch 97
# Training loss (for one batch) at step 0: 0.4839404821395874
# Epoch 97, Loss: 0.4839404821395874, Val Loss: 0.47213080525398254
# end of epoch.
# start of epoch 98
# Training loss (for one batch) at step 0: 0.4089219272136688
# Epoch 98, Loss: 0.4089219272136688, Val Loss: 0.3945801854133606
# end of epoch.
# start of epoch 99
# Training loss (for one batch) at step 0: 0.5161876082420349
# Epoch 99, Loss: 0.5161876082420349, Val Loss: 0.3913208246231079
# end of epoch.
# start of epoch 100
# Training loss (for one batch) at step 0: 0.5011491179466248
# Epoch 100, Loss: 0.5011491179466248, Val Loss: 0.5042269229888916
# end of epoch.
# start of epoch 101
# Training loss (for one batch) at step 0: 0.5097772479057312
# Epoch 101, Loss: 0.5097772479057312, Val Loss: 0.5139151215553284
# end of epoch.
# start of epoch 102
# Training loss (for one batch) at step 0: 0.4535343647003174
# Epoch 102, Loss: 0.4535343647003174, Val Loss: 0.5468516945838928
# end of epoch.
# start of epoch 103
# Training loss (for one batch) at step 0: 0.5329666137695312
# Epoch 103, Loss: 0.5329666137695312, Val Loss: 0.5095701217651367
# end of epoch.
# start of epoch 104
# Training loss (for one batch) at step 0: 0.5021851658821106
# Epoch 104, Loss: 0.5021851658821106, Val Loss: 0.5384048819541931
# end of epoch.
# start of epoch 105
# Training loss (for one batch) at step 0: 0.5252313017845154
# Epoch 105, Loss: 0.5252313017845154, Val Loss: 0.44411221146583557
# end of epoch.
# start of epoch 106
# Training loss (for one batch) at step 0: 0.4807361662387848
# Epoch 106, Loss: 0.4807361662387848, Val Loss: 0.5073044300079346
# end of epoch.
# start of epoch 107
# Training loss (for one batch) at step 0: 0.3981477916240692
# Epoch 107, Loss: 0.3981477916240692, Val Loss: 0.49227890372276306
# end of epoch.
# start of epoch 108
# Training loss (for one batch) at step 0: 0.4854489862918854
# Epoch 108, Loss: 0.4854489862918854, Val Loss: 0.5633143186569214
# end of epoch.
# start of epoch 109
# Training loss (for one batch) at step 0: 0.5106056928634644
# Epoch 109, Loss: 0.5106056928634644, Val Loss: 0.5378824472427368
# end of epoch.
# start of epoch 110
# Training loss (for one batch) at step 0: 0.4372052550315857
# Epoch 110, Loss: 0.4372052550315857, Val Loss: 0.4682018756866455
# end of epoch.
# start of epoch 111
# Training loss (for one batch) at step 0: 0.5318353772163391
# Epoch 111, Loss: 0.5318353772163391, Val Loss: 0.6086511015892029
# end of epoch.
# start of epoch 112
# Training loss (for one batch) at step 0: 0.46061569452285767
# Epoch 112, Loss: 0.46061569452285767, Val Loss: 0.5551132559776306
# end of epoch.
# start of epoch 113
# Training loss (for one batch) at step 0: 0.45936957001686096
# Epoch 113, Loss: 0.45936957001686096, Val Loss: 0.46759480237960815
# end of epoch.
# start of epoch 114
# Training loss (for one batch) at step 0: 0.49991464614868164
# Epoch 114, Loss: 0.49991464614868164, Val Loss: 0.45112019777297974
# end of epoch.
# start of epoch 115
# Training loss (for one batch) at step 0: 0.5245448350906372
# Epoch 115, Loss: 0.5245448350906372, Val Loss: 0.45091739296913147
# end of epoch.
# start of epoch 116
# Training loss (for one batch) at step 0: 0.5439900755882263
# Epoch 116, Loss: 0.5439900755882263, Val Loss: 0.446855753660202
# end of epoch.
# start of epoch 117
# Training loss (for one batch) at step 0: 0.49121323227882385
# Epoch 117, Loss: 0.49121323227882385, Val Loss: 0.45012927055358887
# end of epoch.
# start of epoch 118
# Training loss (for one batch) at step 0: 0.48901984095573425
# Epoch 118, Loss: 0.48901984095573425, Val Loss: 0.5007525086402893
# end of epoch.
# start of epoch 119
# Training loss (for one batch) at step 0: 0.4226914942264557
# Epoch 119, Loss: 0.4226914942264557, Val Loss: 0.41205528378486633
# end of epoch.
# start of epoch 120
# Training loss (for one batch) at step 0: 0.5911763310432434
# Epoch 120, Loss: 0.5911763310432434, Val Loss: 0.5541760921478271
# end of epoch.
# start of epoch 121
# Training loss (for one batch) at step 0: 0.43915891647338867
# Epoch 121, Loss: 0.43915891647338867, Val Loss: 0.45232537388801575
# end of epoch.
# start of epoch 122
# Training loss (for one batch) at step 0: 0.4007204473018646
# Epoch 122, Loss: 0.4007204473018646, Val Loss: 0.4892006516456604
# end of epoch.
# start of epoch 123
# Training loss (for one batch) at step 0: 0.5178115367889404
# Epoch 123, Loss: 0.5178115367889404, Val Loss: 0.5388297438621521
# end of epoch.
# start of epoch 124
# Training loss (for one batch) at step 0: 0.4027787446975708
# Epoch 124, Loss: 0.4027787446975708, Val Loss: 0.49050870537757874
# end of epoch.
# start of epoch 125
# Training loss (for one batch) at step 0: 0.488705575466156
# Epoch 125, Loss: 0.488705575466156, Val Loss: 0.5358487367630005
# end of epoch.
# start of epoch 126
# Training loss (for one batch) at step 0: 0.5727229714393616
# Epoch 126, Loss: 0.5727229714393616, Val Loss: 0.5171772241592407
# end of epoch.
# start of epoch 127
# Training loss (for one batch) at step 0: 0.46289247274398804
# Epoch 127, Loss: 0.46289247274398804, Val Loss: 0.5309938788414001
# end of epoch.
# start of epoch 128
# Training loss (for one batch) at step 0: 0.5329610705375671
# Epoch 128, Loss: 0.5329610705375671, Val Loss: 0.478251576423645
# end of epoch.
# start of epoch 129
# Training loss (for one batch) at step 0: 0.45901283621788025
# Epoch 129, Loss: 0.45901283621788025, Val Loss: 0.5067229866981506
# end of epoch.
# start of epoch 130
# Training loss (for one batch) at step 0: 0.512304425239563
# Epoch 130, Loss: 0.512304425239563, Val Loss: 0.4824734032154083
# end of epoch.
# start of epoch 131
# Training loss (for one batch) at step 0: 0.4704689681529999
# Epoch 131, Loss: 0.4704689681529999, Val Loss: 0.4299100935459137
# end of epoch.
# start of epoch 132
# Training loss (for one batch) at step 0: 0.46836161613464355
# Epoch 132, Loss: 0.46836161613464355, Val Loss: 0.38347944617271423
# end of epoch.
# start of epoch 133
# Training loss (for one batch) at step 0: 0.4874621331691742
# Epoch 133, Loss: 0.4874621331691742, Val Loss: 0.5106533765792847
# end of epoch.
# start of epoch 134
# Training loss (for one batch) at step 0: 0.3934703767299652
# Epoch 134, Loss: 0.3934703767299652, Val Loss: 0.5317761898040771
# end of epoch.
# start of epoch 135
# Training loss (for one batch) at step 0: 0.38384154438972473
# Epoch 135, Loss: 0.38384154438972473, Val Loss: 0.5139075517654419
# end of epoch.
# start of epoch 136
# Training loss (for one batch) at step 0: 0.41619816422462463
# Epoch 136, Loss: 0.41619816422462463, Val Loss: 0.4717979431152344
# end of epoch.
# start of epoch 137
# Training loss (for one batch) at step 0: 0.482726126909256
# Epoch 137, Loss: 0.482726126909256, Val Loss: 0.43539345264434814
# end of epoch.
# start of epoch 138
# Training loss (for one batch) at step 0: 0.471164733171463
# Epoch 138, Loss: 0.471164733171463, Val Loss: 0.5133724808692932
# end of epoch.
# start of epoch 139
# Training loss (for one batch) at step 0: 0.5339082479476929
# Epoch 139, Loss: 0.5339082479476929, Val Loss: 0.34489575028419495
# end of epoch.
# start of epoch 140
# Training loss (for one batch) at step 0: 0.5349751114845276
# Epoch 140, Loss: 0.5349751114845276, Val Loss: 0.4408659338951111
# end of epoch.
# start of epoch 141
# Training loss (for one batch) at step 0: 0.44253337383270264
# Epoch 141, Loss: 0.44253337383270264, Val Loss: 0.5033141374588013
# end of epoch.
# start of epoch 142
# Training loss (for one batch) at step 0: 0.4849408268928528
# Epoch 142, Loss: 0.4849408268928528, Val Loss: 0.4924718737602234
# end of epoch.
# start of epoch 143
# Training loss (for one batch) at step 0: 0.48858752846717834
# Epoch 143, Loss: 0.48858752846717834, Val Loss: 0.5475286841392517
# end of epoch.
# start of epoch 144
# Training loss (for one batch) at step 0: 0.4280082583427429
# Epoch 144, Loss: 0.4280082583427429, Val Loss: 0.47628551721572876
# end of epoch.
# start of epoch 145
# Training loss (for one batch) at step 0: 0.5000052452087402
# Epoch 145, Loss: 0.5000052452087402, Val Loss: 0.4117964208126068
# end of epoch.
# start of epoch 146
# Training loss (for one batch) at step 0: 0.5319529175758362
# Epoch 146, Loss: 0.5319529175758362, Val Loss: 0.48171335458755493
# end of epoch.
# start of epoch 147
# Training loss (for one batch) at step 0: 0.5096194744110107
# Epoch 147, Loss: 0.5096194744110107, Val Loss: 0.527681291103363
# end of epoch.
# start of epoch 148
# Training loss (for one batch) at step 0: 0.4608054459095001
# Epoch 148, Loss: 0.4608054459095001, Val Loss: 0.4238186180591583
# end of epoch.
# start of epoch 149
# Training loss (for one batch) at step 0: 0.484857976436615
# Epoch 149, Loss: 0.484857976436615, Val Loss: 0.5127926468849182
# end of epoch.
# start of epoch 150
# Training loss (for one batch) at step 0: 0.4608716368675232
# Epoch 150, Loss: 0.4608716368675232, Val Loss: 0.5505252480506897
# end of epoch.
# start of epoch 151
# Training loss (for one batch) at step 0: 0.50189208984375
# Epoch 151, Loss: 0.50189208984375, Val Loss: 0.4634908139705658
# end of epoch.
# start of epoch 152
# Training loss (for one batch) at step 0: 0.5389617681503296
# Epoch 152, Loss: 0.5389617681503296, Val Loss: 0.5198059678077698
# end of epoch.
# start of epoch 153
# Training loss (for one batch) at step 0: 0.4933423399925232
# Epoch 153, Loss: 0.4933423399925232, Val Loss: 0.5368367433547974
# end of epoch.
# start of epoch 154
# Training loss (for one batch) at step 0: 0.5760488510131836
# Epoch 154, Loss: 0.5760488510131836, Val Loss: 0.5565564036369324
# end of epoch.
# start of epoch 155
# Training loss (for one batch) at step 0: 0.4810642898082733
# Epoch 155, Loss: 0.4810642898082733, Val Loss: 0.5116286277770996
# end of epoch.
# start of epoch 156
# Training loss (for one batch) at step 0: 0.5310393571853638
# Epoch 156, Loss: 0.5310393571853638, Val Loss: 0.4392877221107483
# end of epoch.
# start of epoch 157
# Training loss (for one batch) at step 0: 0.4356589913368225
# Epoch 157, Loss: 0.4356589913368225, Val Loss: 0.47171419858932495
# end of epoch.
# start of epoch 158
# Training loss (for one batch) at step 0: 0.5147786140441895
# Epoch 158, Loss: 0.5147786140441895, Val Loss: 0.5050920844078064
# end of epoch.
# start of epoch 159
# Training loss (for one batch) at step 0: 0.5289942026138306
# Epoch 159, Loss: 0.5289942026138306, Val Loss: 0.538860023021698
# end of epoch.
# start of epoch 160
# Training loss (for one batch) at step 0: 0.451052188873291
# Epoch 160, Loss: 0.451052188873291, Val Loss: 0.5251871943473816
# end of epoch.
# start of epoch 161
# Training loss (for one batch) at step 0: 0.5163478255271912
# Epoch 161, Loss: 0.5163478255271912, Val Loss: 0.4991986155509949
# end of epoch.
# start of epoch 162
# Training loss (for one batch) at step 0: 0.5124706029891968
# Epoch 162, Loss: 0.5124706029891968, Val Loss: 0.4338535666465759
# end of epoch.
# start of epoch 163
# Training loss (for one batch) at step 0: 0.40053173899650574
# Epoch 163, Loss: 0.40053173899650574, Val Loss: 0.5323023796081543
# end of epoch.
# start of epoch 164
# Training loss (for one batch) at step 0: 0.4380868971347809
# Epoch 164, Loss: 0.4380868971347809, Val Loss: 0.5056565403938293
# end of epoch.
# start of epoch 165
# Training loss (for one batch) at step 0: 0.43947461247444153
# Epoch 165, Loss: 0.43947461247444153, Val Loss: 0.5219836831092834
# end of epoch.
# start of epoch 166
# Training loss (for one batch) at step 0: 0.4115769565105438
# Epoch 166, Loss: 0.4115769565105438, Val Loss: 0.5048850178718567
# end of epoch.
# start of epoch 167
# Training loss (for one batch) at step 0: 0.4372656047344208
# Epoch 167, Loss: 0.4372656047344208, Val Loss: 0.44943907856941223
# end of epoch.
# start of epoch 168
# Training loss (for one batch) at step 0: 0.4034441113471985
# Epoch 168, Loss: 0.4034441113471985, Val Loss: 0.4752097427845001
# end of epoch.
# start of epoch 169
# Training loss (for one batch) at step 0: 0.4113324284553528
# Epoch 169, Loss: 0.4113324284553528, Val Loss: 0.4327903985977173
# end of epoch.
# start of epoch 170
# Training loss (for one batch) at step 0: 0.46579673886299133
# Epoch 170, Loss: 0.46579673886299133, Val Loss: 0.508307933807373
# end of epoch.
# start of epoch 171
# Training loss (for one batch) at step 0: 0.4728218913078308
# Epoch 171, Loss: 0.4728218913078308, Val Loss: 0.5055421590805054
# end of epoch.
# start of epoch 172
# Training loss (for one batch) at step 0: 0.4935483932495117
# Epoch 172, Loss: 0.4935483932495117, Val Loss: 0.5041883587837219
# end of epoch.
# start of epoch 173
# Training loss (for one batch) at step 0: 0.431230366230011
# Epoch 173, Loss: 0.431230366230011, Val Loss: 0.47536152601242065
# end of epoch.
# start of epoch 174
# Training loss (for one batch) at step 0: 0.4983348250389099
# Epoch 174, Loss: 0.4983348250389099, Val Loss: 0.3902716040611267
# end of epoch.
# start of epoch 175
# Training loss (for one batch) at step 0: 0.5215039849281311
# Epoch 175, Loss: 0.5215039849281311, Val Loss: 0.5398398637771606
# end of epoch.
# start of epoch 176
# Training loss (for one batch) at step 0: 0.38743215799331665
# Epoch 176, Loss: 0.38743215799331665, Val Loss: 0.5345751047134399
# end of epoch.
# start of epoch 177
# Training loss (for one batch) at step 0: 0.5194539427757263
# Epoch 177, Loss: 0.5194539427757263, Val Loss: 0.5259842276573181
# end of epoch.
# start of epoch 178
# Training loss (for one batch) at step 0: 0.5240753889083862
# Epoch 178, Loss: 0.5240753889083862, Val Loss: 0.45147207379341125
# end of epoch.
# start of epoch 179
# Training loss (for one batch) at step 0: 0.48930585384368896
# Epoch 179, Loss: 0.48930585384368896, Val Loss: 0.4709450602531433
# end of epoch.
# start of epoch 180
# Training loss (for one batch) at step 0: 0.4270482361316681
# Epoch 180, Loss: 0.4270482361316681, Val Loss: 0.42699483036994934
# end of epoch.
# start of epoch 181
# Training loss (for one batch) at step 0: 0.48033812642097473
# Epoch 181, Loss: 0.48033812642097473, Val Loss: 0.48846787214279175
# end of epoch.
# start of epoch 182
# Training loss (for one batch) at step 0: 0.40170708298683167
# Epoch 182, Loss: 0.40170708298683167, Val Loss: 0.437779039144516
# end of epoch.
# start of epoch 183
# Training loss (for one batch) at step 0: 0.4042998254299164
# Epoch 183, Loss: 0.4042998254299164, Val Loss: 0.42628365755081177
# end of epoch.
# start of epoch 184
# Training loss (for one batch) at step 0: 0.448465496301651
# Epoch 184, Loss: 0.448465496301651, Val Loss: 0.4950847327709198
# end of epoch.
# start of epoch 185
# Training loss (for one batch) at step 0: 0.46509864926338196
# Epoch 185, Loss: 0.46509864926338196, Val Loss: 0.4710714519023895
# end of epoch.
# start of epoch 186
# Training loss (for one batch) at step 0: 0.43976789712905884
# Epoch 186, Loss: 0.43976789712905884, Val Loss: 0.3894815444946289
# end of epoch.
# start of epoch 187
# Training loss (for one batch) at step 0: 0.5143330097198486
# Epoch 187, Loss: 0.5143330097198486, Val Loss: 0.5464000701904297
# end of epoch.
# start of epoch 188
# Training loss (for one batch) at step 0: 0.41784781217575073
# Epoch 188, Loss: 0.41784781217575073, Val Loss: 0.5541664958000183
# end of epoch.
# start of epoch 189
# Training loss (for one batch) at step 0: 0.5130853652954102
# Epoch 189, Loss: 0.5130853652954102, Val Loss: 0.5025231838226318
# end of epoch.
# start of epoch 190
# Training loss (for one batch) at step 0: 0.4762265682220459
# Epoch 190, Loss: 0.4762265682220459, Val Loss: 0.5611976385116577
# end of epoch.
# start of epoch 191
# Training loss (for one batch) at step 0: 0.4579660892486572
# Epoch 191, Loss: 0.4579660892486572, Val Loss: 0.4762285351753235
# end of epoch.
# start of epoch 192
# Training loss (for one batch) at step 0: 0.5363343954086304
# Epoch 192, Loss: 0.5363343954086304, Val Loss: 0.5084092020988464
# end of epoch.
# start of epoch 193
# Training loss (for one batch) at step 0: 0.47770026326179504
# Epoch 193, Loss: 0.47770026326179504, Val Loss: 0.5637773275375366
# end of epoch.
# start of epoch 194
# Training loss (for one batch) at step 0: 0.5264250636100769
# Epoch 194, Loss: 0.5264250636100769, Val Loss: 0.5088855028152466
# end of epoch.
# start of epoch 195
# Training loss (for one batch) at step 0: 0.4525124728679657
# Epoch 195, Loss: 0.4525124728679657, Val Loss: 0.4270199239253998
# end of epoch.
# start of epoch 196
# Training loss (for one batch) at step 0: 0.40744757652282715
# Epoch 196, Loss: 0.40744757652282715, Val Loss: 0.46216368675231934
# end of epoch.
# start of epoch 197
# Training loss (for one batch) at step 0: 0.3961133360862732
# Epoch 197, Loss: 0.3961133360862732, Val Loss: 0.5647318363189697
# end of epoch.
# start of epoch 198
# Training loss (for one batch) at step 0: 0.47027459740638733
# Epoch 198, Loss: 0.47027459740638733, Val Loss: 0.5367097854614258
# end of epoch.
# start of epoch 199
# Training loss (for one batch) at step 0: 0.43841293454170227
# Epoch 199, Loss: 0.43841293454170227, Val Loss: 0.4838854670524597
# end of epoch.
# start of epoch 200
# Training loss (for one batch) at step 0: 0.5208227038383484
# Epoch 200, Loss: 0.5208227038383484, Val Loss: 0.37914028763771057
# end of epoch.
# Checkpoint directory :  checkpoints/CNNgeo/200507_regressor_filter_size_up
# Tensorboard log directory :  logs/CNNgeo/200507_regressor_filter_size_up

# %%
model.summary()
# Out:
# Model: "cnn_geo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature__extractor (Feature_ multiple                  113600
# _________________________________________________________________
# correlation_network (Correla multiple                  0
# _________________________________________________________________
# spatial_transformer_regresso multiple                  875250
# =================================================================
# Total params: 988,850
# Trainable params: 988,146
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# # 3. Debug

# %%
datasets = load_data(['train'], config)
ds = datasets['train'].batch(1)
# Out:
# train dataset amount : 1

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
#image_B_hat = np.ones([1, 64, 64, 3])
pred, score = model(image_A, image_B)

# %%
print("parameter shape", pred.shape)
print("score shape", score.shape)
print(image_A.shape)
# Out:
# parameter shape (1, 9, 2)
# score shape (1, 16, 16, 16, 16)
# (1, 64, 64, 3)

# %% [markdown]
# ## 3.1. 입력 영상에 따른 모델 추정 확인

# %% [markdown]
# ### case 1) 임의의 기하관계를 갖는 영상 쌍 (image A, image B)

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred1 = pred.copy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.0421 0.1149]
#   [0.0646 -0.0600]
#   [0.1233 -0.1826]
#   [0.1987 -0.0121]
#   [0.1838 -0.0579]
#   [-0.0676 -0.1882]
#   [-0.1405 0.1601]
#   [-0.1487 0.1025]
#   [-0.1478 0.1609]]] and
#  pred : [[[-0.0040 0.0018]
#   [-0.0005 0.0023]
#   [0.0022 -0.0011]
#   [0.0089 0.0033]
#   [-0.0040 -0.0013]
#   [-0.0002 -0.0045]
#   [0.0001 0.0007]
#   [-0.0082 0.0005]
#   [0.0040 -0.0026]]]
# loss : [0.1541]

# %% [markdown]
# ### case 2) 임의의 다른 기하관계를 갖는 영상 쌍 (image A, image B)

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred2 = pred.copy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.0869 0.1943]
#   [0.0039 -0.0531]
#   [-0.0707 0.1441]
#   [-0.0651 0.0581]
#   [0.0862 0.1420]
#   [0.1797 0.0424]
#   [-0.1575 -0.1379]
#   [0.0096 0.1941]
#   [-0.1050 -0.0474]]] and
#  pred : [[[-0.0040 0.0018]
#   [-0.0005 0.0023]
#   [0.0022 -0.0011]
#   [0.0089 0.0033]
#   [-0.0040 -0.0013]
#   [-0.0002 -0.0045]
#   [0.0001 0.0007]
#   [-0.0082 0.0005]
#   [0.0040 -0.0026]]]
# loss : [0.1205]

# %% [markdown]
# ### case 3) Image A와 연관 없는 image B(백색 사진)의 영상 쌍

# %%
image_B = np.ones([1, 64, 64, 3])
pred, score = model(image_A, image_B)

print("compare gt : {} and \n pred : {}".format(parameters, pred))
loss = tf.reduce_sum(tf.keras.losses.MSE(pred, parameters), axis=1)
print("loss : {}".format(loss))

pred = pred.numpy()
image_C = list(map(lambda x : image.synthesize_image(x[0], x[1], (64, 64), bbox=None, pad_ratio=None),
                   zip(image_A.copy(), pred.copy())))    
image_C = np.array(image_C)
visualize.show_TPS_image([image_A, image_B, image_C], [np.ones_like(parameters), parameters, pred])    

pred3 = pred.copy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# compare gt : [[[-0.0869 0.1943]
#   [0.0039 -0.0531]
#   [-0.0707 0.1441]
#   [-0.0651 0.0581]
#   [0.0862 0.1420]
#   [0.1797 0.0424]
#   [-0.1575 -0.1379]
#   [0.0096 0.1941]
#   [-0.1050 -0.0474]]] and
#  pred : [[[-0.0040 0.0018]
#   [-0.0005 0.0023]
#   [0.0022 -0.0011]
#   [0.0089 0.0033]
#   [-0.0040 -0.0013]
#   [-0.0002 -0.0045]
#   [0.0001 0.0007]
#   [-0.0082 0.0005]
#   [0.0040 -0.0026]]]
# loss : [0.1205]

# %%
print(pred1, "\n", pred2, "\n", pred3)
# Out:
# [[[-0.0040 0.0018]
#   [-0.0005 0.0023]
#   [0.0022 -0.0011]
#   [0.0089 0.0033]
#   [-0.0040 -0.0013]
#   [-0.0002 -0.0045]
#   [0.0001 0.0007]
#   [-0.0082 0.0005]
#   [0.0040 -0.0026]]]
#  [[[-0.0040 0.0018]
#   [-0.0005 0.0023]
#   [0.0022 -0.0011]
#   [0.0089 0.0033]
#   [-0.0040 -0.0013]
#   [-0.0002 -0.0045]
#   [0.0001 0.0007]
#   [-0.0082 0.0005]
#   [0.0040 -0.0026]]]
#  [[[-0.0040 0.0018]
#   [-0.0005 0.0023]
#   [0.0022 -0.0011]
#   [0.0089 0.0033]
#   [-0.0040 -0.0013]
#   [-0.0002 -0.0045]
#   [0.0001 0.0007]
#   [-0.0082 0.0005]
#   [0.0040 -0.0026]]]

# %% [markdown]
# case 1)와 case 2)는 동일한 영상을 다른 기하관계를 사용하여 두 개의 영상쌍(image pair)을 만든 경우를 말한다. 모델이 정상적이라면 각 영상쌍의 기하관계를 추정할 수 있을 것이다. 그러나 두 영상쌍이 다른 기하관계를 갖음에도 동일한 모션파라미터를 추정하였다. case 3)에서는 전혀 연관 없는 영상을 image B로 사용하였다. image B는 어떤 특징 정보도 없는 백색 사진임에도 불구하고 모델은 case 1)과 case 2)에서와 같은 모션파라미터를 추정하였다.

# %%
model.summary()
# Out:
# Model: "cnn_geo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature__extractor (Feature_ multiple                  113600
# _________________________________________________________________
# correlation_network (Correla multiple                  0
# _________________________________________________________________
# spatial_transformer_regresso multiple                  875250
# =================================================================
# Total params: 988,850
# Trainable params: 988,146
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# ## 3.2 Correlation 분포에 따른 Regressor 예측

# %% [markdown]
# 3.1의 case 1, 2, 3에서 Regressor은 같은 모션파라미터를 예측했다. 명확한 이유를 파악하기 위해 입력 correlation(matching scores)를 제어하며 spatial parameter regressor의 출력을 분석했다.

# %%
x = np.zeros([1, 16, 16, 16, 16]) # all correlations are zero
y = model.layers[2](x)
print(y)
# Out:
# WARNING:tensorflow:Layer spatial_transformer_regressor is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# tf.Tensor(
# [[-0.0040 0.0018 -0.0005 0.0023 0.0022 -0.0011 0.0089 0.0033 -0.0040
#   -0.0013 -0.0002 -0.0045 0.0001 0.0007 -0.0082 0.0005 0.0040 -0.0026]], shape=(1, 18), dtype=float32)

# %%
x = np.ones([1, 16, 16, 16, 16]) # all correlations are one
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[-0.0040 0.0018 -0.0005 0.0023 0.0022 -0.0011 0.0089 0.0033 -0.0040
#   -0.0013 -0.0002 -0.0045 0.0001 0.0007 -0.0082 0.0005 0.0040 -0.0026]], shape=(1, 18), dtype=float32)

# %%
x = np.random.normal(loc=0.5, scale=0.0, size=[1, 16, 16, 16, 16])
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[-0.0040 0.0018 -0.0005 0.0023 0.0022 -0.0011 0.0089 0.0033 -0.0040
#   -0.0013 -0.0002 -0.0045 0.0001 0.0007 -0.0082 0.0005 0.0040 -0.0026]], shape=(1, 18), dtype=float32)

# %%
x = np.random.normal(loc=0.5, scale=0.3, size=[1, 16, 16, 16, 16])
y = model.layers[2](x)
print(y)
# Out:
# tf.Tensor(
# [[0.0247 0.0731 -0.0753 -0.0256 -0.0602 0.0343 -0.0709 -0.0920 -0.0198
#   -0.1352 0.0646 -0.0243 0.0047 -0.0519 -0.0321 -0.0129 -0.0521 -0.0869]], shape=(1, 18), dtype=float32)

# %% [markdown]
# 위 실험의 결과를 토대로 확인할 수 있는 것은 regressor의 출력은 입력 correlation의 크기가 아닌 편차에 따라 달라진다는 것이다. correlation의 분포의 표준편차를 변화시키며 출력의 변화 정도를 추정해주었다.

# %%
_range = np.linspace(0, 1.0, 50)
print(_range)
# Out:
# [0.0000 0.0204 0.0408 0.0612 0.0816 0.1020 0.1224 0.1429 0.1633 0.1837
#  0.2041 0.2245 0.2449 0.2653 0.2857 0.3061 0.3265 0.3469 0.3673 0.3878
#  0.4082 0.4286 0.4490 0.4694 0.4898 0.5102 0.5306 0.5510 0.5714 0.5918
#  0.6122 0.6327 0.6531 0.6735 0.6939 0.7143 0.7347 0.7551 0.7755 0.7959
#  0.8163 0.8367 0.8571 0.8776 0.8980 0.9184 0.9388 0.9592 0.9796 1.0000]

# %%
variations_via_std = []
variations_via_mean = []
for std in _range:
    variations = []
    for i in range(1000):
        x = np.random.normal(loc=0.5, scale=std, size=[1, 16, 16, 16, 16])
        _y = model.layers[2](x)
        variations.append(_y)
    variations_via_std.append(np.sum(np.std(np.array(variations), axis = 0)))
    
for mean in _range:
    variations = []
    for i in range(1000):
        x = np.random.normal(loc=mean, scale=0.1, size=[1, 16, 16, 16, 16])
        _y = model.layers[2](x)
        variations.append(_y)
    variations_via_mean.append(np.sum(np.std(np.array(variations), axis = 0)))

# %%
variations
# Out:
# [<tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0027, 0.0095, -0.0104, 0.0038, 0.0036, 0.0016, 0.0042,
#          -0.0005, -0.0045, 0.0016, -0.0048, -0.0126, -0.0023, -0.0062,
#          -0.0137, 0.0104, 0.0011, -0.0110]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0012, 0.0188, -0.0054, -0.0143, 0.0020, -0.0018, 0.0019,
#          -0.0021, -0.0139, 0.0063, 0.0111, -0.0290, 0.0108, -0.0071,
#          -0.0085, 0.0046, -0.0027, -0.0148]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0064, 0.0026, -0.0007, 0.0064, 0.0034, 0.0057, 0.0030,
#          -0.0126, -0.0296, -0.0165, -0.0023, -0.0197, 0.0174, -0.0092,
#          -0.0210, -0.0101, -0.0206, 0.0019]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0046, 0.0053, -0.0116, -0.0069, -0.0042, 0.0037, 0.0039,
#          0.0025, -0.0076, -0.0062, 0.0093, 0.0031, 0.0065, -0.0058,
#          -0.0128, -0.0046, 0.0085, -0.0096]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0163, 0.0195, -0.0053, -0.0052, -0.0106, -0.0011, -0.0013,
#          -0.0052, -0.0093, -0.0102, 0.0086, -0.0041, 0.0062, -0.0035,
#          -0.0168, -0.0060, -0.0060, -0.0066]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0103, 0.0131, -0.0091, -0.0043, -0.0033, -0.0045, -0.0040,
#          -0.0092, -0.0183, 0.0058, 0.0228, -0.0086, -0.0038, -0.0025,
#          0.0068, -0.0083, 0.0001, -0.0030]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[0.0075, -0.0051, -0.0123, -0.0123, -0.0137, 0.0119, -0.0043,
#          0.0197, -0.0036, -0.0059, 0.0161, -0.0057, -0.0131, 0.0141,
#          -0.0045, -0.0027, 0.0014, 0.0091]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0045, 0.0067, -0.0129, -0.0037, 0.0018, 0.0095, 0.0097,
#          -0.0031, -0.0074, 0.0040, 0.0046, -0.0146, 0.0072, -0.0014,
#          -0.0163, -0.0088, -0.0018, 0.0052]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0223, 0.0101, 0.0018, -0.0046, -0.0120, -0.0001, 0.0025,
#          -0.0138, -0.0149, -0.0048, 0.0024, -0.0098, -0.0009, 0.0082,
#          -0.0063, 0.0039, 0.0053, -0.0078]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[0.0005, 0.0046, -0.0099, 0.0139, -0.0023, 0.0153, 0.0015,
#          -0.0002, 0.0127, 0.0006, 0.0039, -0.0030, 0.0133, -0.0112,
#          -0.0165, -0.0009, 0.0125, -0.0053]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[0.0082, 0.0029, -0.0042, 0.0064, -0.0122, 0.0093, -0.0088,
#          -0.0014, -0.0228, -0.0040, -0.0023, -0.0004, 0.0202, 0.0039,
#          -0.0107, -0.0030, 0.0017, 0.0048]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.
], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0087, -0.0022, -0.0133, 0.0025, -0.0311, 0.0049, -0.0071,
#          0.0037, -0.0081, 0.0021, 0.0162, -0.0089, -0.0072, 0.0035,
#          -0.0194, 0.0117, 0.0037, -0.0027]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[0.0062, 0.0084, 0.0041, 0.0032, 0.0033, 0.0039, -0.0036, 0.0057,
#          -0.0304, -0.0100, -0.0008, -0.0138, 0.0102, -0.0020, -0.0109,
#          -0.0011, 0.0066, -0.0007]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[0.0027, 0.0109, 0.0109, -0.0113, 0.0035, 0.0113, 0.0048, 0.0050,
#          -0.0083, 0.0059, 0.0119, -0.0101, 0.0183, -0.0067, 0.0011,
#          0.0037, 0.0020, -0.0085]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0112, 0.0191, -0.0081, -0.0189, 0.0020, -0.0004, -0.0096,
#          -0.0087, -0.0165, 0.0043, -0.0058, -0.0090, 0.0160, -0.0086,
#          -0.0027, -0.0039, 0.0021, 0.0033]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[0.0045, 0.0129, -0.0013, 0.0052, 0.0052, 0.0104, 0.0010, -0.0063,
#          -0.0166, -0.0022, 0.0248, -0.0067, 0.0032, -0.0100, -0.0043,
#          0.0025, -0.0173, -0.0003]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0022, 0.0219, 0.0074, -0.0076, -0.0001, 0.0112, 0.0068,
#          -0.0068, -0.0082, -0.0047, 0.0028, -0.0100, 0.0157, -0.0012,
#          -0.0243, -0.0101, -0.0171, -0.0013]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0048, 0.0095, -0.0183, -0.0032, -0.0010, -0.0023, 0.0085,
#          0.0082, -0.0113, -0.0032, 0.0031, -0.0123, 0.0068, 0.0015,
#          -0.0232, -0.0110, 0.0032, 0.0005]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[-0.0061, 0.0264, -0.0152, 0.0098, -0.0059, 0.0080, 0.0016,
#          -0.0053, -0.0190, -0.0061, 0.0093, -0.0049, 0.0093, -0.0044,
#          -0.0061, 0.0032, -0.0122, -0.0124]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 18), dtype=float32, numpy=
#  array([[0.0056, 0.0005, 0.0010, -0.0081, 0.0084, -0.0086, 0.0080,
#          -0.0095, -0.0020, 0.0149, 0.0138, -0.0061, -0.0007, 0.0134,
#          0.0008, 0.0036, 0.0032, 0.0042]], dtype=float32)>]

# %%
plt.ylabel("variations of motion parameters")
plt.xlabel("via sigma, mean. \n correlations are sampled from N(0.5, sigma), N(mean, 0.1)")
plt.plot(_range, variations_via_std, label='via sigma')
plt.plot(_range, variations_via_mean, label='via mean')
plt.legend()
plt.show()

# %% [markdown]
# 1. VGG16을 통한 correlations
# 2. 시각화 방식 개선
# 3. tentative penalty

# %% [markdown]
# ## b. 특징추출기의 정상 동작 검증

# %%
np.set_printoptions(formatter = {"float_kind" : lambda x : "{0:0.4f}".format(x)} )
#np.set_printoptions(formatter={'float_kind': lambda x: "{0:0.3f}".format(x)})

# %% [markdown]
# ### 동일 영상에 대한 correlation

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_A)

score = score.numpy()[0]
parameters = parameters[0]
image_A = image_A[0]
image_B = image_B[0]

print(score.shape, parameters.shape, image_A.shape)
# Out:
# (16, 16, 16, 16) (9, 2) (64, 64, 3)

# %%
def get_matching_grid_from_B(parameters, center_point):
    src_points = np.array([[0.0, 0.0], [0.5, 0.0], [1.0, 0.0],
                                   [0.0, 0.5], [0.5, 0.5], [1.0, 0.5],
                                   [0.0, 1.0], [0.5, 1.0], [1.0, 1.0]])

    dst_points = src_points +parameters

    theta = tps.tps_theta_from_points(src_points, dst_points, reduced=True)
    dshape = (64, 64)
    grid = tps.tps_grid(theta, dst_points, dshape)
    mapx, mapy = tps.tps_grid_to_remap(grid, (64, 64))
    points = np.concatenate([mapy[:,:,np.newaxis], mapx[:,:,np.newaxis]], axis=2)
    #print("points :", points)
    center_point = np.array(center_point)
    #print("grid center : ", center_point)
    center_point = center_point[np.newaxis, np.newaxis, :]
    distance = np.sum(np.power((points - center_point), 2), axis=2)
    #print("distance : ", distance)
    ri, ci = distance.argmin()//distance.shape[1], distance.argmin()%distance.shape[1]
    return (ri, ci)

# %%
def score_test(grid_coord, score, parameters, images, grid_shape=(16,16)):
    image_A, image_B = images
    score = score[grid_coord[0], grid_coord[1]]
    H, W, C = image_A.shape
    grid_size = H/grid_shape[0], W/grid_shape[1]

    start_pix_h = int(grid_size[0]*grid_coord[0])
    end_pix_h = int(grid_size[0]*(1+grid_coord[0]))
    start_pix_w = int(grid_size[1]*grid_coord[1])
    end_pix_w = int(grid_size[1]*(1+grid_coord[1]))
    
    drawn_grid_image_A = image_A.copy()
    drawn_grid_image_A[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)   
    
    expected_drawn_grid_image_B = image_B.copy()
    grid_center_A = (int(start_pix_h+grid_size[0]/2), int(start_pix_w+grid_size[1]/2))
    grid_center_B = get_matching_grid_from_B(parameters, grid_center_A)
    start_pix_h = int(grid_center_B[0] - grid_size[0]/2)
    start_pix_w = int(grid_center_B[1] - grid_size[1]/2)
    end_pix_h = int(grid_center_B[0] + grid_size[0]/2)
    end_pix_w = int(grid_center_B[1] + grid_size[1]/2)
    expected_drawn_grid_image_B[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)
    
    drawn_grid_image_B = image_B.copy()
    max_correlation_grid_index = score.argmax()//score.shape[1], score.argmax()%score.shape[1]
    start_pix_h = int(grid_size[0]*max_correlation_grid_index[0])
    end_pix_h = int(grid_size[0]*(1+max_correlation_grid_index[0]))
    start_pix_w = int(grid_size[1]*max_correlation_grid_index[1])
    end_pix_w = int(grid_size[1]*(1+max_correlation_grid_index[1]))

    drawn_grid_image_B[start_pix_h:end_pix_h, start_pix_w:end_pix_w] = (0,0,0)
    
    print("top 10 correlation values in descending : ", np.sort(score.flatten())[::-1][:10])
    print("standard deviation : {}".format(np.std(score)))
    return drawn_grid_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, score

# %%
drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, patch_score= score_test(grid_coord=(5,10), 
                                                                            score=score, 
                                                                            parameters=np.zeros([9,2]), 
                                                                            images=(image_A, image_A))
# Out:
# top 10 correlation values in descending :  [0.0637 0.0636 0.0636 0.0636 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635]
# standard deviation : 0.0010157673386856914

# %%
# n, bins, patches = plt.hist(patch_score, bins=10, density=False, facecolor='blue', alpha=0.5)
# plt.xlabel('X bins')
# plt.ylabel('Frequency')
# plt.title('Histogram of correlations')


fig = plt.figure()

ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)
ax1.imshow(drawn_image_A)
ax2.imshow(expected_drawn_grid_image_B)
ax3.imshow(drawn_grid_image_B)
plt.show()
n, bins, patches = plt.hist(patch_score, bins=5, density=False, facecolor='blue', alpha=0.5)
plt.show()

# %%
drawn_image_A.shape
expected_drawn_grid_image_B.shape
drawn_grid_image_B.shape
# Out:
# (64, 64, 3)

# %% [markdown]
# ### b.1 ) 동일한 사진의 경우

# %%
for i in range(16):
    drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, patch_score= score_test(grid_coord=(i,i), 
                                                                                score=score, 
                                                                                parameters=np.zeros([9,2]), 
                                                                                images=(image_A, image_A))   
    fig = plt.figure()
    
    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)

    ax1.imshow(drawn_image_A)
    ax2.imshow(expected_drawn_grid_image_B)
    ax3.imshow(drawn_grid_image_B)

    plt.show()
    n, bins, patches = plt.hist(patch_score, bins=5, density=False, facecolor='blue', alpha=0.5)
    plt.axis([0.055, 0.070, 0, 30])
    plt.show()
# Out:
# top 10 correlation values in descending :  [0.0684 0.0671 0.0670 0.0670 0.0669 0.0669 0.0669 0.0669 0.0669 0.0669]
# standard deviation : 0.001597558963112533
# top 10 correlation values in descending :  [0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634]
# standard deviation : 0.0011226602364331484
# top 10 correlation values in descending :  [0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635]
# standard deviation : 0.0011879857629537582
# top 10 correlation values in descending :  [0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635]
# standard deviation : 0.0011886610882356763
# top 10 correlation values in descending :  [0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635]
# standard deviation : 0.0011864237021654844
# top 10 correlation values in descending :  [0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635]
# standard deviation : 0.0011612907983362675
# top 10 correlation values in descending :  [0.0634 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633]
# standard deviation : 0.0010184899438172579
# top 10 correlation values in descending :  [0.0637 0.0635 0.0635 0.0635 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634]
# standard deviation : 0.0012352525955066085
# top 10 correlation values in descending :  [0.0635 0.0634 0.0634 0.0634 0.0634 0.0633 0.0633 0.0633 0.0633 0.0633]
# standard deviation : 0.0010360548039898276
# top 10 correlation values in descending :  [0.0636 0.0635 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634]
# standard deviation : 0.0009450266952626407
# top 10 correlation values in descending :  [0.0635 0.0633 0.0633 0.0633 0.0632 0.0632 0.0632 0.0632 0.0632 0.0632]
# standard deviation : 0.0009698489448055625
# top 10 correlation values in descending :  [0.0634 0.0634 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633]
# standard deviation : 0.0011283416533842683
# top 10 correlation values in descending :  [0.0635 0.0635 0.0635 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634]
# standard deviation : 0.0012133409036323428
# top 10 correlation values in descending :  [0.0635 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634]
# standard deviation : 0.0011881880927830935
# top 10 correlation values in descending :  [0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634]
# standard deviation : 0.001091345096938312
# top 10 correlation values in descending :  [0.0660 0.0650 0.0649 0.0649 0.0649 0.0649 0.0649 0.0649 0.0649 0.0649]
# standard deviation : 0.0014043570263311267

# %% [markdown]
# ### b.2 ) 다른 사진의 경우

# %%
for image_A, image_B, parameters in ds.take(1):
    image_A = image_A.numpy()
    image_B = image_B.numpy()
    parameters = parameters.numpy()
pred, score = model(image_A, image_A)

score = score.numpy()[0]
parameters = parameters[0]
image_A = image_A[0]
image_B = image_B[0]

print(score.shape, parameters.shape, image_A.shape)
# Out:
# (16, 16, 16, 16) (9, 2) (64, 64, 3)

# %%
for i in range(16):
    drawn_image_A, expected_drawn_grid_image_B, drawn_grid_image_B, patch_score = score_test(grid_coord=(i,i), 
                                                                                score=score, 
                                                                                parameters=parameters, 
                                                                                images=(image_A, image_B))   
    fig = plt.figure()

    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)

    ax1.imshow(drawn_image_A)
    ax2.imshow(expected_drawn_grid_image_B)
    ax3.imshow(drawn_grid_image_B)

    plt.show()
    n, bins, patches = plt.hist(patch_score, bins=5, density=False, facecolor='blue', alpha=0.5)
    plt.axis([0.055, 0.070, 0, 30])
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0684 0.0670 0.0670 0.0669 0.0669 0.0668 0.0668 0.0668 0.0668 0.0668]
# standard deviation : 0.0015956450952216983
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0635 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634]
# standard deviation : 0.0011092957574874163
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635]
# standard deviation : 0.0011638342402875423
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635]
# standard deviation : 0.001165060675702989
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635 0.0635]
# standard deviation : 0.0011623476166278124
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634]
# standard deviation : 0.0011253750417381525
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0635 0.0634 0.0634 0.0634 0.0634 0.0634 0.0634 0.0633 0.0633 0.0633]
# standard deviation : 0.0011014011688530445
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0639 0.0636 0.0635 0.0635 0.0635 0.0635 0.0635 0.0634 0.0634 0.0634]
# standard deviation : 0.0011900101089850068
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0636 0.0634 0.0634 0.0634 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633]
# standard deviation : 0.0009931107051670551
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0636 0.0634 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633 0.0632 0.0632]
# standard deviation : 0.0010418005986139178
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0636 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633 0.0632 0.0632 0.0632]
# standard deviation : 0.000874319754075259
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0638 0.0635 0.0634 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633 0.0633]
# standard deviation : 0.0009026258485391736
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0639 0.0636 0.0635 0.0634 0.0634 0.0633 0.0633 0.0633 0.0633 0.0633]
# standard deviation : 0.0007458688342012465
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0639 0.0637 0.0637 0.0634 0.0633 0.0633 0.0633 0.0632 0.0632 0.0632]
# standard deviation : 0.0007063895463943481
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0640 0.0638 0.0635 0.0634 0.0633 0.0633 0.0632 0.0632 0.0631 0.0631]
# standard deviation : 0.0006769049214199185
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# top 10 correlation values in descending :  [0.0679 0.0656 0.0650 0.0649 0.0649 0.0649 0.0648 0.0648 0.0648 0.0648]
# standard deviation : 0.0012634923914447427
